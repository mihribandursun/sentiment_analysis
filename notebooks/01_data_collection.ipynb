# %% [markdown]
# # The notebook from which I extracted the data.

# %% [markdown]
# Maltepe Links with vendor_id

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time
import csv
import re

# Chrome settings
chrome_options = Options()
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                            "AppleWebKit/537.36 (KHTML, like Gecko) "
                            "Chrome/127.0.0.0 Safari/537.36")
# chrome_options.add_argument("--headless")

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

url = "https://www.yemeksepeti.com/restaurants/new?lng=29.1306017790985&lat=40.92470845978729&vertical=restaurants&cuisines=1090"
driver.get(url)
time.sleep(7)

print("Sayfa yüklendi, restoranlar toplanıyor...")

# Scroll simulation
scroll_pause = 4
scroll_step = 1000
max_scrolls = 120

last_height = driver.execute_script("return document.body.scrollHeight")
scrolls_done = 0

while scrolls_done < max_scrolls:
    driver.execute_script(f"window.scrollBy(0, {scroll_step});")
    time.sleep(scroll_pause)
    new_height = driver.execute_script("return document.body.scrollHeight")

    if new_height == last_height:
        print("Sayfanın sonuna ulaşıldı ✅")
        break
    last_height = new_height
    scrolls_done += 1
    print(f"{scrolls_done}. scroll tamamlandı...")

print("Tüm restoran kartları yüklendi, veriler çekiliyor...")
time.sleep(2)

# Find restaurant cards
cards = driver.find_elements(By.CSS_SELECTOR, 'a[data-testid^="vendor-tile-new-link-"]')
print(f"{len(cards)} restoran bulundu.\n")

# CSV file
filename = "../data/raw/links/maltepe_links/maltepe_waffle_restaurants.csv"
headers = [
    "vendor_id", "restaurant_name", "link", "img", "rating", "review_count",
    "price_range", "min_order", "cuisine_type",
    "delivery_time", "delivery_type"
]

with open(filename, "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(headers)

# Get the information from each restaurant card.
for i, card in enumerate(cards, 1):
    try:
        name = card.find_element(By.CSS_SELECTOR, "div.vendor-name").get_attribute("title")
        link = card.get_attribute("href")
        img = ""
        rating = ""
        review_count = ""
        price_range = ""
        min_order = ""
        cuisine_type = ""
        delivery_time = ""
        delivery_type = ""
        vendor_id = ""

        # Get the vendor ID from the link.
        try:
            match = re.search(r"/restaurant/([^/]+)/", link)
            if match:
                vendor_id = match.group(1)
        except:
            pass

        # Image
        try:
            img = card.find_element(By.CSS_SELECTOR, "img").get_attribute("src")
        except:
            pass

        # Rating and review
        try:
            rating = card.find_element(By.CSS_SELECTOR, ".bds-c-rating__label-primary").text
        except:
            pass
        try:
            review_count = card.find_element(By.CSS_SELECTOR, ".bds-c-rating__label-secondary").text
        except:
            pass

        # Information lines
        info_items = card.find_elements(By.CSS_SELECTOR, ".vendor-info-row-text .sanitized-row-text")
        if len(info_items) > 0:
            price_range = info_items[0].text if len(info_items) > 0 else ""
            min_order = info_items[1].text if len(info_items) > 1 else ""
            cuisine_type = info_items[2].text if len(info_items) > 2 else ""
            delivery_time = info_items[3].text if len(info_items) > 3 else ""
            delivery_type = info_items[4].text if len(info_items) > 4 else ""

        row = [
            vendor_id, name, link, img, rating, review_count,
            price_range, min_order, cuisine_type, delivery_time, delivery_type
        ]

        with open(filename, "a", newline="", encoding="utf-8") as f:
            writer = csv.writer(f)
            writer.writerow(row)

        print(f"[{i}/{len(cards)}] Kaydedildi: {name} ({vendor_id})")

    except Exception as e:
        print(f"Hata oluştu: {e}")

print(f"\n✅ Tüm {len(cards)} restoran bilgileri {filename} dosyasına kaydedildi.")
driver.quit()
# Out:
# Sayfa yüklendi, restoranlar toplanıyor...
# Sayfanın sonuna ulaşıldı ✅
# Tüm restoran kartları yüklendi, veriler çekiliyor...
# 43 restoran bulundu.
#
# [1/43] Kaydedildi: Pwb Peanut Waffle Belgium (trbe)
# [2/43] Kaydedildi: Ruby Patisserie (dwle)
# [3/43] Kaydedildi: Always Waffle (a8yy)
# [4/43] Kaydedildi: Waffpir Waffle & Kumpir (zs1i)
# [5/43] Kaydedildi: Keyf-i Kumpir & Waffle (raoo)
# [6/43] Kaydedildi: Ortaköylü Kumpir Waffle (h7ph)
# [7/43] Kaydedildi: Mina Waffle (ut4g)
# [8/43] Kaydedildi: Waffee Waffle (wu45)
# [9/43] Kaydedildi: Peanut Waffle Belgium (u0zq)
# [10/43] Kaydedildi: Lotus Croissant & Breakfast (eil1)
# [11/43] Kaydedildi: Bitez Dondurma Waffle (v65d)
# [12/43] Kaydedildi: Peanut Waffle Belgium (mrtr)
# [13/43] Kaydedildi: Shuffle Waffle Belgium (ljgb)
# [14/43] Kaydedildi: Granny's Waffles & Kumpir (daa5)
# [15/43] Kaydedildi: Waffle Time (denz)
# [16/43] Kaydedildi: 112 Kumpir & Waffle (qlsq)
# [17/43] Kaydedildi: Delice Kumpir & Waffle Dünyası (ch2f)
# [18/43] Kaydedildi: Maltepe Tostçusu Waffle & Magnolia (yfyo)
# [19/43] Kaydedildi: Altı Ustü Waffle (e0fw)
# [20/43] Kaydedildi: Büyük Boy Pizza (y0rw)
# [21/43] Kaydedildi: Kral Waffle (v9xk)
# [22/43] Kaydedildi: Galata Kumpir & Waffle (sugx)
# [23/43] Kaydedildi: Galaxy Waffle (eqd0)
# [24/43] Kaydedildi: Burger Place (en9a)
# [25/43] Kaydedildi: Mm’s Sweet House (tg2k)
# [26/43] Kaydedildi: Chicken Place (uvor)
# [27/43] Kaydedildi: Daddy's Waffle (lokb)
# [28/43] Kaydedildi: +1 Waffle (w6nc)
# [29/43] Kaydedildi: Adam Pizza & Burger (hu4d)
# [30/43] Kaydedildi: E Waffle (yo1c)
# [31/43] Kaydedildi: Waffle Pause (aedy)
# [32/43] Kaydedildi: Date Waffle & Kumpir (x1p2)
# [33/43] Kaydedildi: Müptela Waffle (d3od)
# [34/43] Kaydedildi: Xxl Waffle (sjqj)
# [35/43] Kaydedildi: Angel's Kumpir & Waffle (enqj)
# [36/43] Kaydedildi: Mimiloss Waffle (kpca)
# [37/43] Kaydedildi: Etod Kumpir & Waffle & Dondurma (cypw)
# [38/43] Kaydedildi: No:1 Waffle & Croissant House (ebxy)
# [39/43] Kaydedildi: Doxie Coffee & Waffle (l0v1)
# [40/43] Kaydedildi: Waffle Boom (e62y)
# [41/43] Kaydedildi: Waffle XL & Juice (rx0e)
# [42/43] Kaydedildi: Ma Belle Chocolate (xxbq)
# [43/43] Kaydedildi: Öz Waffle (wmja)
#
# ✅ Tüm 43 restoran bilgileri maltepe_waffle_restoranlar_detayli.csv dosyasına kaydedildi.

# %% [markdown]
# Beyoğlu Links with vendor_id

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time
import csv
import re

# Chrome settings
chrome_options = Options()
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                            "AppleWebKit/537.36 (KHTML, like Gecko) "
                            "Chrome/127.0.0.0 Safari/537.36")
# chrome_options.add_argument("--headless")

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

url = "https://www.yemeksepeti.com/restaurants/new?lng=28.9672834105591&lat=41.03933841010486&vertical=restaurants&cuisines=1090"
driver.get(url)
time.sleep(7)

print("Sayfa yüklendi, restoranlar toplanıyor...")

# Scroll simulation
scroll_pause = 4
scroll_step = 1000
max_scrolls = 120

last_height = driver.execute_script("return document.body.scrollHeight")
scrolls_done = 0

while scrolls_done < max_scrolls:
    driver.execute_script(f"window.scrollBy(0, {scroll_step});")
    time.sleep(scroll_pause)
    new_height = driver.execute_script("return document.body.scrollHeight")

    if new_height == last_height:
        print("Sayfanın sonuna ulaşıldı ✅")
        break
    last_height = new_height
    scrolls_done += 1
    print(f"{scrolls_done}. scroll tamamlandı...")

print("Tüm restoran kartları yüklendi, veriler çekiliyor...")
time.sleep(2)

# Find restaurant cards
cards = driver.find_elements(By.CSS_SELECTOR, 'a[data-testid^="vendor-tile-new-link-"]')
print(f"{len(cards)} restoran bulundu.\n")

# CSV file
filename = "../data/raw/links/beyoglu_links/beyoglu_waffle_restaurants.csv"
headers = [
    "vendor_id", "restaurant_name", "link", "img", "rating", "review_count",
    "price_range", "min_order", "cuisine_type",
    "delivery_time", "delivery_type"
]

with open(filename, "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(headers)

# Get the information from each restaurant card.
for i, card in enumerate(cards, 1):
    try:
        name = card.find_element(By.CSS_SELECTOR, "div.vendor-name").get_attribute("title")
        link = card.get_attribute("href")
        img = ""
        rating = ""
        review_count = ""
        price_range = ""
        min_order = ""
        cuisine_type = ""
        delivery_time = ""
        delivery_type = ""
        vendor_id = ""

        # Vendor ID
        try:
            match = re.search(r"/restaurant/([^/]+)/", link)
            if match:
                vendor_id = match.group(1)
        except:
            pass

        # Image
        try:
            img = card.find_element(By.CSS_SELECTOR, "img").get_attribute("src")
        except:
            pass

        # Rating and review
        try:
            rating = card.find_element(By.CSS_SELECTOR, ".bds-c-rating__label-primary").text
        except:
            pass
        try:
            review_count = card.find_element(By.CSS_SELECTOR, ".bds-c-rating__label-secondary").text
        except:
            pass

        # Information lines
        info_items = card.find_elements(By.CSS_SELECTOR, ".vendor-info-row-text .sanitized-row-text")
        if len(info_items) > 0:
            price_range = info_items[0].text if len(info_items) > 0 else ""
            min_order = info_items[1].text if len(info_items) > 1 else ""
            cuisine_type = info_items[2].text if len(info_items) > 2 else ""
            delivery_time = info_items[3].text if len(info_items) > 3 else ""
            delivery_type = info_items[4].text if len(info_items) > 4 else ""

        row = [
            vendor_id, name, link, img, rating, review_count,
            price_range, min_order, cuisine_type, delivery_time, delivery_type
        ]

        with open(filename, "a", newline="", encoding="utf-8") as f:
            writer = csv.writer(f)
            writer.writerow(row)

        print(f"[{i}/{len(cards)}] Kaydedildi: {name} ({vendor_id})")

    except Exception as e:
        print(f"Hata oluştu: {e}")

print(f"\n✅ Tüm {len(cards)} restoran bilgileri {filename} dosyasına kaydedildi.")
driver.quit()
# Out:
# Sayfa yüklendi, restoranlar toplanıyor...
# Sayfanın sonuna ulaşıldı ✅
# Tüm restoran kartları yüklendi, veriler çekiliyor...
# 18 restoran bulundu.
#
# [1/18] Kaydedildi: Ziyafet Tavuklu Pilav (at6y)
# [2/18] Kaydedildi: Chocolate Waffle (kvow)
# [3/18] Kaydedildi: Always Waffle (h177)
# [4/18] Kaydedildi: Wowmix (eu3g)
# [5/18] Kaydedildi: Pwb Peanut Waffle Belgium (mu9g)
# [6/18] Kaydedildi: Happy Waffle (r4f0)
# [7/18] Kaydedildi: Wafflecım 777 (xqsr)
# [8/18] Kaydedildi: Lale Waffle & Kumpir (zzsd)
# [9/18] Kaydedildi: Safiş Kumpir & Waffle (zzpu)
# [10/18] Kaydedildi: Crispy Waffle (ev51)
# [11/18] Kaydedildi: Bunny Waffle (si93)
# [12/18] Kaydedildi: Waffle House Special (kuvc)
# [13/18] Kaydedildi: One Sweet (wrj2)
# [14/18] Kaydedildi: A Love Waffle (rb2f)
# [15/18] Kaydedildi: Nuray Waffle (ofru)
# [16/18] Kaydedildi: Waffle Store (l0oq)
# [17/18] Kaydedildi: !Classo Dondurma & Waffle (byr7)
# [18/18] Kaydedildi: Granny's Waffles & Kumpir (kz3x)
#
# ✅ Tüm 18 restoran bilgileri ../data/raw/beyoglu_linkler/beyoglu_waffle_restoranlar.csv dosyasına kaydedildi.

# %% [markdown]
# Beşiktaş Links with vendor_id

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time
import csv
import re

# Chrome settings
chrome_options = Options()
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                            "AppleWebKit/537.36 (KHTML, like Gecko) "
                            "Chrome/127.0.0.0 Safari/537.36")
# chrome_options.add_argument("--headless")

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

url = "https://www.yemeksepeti.com/restaurants/new?lng=29.02681888623049&lat=41.068357160446595&vertical=restaurants&cuisines=1090"
driver.get(url)
time.sleep(7)

print("Sayfa yüklendi, restoranlar toplanıyor...")

# Scroll simulation
scroll_pause = 4
scroll_step = 1000
max_scrolls = 120

last_height = driver.execute_script("return document.body.scrollHeight")
scrolls_done = 0

while scrolls_done < max_scrolls:
    driver.execute_script(f"window.scrollBy(0, {scroll_step});")
    time.sleep(scroll_pause)
    new_height = driver.execute_script("return document.body.scrollHeight")

    if new_height == last_height:
        print("Sayfanın sonuna ulaşıldı ✅")
        break
    last_height = new_height
    scrolls_done += 1
    print(f"{scrolls_done}. scroll tamamlandı...")

print("Tüm restoran kartları yüklendi, veriler çekiliyor...")
time.sleep(2)

# Find restaurant cards
cards = driver.find_elements(By.CSS_SELECTOR, 'a[data-testid^="vendor-tile-new-link-"]')
print(f"{len(cards)} restoran bulundu.\n")

# CSV file
filename = "../data/raw/links/besiktas_links/besiktas_waffle_restaurants.csv"
headers = [
    "vendor_id", "restaurant_name", "link", "img", "rating", "review_count",
    "price_range", "min_order", "cuisine_type",
    "delivery_time", "delivery_type"
]

with open(filename, "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(headers)

# Get the information from each restaurant card.
for i, card in enumerate(cards, 1):
    try:
        name = card.find_element(By.CSS_SELECTOR, "div.vendor-name").get_attribute("title")
        link = card.get_attribute("href")
        img = ""
        rating = ""
        review_count = ""
        price_range = ""
        min_order = ""
        cuisine_type = ""
        delivery_time = ""
        delivery_type = ""
        vendor_id = ""

        # Vendor ID
        try:
            match = re.search(r"/restaurant/([^/]+)/", link)
            if match:
                vendor_id = match.group(1)
        except:
            pass

        # Image
        try:
            img = card.find_element(By.CSS_SELECTOR, "img").get_attribute("src")
        except:
            pass

        # Rating and review
        try:
            rating = card.find_element(By.CSS_SELECTOR, ".bds-c-rating__label-primary").text
        except:
            pass
        try:
            review_count = card.find_element(By.CSS_SELECTOR, ".bds-c-rating__label-secondary").text
        except:
            pass

        # Information lines
        info_items = card.find_elements(By.CSS_SELECTOR, ".vendor-info-row-text .sanitized-row-text")
        if len(info_items) > 0:
            price_range = info_items[0].text if len(info_items) > 0 else ""
            min_order = info_items[1].text if len(info_items) > 1 else ""
            cuisine_type = info_items[2].text if len(info_items) > 2 else ""
            delivery_time = info_items[3].text if len(info_items) > 3 else ""
            delivery_type = info_items[4].text if len(info_items) > 4 else ""

        row = [
            vendor_id, name, link, img, rating, review_count,
            price_range, min_order, cuisine_type, delivery_time, delivery_type
        ]

        with open(filename, "a", newline="", encoding="utf-8") as f:
            writer = csv.writer(f)
            writer.writerow(row)

        print(f"[{i}/{len(cards)}] Kaydedildi: {name} ({vendor_id})")

    except Exception as e:
        print(f"Hata oluştu: {e}")

print(f"\n✅ Tüm {len(cards)} restoran bilgileri {filename} dosyasına kaydedildi.")
driver.quit()
# Out:
# Sayfa yüklendi, restoranlar toplanıyor...
# Sayfanın sonuna ulaşıldı ✅
# Tüm restoran kartları yüklendi, veriler çekiliyor...
# 18 restoran bulundu.
#
# [1/18] Kaydedildi: Peanut Waffle Belgium (t00u)
# [2/18] Kaydedildi: Always Waffle (h177)
# [3/18] Kaydedildi: Always Waffle (n6eg)
# [4/18] Kaydedildi: Bebek Susam Waffle & Kumpir (sajr)
# [5/18] Kaydedildi: Kanyon Waffle (w4dx)
# [6/18] Kaydedildi: Granny's Waffles & Kumpir (ad13)
# [7/18] Kaydedildi: Bebek Susam Waffle & Kumpir (achj)
# [8/18] Kaydedildi: Crispy Waffle (ev51)
# [9/18] Kaydedildi: Anka Waffle (eo2f)
# [10/18] Kaydedildi: One Sweet (wrj2)
# [11/18] Kaydedildi: Asia Waffle (g1hb)
# [12/18] Kaydedildi: Favori Waffle (xixg)
# [13/18] Kaydedildi: Bunny Waffle (si93)
# [14/18] Kaydedildi: A Love Waffle (rb2f)
# [15/18] Kaydedildi: Etiler Waffle (afsl)
# [16/18] Kaydedildi: Balkon Waffle (u189)
# [17/18] Kaydedildi: Gossip Waffle (nua4)
# [18/18] Kaydedildi: Müpto Waffle (a99h)
#
# ✅ Tüm 18 restoran bilgileri ../data/raw/links/besiktas_linkler/besiktas_waffle_restoranlar.csv dosyasına kaydedildi.

# %% [markdown]
# merge links

# %%
import pandas as pd
import os

csv_files = [
    ("../data/raw/links/maltepe_links/maltepe_balik_restaurants.csv", "Maltepe"),
    ("../data/raw/links/maltepe_links/maltepe_burger_restaurants.csv", "Maltepe"),
    ("../data/raw/links/maltepe_links/maltepe_cigkofte_restaurants.csv", "Maltepe"),
    ("../data/raw/links/maltepe_links/maltepe_dondurma_restaurants.csv", "Maltepe"),
    ("../data/raw/links/maltepe_links/maltepe_doner_restaurants.csv", "Maltepe"),
    ("../data/raw/links/maltepe_links/maltepe_dunyamutfagi_restaurants.csv", "Maltepe"),
    ("../data/raw/links/maltepe_links/maltepe_evyemekleri_restaurants.csv", "Maltepe"),
    ("../data/raw/links/maltepe_links/maltepe_kahvalti_restaurants.csv", "Maltepe"),
    ("../data/raw/links/maltepe_links/maltepe_kahve_restaurants.csv", "Maltepe"),
    ("../data/raw/links/maltepe_links/maltepe_kebap_restaurants.csv", "Maltepe"),
    ("../data/raw/links/maltepe_links/maltepe_kofte_restaurants.csv", "Maltepe"),
    ("../data/raw/links/maltepe_links/maltepe_kokorec_restaurants.csv", "Maltepe"),
    ("../data/raw/links/maltepe_links/maltepe_kumpir_restaurants.csv", "Maltepe"),
    ("../data/raw/links/maltepe_links/maltepe_makarna_restaurants.csv", "Maltepe"),
    ("../data/raw/links/maltepe_links/maltepe_manti_restaurants.csv", "Maltepe"),
    ("../data/raw/links/maltepe_links/maltepe_meze_restaurants.csv", "Maltepe"),
    ("../data/raw/links/maltepe_links/maltepe_pastane_restaurants.csv", "Maltepe"),
    ("../data/raw/links/maltepe_links/maltepe_pide_restaurants.csv", "Maltepe"),
    ("../data/raw/links/maltepe_links/maltepe_pilav_restaurants.csv", "Maltepe"),
    ("../data/raw/links/maltepe_links/maltepe_pizza_restaurants.csv", "Maltepe"),
    ("../data/raw/links/maltepe_links/maltepe_salata_restaurants.csv", "Maltepe"),
    ("../data/raw/links/maltepe_links/maltepe_steak_restaurants.csv", "Maltepe"),
    ("../data/raw/links/maltepe_links/maltepe_tantuni_restaurants.csv", "Maltepe"),
    ("../data/raw/links/maltepe_links/maltepe_tatli_restaurants.csv", "Maltepe"),
    ("../data/raw/links/maltepe_links/maltepe_tavuk_restaurants.csv", "Maltepe"),
    ("../data/raw/links/maltepe_links/maltepe_tost_restaurants.csv", "Maltepe"),
    ("../data/raw/links/maltepe_links/maltepe_uzakdogu_restaurants.csv", "Maltepe"),
    ("../data/raw/links/maltepe_links/maltepe_vejetaryen_restaurants.csv", "Maltepe"),
    ("../data/raw/links/maltepe_links/maltepe_waffle_restaurants.csv", "Maltepe"),
    ("../data/raw/links/besiktas_links/besiktas_balik_restaurants.csv", "Beşiktaş"),
    ("../data/raw/links/besiktas_links/besiktas_burger_restaurants.csv", "Beşiktaş"),
    ("../data/raw/links/besiktas_links/besiktas_cigkofte_restaurants.csv", "Beşiktaş"),
    ("../data/raw/links/besiktas_links/besiktas_dondurma_restaurants.csv", "Beşiktaş"),
    ("../data/raw/links/besiktas_links/besiktas_doner_restaurants.csv", "Beşiktaş"),
    ("../data/raw/links/besiktas_links/besiktas_dunyamutfagi_restaurants.csv", "Beşiktaş"),
    ("../data/raw/links/besiktas_links/besiktas_evyemekleri_restaurants.csv", "Beşiktaş"),
    ("../data/raw/links/besiktas_links/besiktas_kahvalti_restaurants.csv", "Beşiktaş"),
    ("../data/raw/links/besiktas_links/besiktas_kahve_restaurants.csv", "Beşiktaş"),
    ("../data/raw/links/besiktas_links/besiktas_kebap_restaurants.csv", "Beşiktaş"),
    ("../data/raw/links/besiktas_links/besiktas_kofte_restaurants.csv", "Beşiktaş"),
    ("../data/raw/links/besiktas_links/besiktas_kokorec_restaurants.csv", "Beşiktaş"),
    ("../data/raw/links/besiktas_links/besiktas_kumpir_restaurants.csv", "Beşiktaş"),
    ("../data/raw/links/besiktas_links/besiktas_makarna_restaurants.csv", "Beşiktaş"),
    ("../data/raw/links/besiktas_links/besiktas_manti_restaurants.csv", "Beşiktaş"),
    ("../data/raw/links/besiktas_links/besiktas_meze_restaurants.csv", "Beşiktaş"),
    ("../data/raw/links/besiktas_links/besiktas_pastane_restaurants.csv", "Beşiktaş"),
    ("../data/raw/links/besiktas_links/besiktas_pide_restaurants.csv", "Beşiktaş"),
    ("../data/raw/links/besiktas_links/besiktas_pilav_restaurants.csv", "Beşiktaş"),
    ("../data/raw/links/besiktas_links/besiktas_pizza_restaurants.csv", "Beşiktaş"),
    ("../data/raw/links/besiktas_links/besiktas_salata_restaurants.csv", "Beşiktaş"),
    ("../data/raw/links/besiktas_links/besiktas_steak_restaurants.csv", "Beşiktaş"),
    ("../data/raw/links/besiktas_links/besiktas_tantuni_restaurants.csv", "Beşiktaş"),
    ("../data/raw/links/besiktas_links/besiktas_tatli_restaurants.csv", "Beşiktaş"),
    ("../data/raw/links/besiktas_links/besiktas_tavuk_restaurants.csv", "Beşiktaş"),
    ("../data/raw/links/besiktas_links/besiktas_tost_restaurants.csv", "Beşiktaş"),
    ("../data/raw/links/besiktas_links/besiktas_uzakdogu_restaurants.csv", "Beşiktaş"),
    ("../data/raw/links/besiktas_links/besiktas_vejetaryen_restaurants.csv", "Beşiktaş"),
    ("../data/raw/links/besiktas_links/besiktas_waffle_restaurants.csv", "Beşiktaş"),
    ("../data/raw/links/beyoglu_links/beyoglu_balik_restaurants.csv", "Beyoğlu"),
    ("../data/raw/links/beyoglu_links/beyoglu_burger_restaurants.csv", "Beyoğlu"),
    ("../data/raw/links/beyoglu_links/beyoglu_cigkofte_restaurants.csv", "Beyoğlu"),
    ("../data/raw/links/beyoglu_links/beyoglu_dondurma_restaurants.csv", "Beyoğlu"),
    ("../data/raw/links/beyoglu_links/beyoglu_doner_restaurants.csv", "Beyoğlu"),
    ("../data/raw/links/beyoglu_links/beyoglu_dunyamutfagi_restaurants.csv", "Beyoğlu"),
    ("../data/raw/links/beyoglu_links/beyoglu_evyemekleri_restaurants.csv", "Beyoğlu"),
    ("../data/raw/links/beyoglu_links/beyoglu_kahvalti_restaurants.csv", "Beyoğlu"),
    ("../data/raw/links/beyoglu_links/beyoglu_kahve_restaurants.csv", "Beyoğlu"),
    ("../data/raw/links/beyoglu_links/beyoglu_kebap_restaurants.csv", "Beyoğlu"),
    ("../data/raw/links/beyoglu_links/beyoglu_kofte_restaurants.csv", "Beyoğlu"),
    ("../data/raw/links/beyoglu_links/beyoglu_kokorec_restaurants.csv", "Beyoğlu"),
    ("../data/raw/links/beyoglu_links/beyoglu_kumpir_restaurants.csv", "Beyoğlu"),
    ("../data/raw/links/beyoglu_links/beyoglu_makarna_restaurants.csv", "Beyoğlu"),
    ("../data/raw/links/beyoglu_links/beyoglu_manti_restaurants.csv", "Beyoğlu"),
    ("../data/raw/links/beyoglu_links/beyoglu_meze_restaurants.csv", "Beyoğlu"),
    ("../data/raw/links/beyoglu_links/beyoglu_pastane_restaurants.csv", "Beyoğlu"),
    ("../data/raw/links/beyoglu_links/beyoglu_pide_restaurants.csv", "Beyoğlu"),
    ("../data/raw/links/beyoglu_links/beyoglu_pilav_restaurants.csv", "Beyoğlu"),
    ("../data/raw/links/beyoglu_links/beyoglu_pizza_restaurants.csv", "Beyoğlu"),
    ("../data/raw/links/beyoglu_links/beyoglu_salata_restaurants.csv", "Beyoğlu"),
    ("../data/raw/links/beyoglu_links/beyoglu_steak_restaurants.csv", "Beyoğlu"),
    ("../data/raw/links/beyoglu_links/beyoglu_tantuni_restaurants.csv", "Beyoğlu"),
    ("../data/raw/links/beyoglu_links/beyoglu_tatli_restaurants.csv", "Beyoğlu"),
    ("../data/raw/links/beyoglu_links/beyoglu_tavuk_restaurants.csv", "Beyoğlu"),
    ("../data/raw/links/beyoglu_links/beyoglu_tost_restaurants.csv", "Beyoğlu"),
    ("../data/raw/links/beyoglu_links/beyoglu_uzakdogu_restaurants.csv", "Beyoğlu"),
    ("../data/raw/links/beyoglu_links/beyoglu_vejetaryen_restaurants.csv", "Beyoğlu"),
    ("../data/raw/links/beyoglu_links/beyoglu_waffle_restaurants.csv", "Beyoğlu")
]

dfs = []
for file, district in csv_files:
    if os.path.exists(file):
        df = pd.read_csv(file)
        df['District'] = district  
        dfs.append(df)
    else:
        print(f"Dosya bulunamadı: {file}")

merged = pd.concat(dfs, ignore_index=True)

merged.to_csv("../data/raw/restaurant_links.csv", index=False, encoding="utf-8")

print("✅ Dosyalar başarıyla birleştirildi -> restaurant_links.csv")
# Out:
# ✅ Dosyalar başarıyla birleştirildi -> restaurant_links.csv

# %% [markdown]
# collecting comments

# %%
# comments from low to high ratings
import pandas as pd
import requests
import csv
import time
import random
import os
import urllib.parse

INPUT_CSV = "../data/raw/links/restaurant_links.csv"
OUTPUT_CSV = "../data/raw/reviews/comments_from_low_to_high_ratings.csv"

df = pd.read_csv(INPUT_CSV)

# Restaurant columns in CSV
restaurant_columns = df.columns.tolist()

# New columns for reviews
restaurant_columns_extended = (
    restaurant_columns
    + ["restaurant_slug"]
)

review_columns = [
    "uuid", "reviewer_name", "reviewer_id",
    "overall_score", "restaurant_food_score", "rider_score",
    "text", "created_at", "like_count", "replies_count", "product_names"
]

# Header
if not os.path.exists(OUTPUT_CSV):
    with open(OUTPUT_CSV, "w", newline="", encoding="utf-8-sig") as f:
        writer = csv.writer(f)
        writer.writerow(restaurant_columns_extended + review_columns)

records = df.to_dict(orient="records")

for i, restaurant in enumerate(records, 1):
    link = restaurant["link"]

    try:
        # Slug name from the link
        parts = link.strip("/").split("/")
        if "restaurant" in parts:
            idx = parts.index("restaurant")
            vendor_id = parts[idx + 1]
            restaurant_slug = parts[idx + 2]
        else:
            vendor_id = parts[-2]
            restaurant_slug = parts[-1]

        # The Turkish name in the CSV file is PRESERVED.
        restaurant["restaurant_slug"] = restaurant_slug
        restaurant["vendor_id"] = vendor_id  

        restaurant_name_tr = restaurant.get("restaurant_name", "")
        print(f"\n[{i}/{len(records)}] {restaurant_name_tr} ({restaurant_slug})")

        next_page = None

        while True:
            url = (
                f"https://reviews-api-tr.fd-api.com/reviews/vendor/{vendor_id}"
                f"?global_entity_id=YS_TR&limit=50&rating=asc&has_dish=true"
            )

            if next_page:
                url += f"&nextPageKey={urllib.parse.quote(next_page)}"

            r = requests.get(url, timeout=15)
            if r.status_code != 200:
                break

            data = r.json()
            reviews = data.get("data", [])
            if not reviews:
                break

            with open(OUTPUT_CSV, "a", newline="", encoding="utf-8-sig") as f:
                writer = csv.writer(f)

                for rev in reviews:
                    row_review = {
                        "uuid": rev.get("uuid", ""),
                        "reviewer_name": rev.get("reviewerName", ""),
                        "reviewer_id": rev.get("reviewerId", ""),
                        "text": rev.get("text", ""),
                        "created_at": rev.get("createdAt", ""),
                        "like_count": rev.get("likeCount", 0),
                        "replies_count": len(rev.get("replies", [])),
                        "overall_score": "",
                        "restaurant_food_score": "",
                        "rider_score": "",
                        "product_names": ""
                    }

                    for rr in rev.get("ratings", []):
                        topic = rr.get("topic", "").lower()
                        if topic == "overall":
                            row_review["overall_score"] = rr.get("score", "")
                        elif topic == "restaurant_food":
                            row_review["restaurant_food_score"] = rr.get("score", "")
                        elif topic == "rider":
                            row_review["rider_score"] = rr.get("score", "")

                    products = []
                    for p in rev.get("productVariations", []) or []:
                        prod = p.get("product", {})
                        name = prod.get("defaultTitle", "")
                        if name:
                            products.append(name)

                    row_review["product_names"] = " | ".join(products)

                    writer.writerow(
                        [restaurant[col] for col in restaurant_columns] +
                        [restaurant["restaurant_slug"]] +
                        [row_review[col] for col in review_columns]
                    )

            next_page = data.get("nextPageKey")
            if not next_page:
                break

            time.sleep(random.uniform(3, 6))

        print(f"✔ {restaurant_name_tr}")

    except Exception as e:
        print("⚠ Hata:", e)
        time.sleep(5)
        continue

print("✅ TÜM RESTORANLAR TAMAMLANDI!")
# Out:
# [1/2165] Mis Balık Restaurant (mis-balik-restaurant)
# ✔ Mis Balık Restaurant tamamlandı
#
# [2/2165] İstanbul Çiğ Köfte (istanbul-cig-kofte-p9zl)
# ✔ İstanbul Çiğ Köfte tamamlandı
#
# [3/2165] Çınar Balık Izgara (cinar-balik-izgara)
# ✔ Çınar Balık Izgara tamamlandı
#
# [4/2165] Karadeniz Balık Lokantası (karadeniz-balik-lokantasi-lhwv)
# ✔ Karadeniz Balık Lokantası tamamlandı
#
# [5/2165] Küçükyalı Balıkçısı (kucukyali-balikcisi-tgvo)
# ✔ Küçükyalı Balıkçısı tamamlandı
#
# [6/2165] Hepsi Meze & Sandviç Küçükyalı (hepsi-meze-and-sandvic-kucukyali)
# ✔ Hepsi Meze & Sandviç Küçükyalı tamamlandı
#
# [7/2165] Balıkçı Selami (balikci-selami-znjl)
# ✔ Balıkçı Selami tamamlandı
#
# [8/2165] Mavi Kıyı Balıkçısı (mavi-kiyi-balikcisi)
# ✔ Mavi Kıyı Balıkçısı tamamlandı
#
# [9/2165] Urla Balıkçısı (urla-balikcisi-t360)
# ✔ Urla Balıkçısı tamamlandı
#
# [10/2165] İstanbul Midye (istanbul-midye-nnt1)
# ✔ İstanbul Midye tamamlandı
#
# [11/2165] Maltepe Şırdancısı (maltepe-sirdancisi)
# ✔ Maltepe Şırdancısı tamamlandı
#
# [12/2165] Es Balık Evi (es-balik-evi)
# ✔ Es Balık Evi tamamlandı
#
# [13/2165] İnci Balık (inci-balik-l1fg)
# ✔ İnci Balık tamamlandı
#
# [14/2165] Adanalı Serra Dürüm (adanali-serra-durum)
# ✔ Adanalı Serra Dürüm tamamlandı
#
# [15/2165] Reşat Balık (resat-balik)
# ✔ Reşat Balık tamamlandı
#
# [16/2165] Ken Sushi And More (ken-sushi-and-more)
# ✔ Ken Sushi And More tamamlandı
#
# [17/2165] Balıkçı İrfan (balikci-irfan)
# ✔ Balıkçı İrfan tamamlandı
#
# [18/2165] Dardenia Fish & Sushi (dardenia-fish-and-sushi-h3yt)
# ✔ Dardenia Fish & Sushi tamamlandı
#
# [19/2165] Midyeci Yasin (midyeci-yasin-r0l2)
# ✔ Midyeci Yasin tamamlandı
#
# [20/2165] Alkar Balık Izgara (alkar-balik-izgara-ximy)
# ✔ Alkar Balık Izgara tamamlandı
#
# [21/2165] Tuzda Balık (tuzda-balik)
# ✔ Tuzda Balık tamamlandı
#
# [22/2165] Fırtına Balık (firtina-balik)
# ✔ Fırtına Balık tamamlandı
#
# [23/2165] Burger King (burger-king-nki0)
# ✔ Burger King tamamlandı
#
# [24/2165] Frango Döner (frango-doner-yozu)
# ✔ Frango Döner tamamlandı
#
# [25/2165] Arden Fried Chicken (arden-fried-chicken-mpwq)
# ✔ Arden Fried Chicken tamamlandı
#
# [26/2165] Gurme Chefs Köz (gurme-chefs-koz)
# ✔ Gurme Chefs Köz tamamlandı
#
# [27/2165] Carl's Jr. (carls-jr-f2h5)
# ✔ Carl's Jr. tamamlandı
#
# [28/2165] Fried-Day Chicken (fried-day-chicken-nmdl)
# ✔ Fried-Day Chicken tamamlandı
#
# [29/2165] Express Marmaris (express-marmaris)
# ✔ Express Marmaris tamamlandı
#
# [30/2165] Burger Yiyelim (burger-yiyelim-ltaq)
# ✔ Burger Yiyelim tamamlandı
#
# [31/2165] Mambos Burger (mambos-burger)
# ✔ Mambos Burger tamamlandı
#
# [32/2165] Pattosan (pattosan)
# ✔ Pattosan tamamlandı
#
# [33/2165] Burger Space (burger-space-qruc)
# ✔ Burger Space tamamlandı
#
# [34/2165] James Burger (james-burger)
# ✔ James Burger tamamlandı
#
# [35/2165] Saloon Burger (saloon-burger-qjfq)
# ✔ Saloon Burger tamamlandı
#
# [36/2165] McDonald's (mcdonalds-q88l)
# ✔ McDonald's tamamlandı
#
# [37/2165] Cantina Prime (cantina-prime)
# ✔ Cantina Prime tamamlandı
#
# [38/2165] My Fried Chicken (my-fried-chicken-q4vq)
# ✔ My Fried Chicken tamamlandı
#
# [39/2165] Hakan Büfe & Burger (hakan-bufe-and-burger)
# ✔ Hakan Büfe & Burger tamamlandı
#
# [40/2165] Tavuk Dürüm Sofrası (tavuk-durum-sofrasi-z3gs)
# ✔ Tavuk Dürüm Sofrası tamamlandı
#
# [41/2165] Cajun Corner (cajun-corner-euzr)
# ✔ Cajun Corner tamamlandı
#
# [42/2165] Domino's Pizza (dominos-pizza-i8et)
# ✔ Domino's Pizza tamamlandı
#
# [43/2165] Arby's (arbys-x24z)
# ✔ Arby's tamamlandı
#
# [44/2165] Big Lou Burger (big-lou-burger)
# ✔ Big Lou Burger tamamlandı
#
# [45/2165] Smash Burger B (smash-burger-b-z1hq)
# ✔ Smash Burger B tamamlandı
#
# [46/2165] +1 Burger (1-burger-qa17)
# ✔ +1 Burger tamamlandı
#
# [47/2165] Why Burger (why-burger)
# ✔ Why Burger tamamlandı
#
# [48/2165] Three Monkeys (three-monkeys-hbq5)
# ✔ Three Monkeys tamamlandı
#
# [49/2165] Daily Dana Burger & Steak (daily-dana-burger-and-steak-g671)
# ✔ Daily Dana Burger & Steak tamamlandı
#
# [50/2165] Tek Büfe (tek-bufe-j6gm)
# ✔ Tek Büfe tamamlandı
#
# [51/2165] Arjantin Burger (arjantin-burger-es06)
# ✔ Arjantin Burger tamamlandı
#
# [52/2165] Burgerillas (burgerillas-l75d)
# ✔ Burgerillas tamamlandı
#
# [53/2165] Coff's Cafe & Restaurant (coffs-cafe-and-restaurant)
# ✔ Coff's Cafe & Restaurant tamamlandı
#
# [54/2165] Bro's Burger (bros-burger-jjcb)
# ✔ Bro's Burger tamamlandı
#
# [55/2165] Hebe Burger (hebe-burger)
# ✔ Hebe Burger tamamlandı
#
# [56/2165] Burger House (burger-house-f4zz)
# ✔ Burger House tamamlandı
#
# [57/2165] Big Baker (big-baker-mcat)
# ✔ Big Baker tamamlandı
#
# [58/2165] Meat Burger & Gurme Mutfak (meat-burger-and-gurme-mutfak-iusl)
# ✔ Meat Burger & Gurme Mutfak tamamlandı
#
# [59/2165] Öztürkler Büfe (ozturkler-bufe)
# ✔ Öztürkler Büfe tamamlandı
#
# [60/2165] Base Burger (base-burger)
# ✔ Base Burger tamamlandı
#
# [61/2165] Tıka Basa (tika-basa-cm82)
# ✔ Tıka Basa tamamlandı
#
# [62/2165] Maris Food (maris-food)
# ✔ Maris Food tamamlandı
#
# [63/2165] Yess Burger (yess-burger)
# ✔ Yess Burger tamamlandı
#
# [64/2165] Santiago Burger (santiago-burger-f8i4)
# ✔ Santiago Burger tamamlandı
#
# [65/2165] Santiago Burger (santiago-burger-bhje)
# ✔ Santiago Burger tamamlandı
#
# [66/2165] Retro Burger & Salad & Dessert (retro-burger-and-salad-and-dessert)
# ✔ Retro Burger & Salad & Dessert tamamlandı
#
# [67/2165] Tost Akademisi (tost-akademisi-upmd)
# ✔ Tost Akademisi tamamlandı
#
# [68/2165] Texas Fried Chicken (texas-fried-chicken-yxha)
# ✔ Texas Fried Chicken tamamlandı
#
# [69/2165] Vegas Burger (vegas-burger-zxiv)
# ✔ Vegas Burger tamamlandı
#
# [70/2165] Packet Burger (packet-burger-ne7b)
# ✔ Packet Burger tamamlandı
#
# [71/2165] Dükkan Büfe (dukkan-bufe)
# ✔ Dükkan Büfe tamamlandı
#
# [72/2165] White Burger by Serhat Doğramacı (white-burger-by-serhat-dogramaci-es2c)
# ✔ White Burger by Serhat Doğramacı tamamlandı
#
# [73/2165] Komagene Etsiz Çiğ Köfte (komagene-etsiz-cig-kofte-sh4q)
# ✔ Komagene Etsiz Çiğ Köfte tamamlandı
#
# [74/2165] Klikya Çiğ Köfte (klikya-cig-kofte)
# ✔ Klikya Çiğ Köfte tamamlandı
#
# [75/2165] Gazi Çiğ Köfte (gazi-cig-kofte-bltx)
# ✔ Gazi Çiğ Köfte tamamlandı
#
# [76/2165] Meşhur Adıyaman Çiğ Köftecisi Ömer Aybak (meshur-adiyaman-cig-koftecisi-omer-aybak-tr3t)
# ✔ Meşhur Adıyaman Çiğ Köftecisi Ömer Aybak tamamlandı
#
# [77/2165] Çiğ Köfteci Ömer Usta (cig-kofteci-omer-usta-mr8d)
# ✔ Çiğ Köfteci Ömer Usta tamamlandı
#
# [78/2165] İstanbul Çiğ Köfte (istanbul-cig-kofte-p9zl)
# ✔ İstanbul Çiğ Köfte tamamlandı
#
# [79/2165] Arsamiea Çiğ Köfte (arsamiea-cig-kofte-p19t)
# ✔ Arsamiea Çiğ Köfte tamamlandı
#
# [80/2165] Oses Çiğ Köfte (oses-cig-kofte-krf9)
# ✔ Oses Çiğ Köfte tamamlandı
#
# [81/2165] Çiğ Köfteci Ömer Usta (cig-kofteci-omer-usta-c10a)
# ✔ Çiğ Köfteci Ömer Usta tamamlandı
#
# [82/2165] Piro El Yapımı Çiğ Köfte (piro-el-yapimi-cig-kofte-dnr6)
# ✔ Piro El Yapımı Çiğ Köfte tamamlandı
#
# [83/2165] Adıyaman Çiğ Köftecisi (adiyaman-cig-koftecisi-ptug)
# ✔ Adıyaman Çiğ Köftecisi tamamlandı
#
# [84/2165] Konyataş (konyatas-azlx)
# ✔ Konyataş tamamlandı
#
# [85/2165] Kahta Çiğ Köfte (kahta-cig-kofte-yrw3)
# ✔ Kahta Çiğ Köfte tamamlandı
#
# [86/2165] Arsamiea (arsamiea-jh0i)
# ✔ Arsamiea tamamlandı
#
# [87/2165] Hepsi Meze & Sandviç Küçükyalı (hepsi-meze-and-sandvic-kucukyali)
# ✔ Hepsi Meze & Sandviç Küçükyalı tamamlandı
#
# [88/2165] Meşhur Adıyaman Çiğ Köftecisi (meshur-adiyaman-cig-koftecisi-awrh)
# ✔ Meşhur Adıyaman Çiğ Köftecisi tamamlandı
#
# [89/2165] Buhara Pide & Lahmacun (buhara-pide-and-lahmacun)
# ✔ Buhara Pide & Lahmacun tamamlandı
#
# [90/2165] Meşhur Çiğ Köfteci Ömür Usta (meshur-cig-kofteci-omur-usta)
# ✔ Meşhur Çiğ Köfteci Ömür Usta tamamlandı
#
# [91/2165] Ziyafet Çiğ Köfte (ziyafet-cig-kofte-i2ki)
# ✔ Ziyafet Çiğ Köfte tamamlandı
#
# [92/2165] Mr. Çiğ Köfte (mr-cig-kofte-u662)
# ✔ Mr. Çiğ Köfte tamamlandı
#
# [93/2165] Köfteci Elifin Mutfağı (kofteci-elifin-mutfagi)
# ✔ Köfteci Elifin Mutfağı tamamlandı
#
# [94/2165] Sepet Fast Food (sepet-fast-food)
# ✔ Sepet Fast Food tamamlandı
#
# [95/2165] Çiğ Köfteci Aziz Usta (cig-kofteci-aziz-usta-pce9)
# ✔ Çiğ Köfteci Aziz Usta tamamlandı
#
# [96/2165] Umur Çiğ Köfte (umur-cig-kofte)
# ✔ Umur Çiğ Köfte tamamlandı
#
# [97/2165] Çiğköftem (cigkoftem-lkmh)
# ✔ Çiğköftem tamamlandı
#
# [98/2165] Mr. Çiğ Köfte (mr-cig-kofte-owpb)
# ✔ Mr. Çiğ Köfte tamamlandı
#
# [99/2165] İsot Lab Çiğ Köfte (isot-lab-cig-kofte)
# ✔ İsot Lab Çiğ Köfte tamamlandı
#
# [100/2165] Sırrı Usta Çiğ Köfte (sirri-usta-cig-kofte-ou7w)
# ✔ Sırrı Usta Çiğ Köfte tamamlandı
#
# [101/2165] Adıger Çiğköfte (adiger-cigkofte)
# ✔ Adıger Çiğköfte tamamlandı
#
# [102/2165] Zarif Çiğ Köfte (zarif-cig-kofte-r5mo)
# ✔ Zarif Çiğ Köfte tamamlandı
#
# [103/2165] Arsamiea Çiğ Köfte (arsamiea-cig-kofte-d9oi)
# ✔ Arsamiea Çiğ Köfte tamamlandı
#
# [104/2165] Sırrı Usta Çiğ Köfte (sirri-usta-cig-kofte-fwpj)
# ✔ Sırrı Usta Çiğ Köfte tamamlandı
#
# [105/2165] Tatlıses Çiğ Köfte (tatlises-cig-kofte-r2t1)
# ✔ Tatlıses Çiğ Köfte tamamlandı
#
# [106/2165] Pide İstanbul (pide-istanbul)
# ✔ Pide İstanbul tamamlandı
#
# [107/2165] Pilav Gurmesi (pilav-gurmesi)
# ✔ Pilav Gurmesi tamamlandı
#
# [108/2165] Köz Biber Kebap & Lahmacun & Pide (koz-biber-kebap-and-lahmacun-and-pide-qqgl)
# ✔ Köz Biber Kebap & Lahmacun & Pide tamamlandı
#
# [109/2165] Meşhur Adıyaman Çiğ Köftecisi (meshur-adiyaman-cig-koftecisi-k4cb)
# ✔ Meşhur Adıyaman Çiğ Köftecisi tamamlandı
#
# [110/2165] Köfteca Doğal Çiğ Köfte (kofteca-dogal-cig-kofte)
# ✔ Köfteca Doğal Çiğ Köfte tamamlandı
#
# [111/2165] Köfte Uzmanı (kofte-uzmani)
# ✔ Köfte Uzmanı tamamlandı
#
# [112/2165] Biberzade Çiğ Köfte (biberzade-cig-kofte-qx9p)
# ✔ Biberzade Çiğ Köfte tamamlandı
#
# [113/2165] Meşhur Adıyamanlı Çiğ Köfteci Canan Şef (meshur-adiyamanli-cig-kofteci-canan-sef)
# ✔ Meşhur Adıyamanlı Çiğ Köfteci Canan Şef tamamlandı
#
# [114/2165] Ustam Çiğ Köfte (ustam-cig-kofte-unb6)
# ✔ Ustam Çiğ Köfte tamamlandı
#
# [115/2165] Ustam Çiğ Köfte (ustam-cig-kofte-j2t5)
# ✔ Ustam Çiğ Köfte tamamlandı
#
# [116/2165] Çiğ Köfteci Sait (cig-kofteci-sait-c415)
# ✔ Çiğ Köfteci Sait tamamlandı
#
# [117/2165] THE ANGRY CHEF (the-angry-chef)
# ✔ THE ANGRY CHEF tamamlandı
#
# [118/2165] Berat Çiğ Köfte (berat-cig-kofte-ybkl)
# ✔ Berat Çiğ Köfte tamamlandı
#
# [119/2165] Çiğ Köfteci Ömer Usta Cevizli (cig-kofteci-omer-usta-cevizli)
# ✔ Çiğ Köfteci Ömer Usta Cevizli tamamlandı
#
# [120/2165] Çiğ Köfteci Ömer Usta (cig-kofteci-omer-usta-m297)
# ✔ Çiğ Köfteci Ömer Usta tamamlandı
#
# [121/2165] Çiğ Köfteci Sait (cig-kofteci-sait-sx4i)
# ✔ Çiğ Köfteci Sait tamamlandı
#
# [122/2165] Bolulu Hasan Usta (bolulu-hasan-usta-agsz)
# ✔ Bolulu Hasan Usta tamamlandı
#
# [123/2165] +1 Sandviç (1-sandvic-nz79)
# ✔ +1 Sandviç tamamlandı
#
# [124/2165] Fıştık (fistik)
# ✔ Fıştık tamamlandı
#
# [125/2165] Cremeria Milano (cremeria-milano-zirh)
# ✔ Cremeria Milano tamamlandı
#
# [126/2165] Mado (mado-comb)
# ✔ Mado tamamlandı
#
# [127/2165] Mua Gelatieri D'Italia (mua-gelatieri-ditalia-mfcz)
# ✔ Mua Gelatieri D'Italia tamamlandı
#
# [128/2165] Serez Dondurmacısı Maltepe (serez-dondurmacisi-maltepe)
# ✔ Serez Dondurmacısı Maltepe tamamlandı
#
# [129/2165] Baklavacı Güllüoğlu (baklavaci-gulluoglu-gzwu)
# ✔ Baklavacı Güllüoğlu tamamlandı
#
# [130/2165] Vero Gelato Bostancı (vero-gelato-bostanci)
# ✔ Vero Gelato Bostancı tamamlandı
#
# [131/2165] Serbele Meze (serbele-meze-r31o)
# ✔ Serbele Meze tamamlandı
#
# [132/2165] Meşhur Gaziantep Baklavacısı Vakıf Usta (meshur-gaziantep-baklavacisi-vakif-usta)
# ✔ Meşhur Gaziantep Baklavacısı Vakıf Usta tamamlandı
#
# [133/2165] Lu Gelato Bostancı (lu-gelato-bostanci)
# ✔ Lu Gelato Bostancı tamamlandı
#
# [134/2165] Pan Dolce Gelato & Coffee (pan-dolce-gelato-and-coffee)
# ✔ Pan Dolce Gelato & Coffee tamamlandı
#
# [135/2165] Meşhur Gaziantep Baklavacısı Mehmet Usta (meshur-gaziantep-baklavacisi-mehmet-usta)
# ✔ Meşhur Gaziantep Baklavacısı Mehmet Usta tamamlandı
#
# [136/2165] Fıstıkzade Baklava & Tatlı (fistikzade-baklava-and-tatli)
# ✔ Fıstıkzade Baklava & Tatlı tamamlandı
#
# [137/2165] Asiloğlu Baklava (asiloglu-baklava)
# ✔ Asiloğlu Baklava tamamlandı
#
# [138/2165] Dondurmacı Güllüoğlu (dondurmaci-gulluoglu)
# ✔ Dondurmacı Güllüoğlu tamamlandı
#
# [139/2165] Vardarlı Dondurma (vardarli-dondurma)
# ✔ Vardarlı Dondurma tamamlandı
#
# [140/2165] Zarifzade Baklava (zarifzade-baklava)
# ✔ Zarifzade Baklava tamamlandı
#
# [141/2165] Çınar Dondurma (cinar-dondurma-ofix)
# ✔ Çınar Dondurma tamamlandı
#
# [142/2165] Hacıbey Tatlıcılık (hacibey-tatlicilik-mmh8)
# ✔ Hacıbey Tatlıcılık tamamlandı
#
# [143/2165] Blue Ice Cream (blue-ice-cream-qlzs)
# ✔ Blue Ice Cream tamamlandı
#
# [144/2165] Acil Dondurma (acil-dondurma)
# ✔ Acil Dondurma tamamlandı
#
# [145/2165] Lucio Gelato (lucio-gelato)
# ✔ Lucio Gelato tamamlandı
#
# [146/2165] Yaşar Usta Sorbe Dondurma (yasar-usta-sorbe-dondurma)
# ✔ Yaşar Usta Sorbe Dondurma tamamlandı
#
# [147/2165] Etod Kumpir & Waffle & Dondurma (etod-kumpir-and-waffle-and-dondurma-cypw)
# ✔ Etod Kumpir & Waffle & Dondurma tamamlandı
#
# [148/2165] Gülün Dondurma Dünyası Yaşar Usta (gulun-dondurma-dunyasi-yasar-usta)
# ✔ Gülün Dondurma Dünyası Yaşar Usta tamamlandı
#
# [149/2165] Nido Maraş Dondurma (nido-maras-dondurma)
# ✔ Nido Maraş Dondurma tamamlandı
#
# [150/2165] Nido Maraş Dondurma (nido-maras-dondurma-k1up)
# ✔ Nido Maraş Dondurma tamamlandı
#
# [151/2165] İkram Dondurma (ikram-dondurma-v6j8)
# ✔ İkram Dondurma tamamlandı
#
# [152/2165] Hayri Usta Maraş Dondurma (hayri-usta-maras-dondurma)
# ✔ Hayri Usta Maraş Dondurma tamamlandı
#
# [153/2165] Hacıbaşar Kebap & Baklava (hacibasar-kebap-and-baklava-e8wi)
# ✔ Hacıbaşar Kebap & Baklava tamamlandı
#
# [154/2165] Starhan Pide & Döner (starhan-pide-and-doner)
# ✔ Starhan Pide & Döner tamamlandı
#
# [155/2165] Dönerci Celal Usta (donerci-celal-usta-iqvo)
# ✔ Dönerci Celal Usta tamamlandı
#
# [156/2165] Aboo Dürümcü Mahmut Usta (aboo-durumcu-mahmut-usta)
# ✔ Aboo Dürümcü Mahmut Usta tamamlandı
#
# [157/2165] Çeltik Kebap & Lahmacun (celtik-kebap-and-lahmacun-ow5z)
# ✔ Çeltik Kebap & Lahmacun tamamlandı
#
# [158/2165] As İskender Kebap (as-iskender-kebap)
# ✔ As İskender Kebap tamamlandı
#
# [159/2165] Hatay Soslu Dürüm Evi (hatay-soslu-durum-evi-ynf3)
# ✔ Hatay Soslu Dürüm Evi tamamlandı
#
# [160/2165] Maydonoz Döner (maydonoz-doner-u6xi)
# ✔ Maydonoz Döner tamamlandı
#
# [161/2165] Tavukoloji (tavukoloji-udag)
# ✔ Tavukoloji tamamlandı
#
# [162/2165] Kebo (kebo-twui)
# ✔ Kebo tamamlandı
#
# [163/2165] Express Marmaris (express-marmaris)
# ✔ Express Marmaris tamamlandı
#
# [164/2165] Hatto Döner (hatto-doner)
# ✔ Hatto Döner tamamlandı
#
# [165/2165] Paşa Döner (pasa-doner-ski6)
# ✔ Paşa Döner tamamlandı
#
# [166/2165] By Hatay Döner Dürüm (by-hatay-doner-durum)
# ✔ By Hatay Döner Dürüm tamamlandı
#
# [167/2165] Kaplan Kebap(Zümrütevler) (kaplan-kebap-zumrutevler)
# ✔ Kaplan Kebap(Zümrütevler) tamamlandı
#
# [168/2165] Döner Ustası Çetin Yalçın (doner-ustasi-cetin-yalcin-x2ot)
# ✔ Döner Ustası Çetin Yalçın tamamlandı
#
# [169/2165] Öncü Döner (oncu-doner-gkfx)
# ✔ Öncü Döner tamamlandı
#
# [170/2165] Tavuk Dürüm Sofrası (tavuk-durum-sofrasi-z3gs)
# ✔ Tavuk Dürüm Sofrası tamamlandı
#
# [171/2165] HD İskender (hd-iskender-cp0c)
# ✔ HD İskender tamamlandı
#
# [172/2165] Dürüm Max (durum-max-pe8k)
# ✔ Dürüm Max tamamlandı
#
# [173/2165] Usta Dönerci (usta-donerci-xvp0)
# ✔ Usta Dönerci tamamlandı
#
# [174/2165] Tek Büfe (tek-bufe-j6gm)
# ✔ Tek Büfe tamamlandı
#
# [175/2165] Maltepe Zurna Dürüm (maltepe-zurna-durum)
# ✔ Maltepe Zurna Dürüm tamamlandı
#
# [176/2165] Kardeşler Zurna Dürüm (kardesler-zurna-durum-e55n)
# ✔ Kardeşler Zurna Dürüm tamamlandı
#
# [177/2165] İntiba Döner (intiba-doner-zlvo)
# ✔ İntiba Döner tamamlandı
#
# [178/2165] Tarihi Demirci Döner Lokantası (tarihi-demirci-doner-lokantasi-n0t0)
# ✔ Tarihi Demirci Döner Lokantası tamamlandı
#
# [179/2165] Hot Döner (hot-doner-xggd)
# ✔ Hot Döner tamamlandı
#
# [180/2165] Frango Döner & Sauce (frango-doner-and-sauce-tay4)
# ✔ Frango Döner & Sauce tamamlandı
#
# [181/2165] Yeniyo Döner (yeniyo-doner-fhtv)
# ✔ Yeniyo Döner tamamlandı
#
# [182/2165] Deha Dürüm (deha-durum)
# ✔ Deha Dürüm tamamlandı
#
# [183/2165] Kardeşim Zurna Dürüm (kardesim-zurna-durum-xzg9)
# ✔ Kardeşim Zurna Dürüm tamamlandı
#
# [184/2165] Tek Büfe (tek-bufe-aspq)
# ✔ Tek Büfe tamamlandı
#
# [185/2165] Bereket Döner (bereket-doner-i1x6)
# ✔ Bereket Döner tamamlandı
#
# [186/2165] Şehzade Katık Dürüm (sehzade-katik-durum)
# ✔ Şehzade Katık Dürüm tamamlandı
#
# [187/2165] Bursa İshakbey (bursa-ishakbey-xsy7)
# ✔ Bursa İshakbey tamamlandı
#
# [188/2165] Deran Usta Hatay Döner (deran-usta-hatay-doner)
# ✔ Deran Usta Hatay Döner tamamlandı
#
# [189/2165] Hatay Soslu Döner Evi (hatay-soslu-doner-evi)
# ✔ Hatay Soslu Döner Evi tamamlandı
#
# [190/2165] Dönerci Ali Usta (donerci-ali-usta-gjrh)
# ✔ Dönerci Ali Usta tamamlandı
#
# [191/2165] Kaplan Kebap (Küçükyalı) (kaplan-kebap-kucukyali)
# ✔ Kaplan Kebap (Küçükyalı) tamamlandı
#
# [192/2165] Hacıoğlu (hacioglu-vj7e)
# ✔ Hacıoğlu tamamlandı
#
# [193/2165] Tat Kebap (tat-kebap-t66e)
# ✔ Tat Kebap tamamlandı
#
# [194/2165] Gülüm Döner & Lahmacun (gulum-doner-and-lahmacun)
# ✔ Gülüm Döner & Lahmacun tamamlandı
#
# [195/2165] Özel Soslu Hatay Döneri (ozel-soslu-hatay-doneri)
# ✔ Özel Soslu Hatay Döneri tamamlandı
#
# [196/2165] Baydöner İskender (baydoner-iskender-kwbl)
# ✔ Baydöner İskender tamamlandı
#
# [197/2165] Karınca Kebap (karinca-kebap)
# ✔ Karınca Kebap tamamlandı
#
# [198/2165] By Hatay Döner (by-hatay-doner-rzm7)
# ✔ By Hatay Döner tamamlandı
#
# [199/2165] Dürüm Max (durum-max-rnwp)
# ✔ Dürüm Max tamamlandı
#
# [200/2165] Akan Zurna & Döner (akan-zurna-and-doner)
# ✔ Akan Zurna & Döner tamamlandı
#
# [201/2165] Acaip Soslu Döner (acaip-soslu-doner)
# ✔ Acaip Soslu Döner tamamlandı
#
# [202/2165] Hatay Usulü Zurna Dürüm (hatay-usulu-zurna-durum-h8e3)
# ✔ Hatay Usulü Zurna Dürüm tamamlandı
#
# [203/2165] Cajun Corner (cajun-corner-euzr)
# ✔ Cajun Corner tamamlandı
#
# [204/2165] Tavuk Fakültesi (tavuk-fakultesi-o65k)
# ✔ Tavuk Fakültesi tamamlandı
#
# [205/2165] Tavuk Dünyası (tavuk-dunyasi-hl5v)
# ✔ Tavuk Dünyası tamamlandı
#
# [206/2165] Garden Gurme (garden-gurme)
# ✔ Garden Gurme tamamlandı
#
# [207/2165] Green Salads (green-salads-l5yb)
# ✔ Green Salads tamamlandı
#
# [208/2165] Bowl Lab (bowl-lab)
# ✔ Bowl Lab tamamlandı
#
# [209/2165] Cantina Prime (cantina-prime)
# ✔ Cantina Prime tamamlandı
#
# [210/2165] Must Bowl by Migros (must-bowl-by-migros-t1ah)
# ✔ Must Bowl by Migros tamamlandı
#
# [211/2165] Coff's Cafe & Restaurant (coffs-cafe-and-restaurant)
# ✔ Coff's Cafe & Restaurant tamamlandı
#
# [212/2165] Smash Burger B (smash-burger-b-z1hq)
# ✔ Smash Burger B tamamlandı
#
# [213/2165] Pastacı Hamdi (pastaci-hamdi)
# ✔ Pastacı Hamdi tamamlandı
#
# [214/2165] Cookshop (cookshop-r2fs)
# ✔ Cookshop tamamlandı
#
# [215/2165] KitchenDo (kitchendo)
# ✔ KitchenDo tamamlandı
#
# [216/2165] Bowl & Bowl (bowl-and-bowl-aw0q)
# ✔ Bowl & Bowl tamamlandı
#
# [217/2165] The Granma Food & Coffee (the-granma-food-and-coffee)
# ✔ The Granma Food & Coffee tamamlandı
#
# [218/2165] Bowl Kase (bowl-kase-hd88)
# ✔ Bowl Kase tamamlandı
#
# [219/2165] Timboo Cafe (timboo-cafe)
# ✔ Timboo Cafe tamamlandı
#
# [220/2165] Bowl & More (bowl-and-more-lrip)
# ✔ Bowl & More tamamlandı
#
# [221/2165] Schnitzel Art (schnitzel-art-efh6)
# ✔ Schnitzel Art tamamlandı
#
# [222/2165] Akça Pasta & Cafe & Restaurant (akca-pasta-and-cafe-and-restaurant)
# ✔ Akça Pasta & Cafe & Restaurant tamamlandı
#
# [223/2165] Tazedirekt Mutfak (tazedirekt-mutfak)
# ✔ Tazedirekt Mutfak tamamlandı
#
# [224/2165] Let's Salad (lets-salad-rc7k)
# ✔ Let's Salad tamamlandı
#
# [225/2165] Gina Bowl (gina-bowl-mz9t)
# ✔ Gina Bowl tamamlandı
#
# [226/2165] Mev Mutfak (mev-mutfak-bls1)
# ✔ Mev Mutfak tamamlandı
#
# [227/2165] Food Nook Roll & Sandwiches (food-nook-roll-and-sandwiches)
# ✔ Food Nook Roll & Sandwiches tamamlandı
#
# [228/2165] Sultan Döner Kebap & Lahmacun (sultan-doner-kebap-and-lahmacun)
# ✔ Sultan Döner Kebap & Lahmacun tamamlandı
#
# [229/2165] Mado (mado-comb)
# ✔ Mado tamamlandı
#
# [230/2165] Bodrum Mantı & Cafe (bodrum-manti-and-cafe-tt4n)
# ✔ Bodrum Mantı & Cafe tamamlandı
#
# [231/2165] Filifu Cafe (filifu-cafe)
# ✔ Filifu Cafe tamamlandı
#
# [232/2165] Big Chefs (big-chefs-i0fd)
# ✔ Big Chefs tamamlandı
#
# [233/2165] Natura Prime (natura-prime)
# ✔ Natura Prime tamamlandı
#
# [234/2165] Makarna Company (makarna-company-gob9)
# ✔ Makarna Company tamamlandı
#
# [235/2165] Bowllife (bowllife)
# ✔ Bowllife tamamlandı
#
# [236/2165] Gurme Mutfak Ev Yemekleri (gurme-mutfak-ev-yemekleri-lz14)
# ✔ Gurme Mutfak Ev Yemekleri tamamlandı
#
# [237/2165] Leyla Anne Ev Yemekleri (leyla-anne-ev-yemekleri-eqls)
# ✔ Leyla Anne Ev Yemekleri tamamlandı
#
# [238/2165] Schnitzel Art (schnitzel-art-u8qu)
# ✔ Schnitzel Art tamamlandı
#
# [239/2165] Güneş Kahvaltı Evi (gunes-kahvalti-evi-vc6p)
# ✔ Güneş Kahvaltı Evi tamamlandı
#
# [240/2165] Salad Town (salad-town-r2to)
# ✔ Salad Town tamamlandı
#
# [241/2165] Nammos (nammos-ki83)
# ✔ Nammos tamamlandı
#
# [242/2165] Cafe dlento (cafe-dlento)
# ✔ Cafe dlento tamamlandı
#
# [243/2165] Paul's Lazanya (pauls-lazanya)
# ✔ Paul's Lazanya tamamlandı
#
# [244/2165] The Rhythm Of Pasta Mambos (the-rhythm-of-pasta-mambos)
# ✔ The Rhythm Of Pasta Mambos tamamlandı
#
# [245/2165] Boshi-Co Balkan Mutfağı (boshi-co-balkan-mutfagi)
# ✔ Boshi-Co Balkan Mutfağı tamamlandı
#
# [246/2165] Tacofit (tacofit-y1m0)
# ✔ Tacofit tamamlandı
#
# [247/2165] Japon Uzakdoğu Mutfağı (japon-uzakdogu-mutfagi)
# ✔ Japon Uzakdoğu Mutfağı tamamlandı
#
# [248/2165] Ethique Patisserie & Boulangerie (ethique-patisserie-and-boulangerie)
# ✔ Ethique Patisserie & Boulangerie tamamlandı
#
# [249/2165] Wrap Republic (wrap-republic)
# ✔ Wrap Republic tamamlandı
#
# [250/2165] Lebon Gurme (lebon-gurme)
# ✔ Lebon Gurme tamamlandı
#
# [251/2165] Chef Ayşe (chef-ayse)
# ✔ Chef Ayşe tamamlandı
#
# [252/2165] Taze Kase (taze-kase-e2v7)
# ✔ Taze Kase tamamlandı
#
# [253/2165] Moston Ev Yemekleri (moston-ev-yemekleri)
# ✔ Moston Ev Yemekleri tamamlandı
#
# [254/2165] Kavurmacı Hasan Usta (kavurmaci-hasan-usta-ixoq)
# ✔ Kavurmacı Hasan Usta tamamlandı
#
# [255/2165] İskender Köfteci (iskender-kofteci)
# ✔ İskender Köfteci tamamlandı
#
# [256/2165] Köylüm Gözleme & Kahvaltı (koylum-gozleme-and-kahvalti)
# ✔ Köylüm Gözleme & Kahvaltı tamamlandı
#
# [257/2165] Pilav Noktası (pilav-noktasi)
# ✔ Pilav Noktası tamamlandı
#
# [258/2165] Tavuk Kampüsü (tavuk-kampusu-s6my)
# ✔ Tavuk Kampüsü tamamlandı
#
# [259/2165] Adile Sultan Ev Yemekleri (adile-sultan-ev-yemekleri-r2kp)
# ✔ Adile Sultan Ev Yemekleri tamamlandı
#
# [260/2165] Meydan Kokoreç & İşkembe (meydan-kokorec-and-iskembe-meba)
# ✔ Meydan Kokoreç & İşkembe tamamlandı
#
# [261/2165] Tavuk Dürüm Sofrası (tavuk-durum-sofrasi-z3gs)
# ✔ Tavuk Dürüm Sofrası tamamlandı
#
# [262/2165] Çorba Molası (corba-molasi-yqp3)
# ✔ Çorba Molası tamamlandı
#
# [263/2165] Şölen Çorba 7/24 (solen-corba-7-24)
# ✔ Şölen Çorba 7/24 tamamlandı
#
# [264/2165] Tarihi Maltepe Çorbacısı (tarihi-maltepe-corbacisi-i1w0)
# ✔ Tarihi Maltepe Çorbacısı tamamlandı
#
# [265/2165] Çorbistan (corbistan)
# ✔ Çorbistan tamamlandı
#
# [266/2165] Kafalti Meze & Şarküteri (kafalti-meze-and-sarkuteri-zxzi)
# ✔ Kafalti Meze & Şarküteri tamamlandı
#
# [267/2165] Çinilihan Mutfağı (cinilihan-mutfagi)
# ✔ Çinilihan Mutfağı tamamlandı
#
# [268/2165] Gurme Mutfak Ev Yemekleri (gurme-mutfak-ev-yemekleri-lz14)
# ✔ Gurme Mutfak Ev Yemekleri tamamlandı
#
# [269/2165] Aras Ev Lezzetleri (aras-ev-lezzetleri)
# ✔ Aras Ev Lezzetleri tamamlandı
#
# [270/2165] Lezzet Lokantası (lezzet-lokantasi-c0gq)
# ✔ Lezzet Lokantası tamamlandı
#
# [271/2165] Sevgi Lokantası Ev Yemekleri (sevgi-lokantasi-ev-yemekleri-jf8i)
# ✔ Sevgi Lokantası Ev Yemekleri tamamlandı
#
# [272/2165] Yağlama & Mantı Evi (yaglama-and-manti-evi)
# ✔ Yağlama & Mantı Evi tamamlandı
#
# [273/2165] Leyla Anne Ev Yemekleri (leyla-anne-ev-yemekleri-eqls)
# ✔ Leyla Anne Ev Yemekleri tamamlandı
#
# [274/2165] Erenler Et Lokantası (erenler-et-lokantasi)
# ✔ Erenler Et Lokantası tamamlandı
#
# [275/2165] Agapia Mezze (agapia-mezze-go95)
# ✔ Agapia Mezze tamamlandı
#
# [276/2165] Adile Hanımın Mutfağı (adile-hanimin-mutfagi)
# ✔ Adile Hanımın Mutfağı tamamlandı
#
# [277/2165] Altın Tencere Ev Yemekleri (altin-tencere-ev-yemekleri-fbir)
# ✔ Altın Tencere Ev Yemekleri tamamlandı
#
# [278/2165] Mezelerce (mezelerce-gau6)
# ✔ Mezelerce tamamlandı
#
# [279/2165] Envai Karaköy Lokantası (envai-karakoy-lokantasi-fofm)
# ✔ Envai Karaköy Lokantası tamamlandı
#
# [280/2165] Salatsa (salatsa)
# ✔ Salatsa tamamlandı
#
# [281/2165] Nostalji Ev Yemekleri (nostalji-ev-yemekleri)
# ✔ Nostalji Ev Yemekleri tamamlandı
#
# [282/2165] Kısıklı Çorbacısı (kisikli-corbacisi)
# ✔ Kısıklı Çorbacısı tamamlandı
#
# [283/2165] Katibe Hanım Ev Yemekleri (katibe-hanim-ev-yemekleri-zdlg)
# ✔ Katibe Hanım Ev Yemekleri tamamlandı
#
# [284/2165] Maltepe Mantı Evi (maltepe-manti-evi)
# ✔ Maltepe Mantı Evi tamamlandı
#
# [285/2165] Bol Kepçe Ev Yemekleri (bol-kepce-ev-yemekleri-w6kd)
# ✔ Bol Kepçe Ev Yemekleri tamamlandı
#
# [286/2165] Meze İstanbul (meze-istanbul)
# ✔ Meze İstanbul tamamlandı
#
# [287/2165] Şu Pilav (su-pilav)
# ✔ Şu Pilav tamamlandı
#
# [288/2165] Köylü Kızı Ev Yemekleri (koylu-kizi-ev-yemekleri)
# ✔ Köylü Kızı Ev Yemekleri tamamlandı
#
# [289/2165] Annenin Ev Yemekleri (annenin-ev-yemekleri-iw95)
# ✔ Annenin Ev Yemekleri tamamlandı
#
# [290/2165] Tokana Mantı (tokana-manti-w09l)
# ✔ Tokana Mantı tamamlandı
#
# [291/2165] Rukiye Teyze Ev Yemekleri (rukiye-teyze-ev-yemekleri-yn6r)
# ✔ Rukiye Teyze Ev Yemekleri tamamlandı
#
# [292/2165] Turkuaz Ev Yemekleri & Tatlı (turkuaz-ev-yemekleri-and-tatli)
# ✔ Turkuaz Ev Yemekleri & Tatlı tamamlandı
#
# [293/2165] Reyhani Ev Yemekleri (reyhani-ev-yemekleri-b7m7)
# ✔ Reyhani Ev Yemekleri tamamlandı
#
# [294/2165] Mahmut Usta Ev Yemekleri (mahmut-usta-ev-yemekleri)
# ✔ Mahmut Usta Ev Yemekleri tamamlandı
#
# [295/2165] Mantı Dünyası (manti-dunyasi-elat)
# ✔ Mantı Dünyası tamamlandı
#
# [296/2165] Bientat Gastronomi (bientat-gastronomi-vegv)
# ✔ Bientat Gastronomi tamamlandı
#
# [297/2165] Meze Sofrası (meze-sofrasi-pn7p)
# ✔ Meze Sofrası tamamlandı
#
# [298/2165] Mantı Hane (manti-hane-rl3j)
# ✔ Mantı Hane tamamlandı
#
# [299/2165] Diyardan Çorba (diyardan-corba-pmhx)
# ✔ Diyardan Çorba tamamlandı
#
# [300/2165] Tarihi Karadeniz Sütlaç (tarihi-karadeniz-sutlac)
# ✔ Tarihi Karadeniz Sütlaç tamamlandı
#
# [301/2165] Arwen Cafe (arwen-cafe)
# ✔ Arwen Cafe tamamlandı
#
# [302/2165] Öz Cemil Usta (oz-cemil-usta)
# ✔ Öz Cemil Usta tamamlandı
#
# [303/2165] Express Marmaris (express-marmaris)
# ✔ Express Marmaris tamamlandı
#
# [304/2165] The Granma Food & Coffee (the-granma-food-and-coffee)
# ✔ The Granma Food & Coffee tamamlandı
#
# [305/2165] Köfteci Yusuf (kofteci-yusuf-hrh4)
# ✔ Köfteci Yusuf tamamlandı
#
# [306/2165] Köylüm Gözleme & Kahvaltı (koylum-gozleme-and-kahvalti)
# ✔ Köylüm Gözleme & Kahvaltı tamamlandı
#
# [307/2165] İskender Köfteci (iskender-kofteci)
# ✔ İskender Köfteci tamamlandı
#
# [308/2165] Fıstıkâlâ  Baklava & Börek (fistikala-baklava-and-borek)
# ✔ Fıstıkâlâ  Baklava & Börek tamamlandı
#
# [309/2165] Kuğu Pastanesi (kugu-pastanesi-u34d)
# ✔ Kuğu Pastanesi tamamlandı
#
# [310/2165] Lotus Croissant & Breakfast (lotus-croissant-and-breakfast)
# ✔ Lotus Croissant & Breakfast tamamlandı
#
# [311/2165] Fıstıkname Baklava & Börek (fistikname-baklava-and-borek)
# ✔ Fıstıkname Baklava & Börek tamamlandı
#
# [312/2165] Kızçe Çi Börek (kizce-ci-borek)
# ✔ Kızçe Çi Börek tamamlandı
#
# [313/2165] Meşhur Sarıyer Börekçisi (meshur-sariyer-borekcisi-xtt7)
# ✔ Meşhur Sarıyer Börekçisi tamamlandı
#
# [314/2165] Yalı Kavurmacısı (yali-kavurmacisi)
# ✔ Yalı Kavurmacısı tamamlandı
#
# [315/2165] Simit Sarayı (simit-sarayi-ztoz)
# ✔ Simit Sarayı tamamlandı
#
# [316/2165] Caleo Coffee & Bakery (caleo-coffee-and-bakery)
# ✔ Caleo Coffee & Bakery tamamlandı
#
# [317/2165] Gurme Chefs Köz (gurme-chefs-koz)
# ✔ Gurme Chefs Köz tamamlandı
#
# [318/2165] Mir Börek & Cafe (mir-borek-and-cafe-vyy6)
# ✔ Mir Börek & Cafe tamamlandı
#
# [319/2165] Zeynep Şef Mantı & Gözleme (zeynep-sef-manti-and-gozleme)
# ✔ Zeynep Şef Mantı & Gözleme tamamlandı
#
# [320/2165] Maltepe Tostçusu Waffle & Magnolia (maltepe-tostcusu-waffle-and-magnolia)
# ✔ Maltepe Tostçusu Waffle & Magnolia tamamlandı
#
# [321/2165] Özsüt (ozsut-rtsy)
# ✔ Özsüt tamamlandı
#
# [322/2165] Güneş Kahvaltı Evi (gunes-kahvalti-evi-vc6p)
# ✔ Güneş Kahvaltı Evi tamamlandı
#
# [323/2165] Pate Mantı & Çi Börek (pate-manti-and-ci-borek)
# ✔ Pate Mantı & Çi Börek tamamlandı
#
# [324/2165] Manolya Pastanesi (manolya-pastanesi-i2j7)
# ✔ Manolya Pastanesi tamamlandı
#
# [325/2165] Çengelköy Börekçisi (cengelkoy-borekcisi-iuuf)
# ✔ Çengelköy Börekçisi tamamlandı
#
# [326/2165] Panista Tost (panista-tost-jw5k)
# ✔ Panista Tost tamamlandı
#
# [327/2165] Simit Mi? Gevrek Mi? (simit-mi-gevrek-mi)
# ✔ Simit Mi? Gevrek Mi? tamamlandı
#
# [328/2165] Simit Omlet (simit-omlet)
# ✔ Simit Omlet tamamlandı
#
# [329/2165] Bolulu Rıfat Usta Neşeli Köfte (bolulu-rifat-usta-neseli-kofte)
# ✔ Bolulu Rıfat Usta Neşeli Köfte tamamlandı
#
# [330/2165] Galata Kahvaltıcısı (galata-kahvalticisi)
# ✔ Galata Kahvaltıcısı tamamlandı
#
# [331/2165] Pişi Omlet (pisi-omlet)
# ✔ Pişi Omlet tamamlandı
#
# [332/2165] Panetto Pasta & Cafe (panetto-pasta-and-cafe)
# ✔ Panetto Pasta & Cafe tamamlandı
#
# [333/2165] Aşk-ı Kahvaltı (ask-i-kahvalti-gmmi)
# ✔ Aşk-ı Kahvaltı tamamlandı
#
# [334/2165] Fıstıkzade Baklava & Tatlı (fistikzade-baklava-and-tatli)
# ✔ Fıstıkzade Baklava & Tatlı tamamlandı
#
# [335/2165] Manolya Pastanesi Kayışdağı (manolya-pastanesi-kayisdagi)
# ✔ Manolya Pastanesi Kayışdağı tamamlandı
#
# [336/2165] Tarabya Kumrucusu 1994 (tarabya-kumrucusu-1994)
# ✔ Tarabya Kumrucusu 1994 tamamlandı
#
# [337/2165] Ulviye Börek (ulviye-borek)
# ✔ Ulviye Börek tamamlandı
#
# [338/2165] Tarihi Pembegül Pastanesi (tarihi-pembegul-pastanesi)
# ✔ Tarihi Pembegül Pastanesi tamamlandı
#
# [339/2165] Köylü Kızı Gözleme (koylu-kizi-gozleme)
# ✔ Köylü Kızı Gözleme tamamlandı
#
# [340/2165] C1 Coffee & Lounge (c1-coffee-and-lounge)
# ✔ C1 Coffee & Lounge tamamlandı
#
# [341/2165] By Puli (by-puli)
# ✔ By Puli tamamlandı
#
# [342/2165] Bi Gözleme Kahvaltı & Mantı Evi (bi-gozleme-kahvalti-and-manti-evi)
# ✔ Bi Gözleme Kahvaltı & Mantı Evi tamamlandı
#
# [343/2165] Bayraktar Gaziantep Baklava (bayraktar-gaziantep-baklava)
# ✔ Bayraktar Gaziantep Baklava tamamlandı
#
# [344/2165] Lokmano (lokmano)
# ✔ Lokmano tamamlandı
#
# [345/2165] Elit Patso (elit-patso)
# ✔ Elit Patso tamamlandı
#
# [346/2165] Acil Pilav (acil-pilav-x11u)
# ✔ Acil Pilav tamamlandı
#
# [347/2165] Mis Börek (mis-borek-ufq8)
# ✔ Mis Börek tamamlandı
#
# [348/2165] Acil Börek (acil-borek)
# ✔ Acil Börek tamamlandı
#
# [349/2165] Acil Ciğer (acil-ciger-szkd)
# ✔ Acil Ciğer tamamlandı
#
# [350/2165] California Wrap (california-wrap)
# ✔ California Wrap tamamlandı
#
# [351/2165] Börekhane (borekhane-kybg)
# ✔ Börekhane tamamlandı
#
# [352/2165] Dönerix (donerix-t59w)
# ✔ Dönerix tamamlandı
#
# [353/2165] Starbucks Coffee (starbucks-coffee-sudm)
# ✔ Starbucks Coffee tamamlandı
#
# [354/2165] The Granma Food & Coffee (the-granma-food-and-coffee)
# ✔ The Granma Food & Coffee tamamlandı
#
# [355/2165] Coffy (coffy-uq7h)
# ✔ Coffy tamamlandı
#
# [356/2165] Yummy Sushi (yummy-sushi)
# ✔ Yummy Sushi tamamlandı
#
# [357/2165] Nazar Profiterol (nazar-profiterol-pu6u)
# ✔ Nazar Profiterol tamamlandı
#
# [358/2165] Moncai Bubble Tea (moncai-bubble-tea-ifvp)
# ✔ Moncai Bubble Tea tamamlandı
#
# [359/2165] Magnolia Shop (magnolia-shop-kxse)
# ✔ Magnolia Shop tamamlandı
#
# [360/2165] Nuna Bakery (nuna-bakery)
# ✔ Nuna Bakery tamamlandı
#
# [361/2165] The Rhythm Of Pasta Mambos (the-rhythm-of-pasta-mambos)
# ✔ The Rhythm Of Pasta Mambos tamamlandı
#
# [362/2165] Burger King Cafe (burger-king-cafe-tkad)
# ✔ Burger King Cafe tamamlandı
#
# [363/2165] Micoffees (micoffees)
# ✔ Micoffees tamamlandı
#
# [364/2165] Mambos (mambos)
# ✔ Mambos tamamlandı
#
# [365/2165] The Co. Coffee (the-co-coffee-nnt8)
# ✔ The Co. Coffee tamamlandı
#
# [366/2165] Kaffee Schütz (kaffee-schutz-rndb)
# ✔ Kaffee Schütz tamamlandı
#
# [367/2165] Paio Coffee (paio-coffee)
# ✔ Paio Coffee tamamlandı
#
# [368/2165] Espressolab (espressolab-lpgx)
# ✔ Espressolab tamamlandı
#
# [369/2165] Caleo Coffee & Bakery (caleo-coffee-and-bakery)
# ✔ Caleo Coffee & Bakery tamamlandı
#
# [370/2165] NockNock Coffee (nocknock-coffee)
# ✔ NockNock Coffee tamamlandı
#
# [371/2165] Riposo Coffee Kitchen (riposo-coffee-kitchen)
# ✔ Riposo Coffee Kitchen tamamlandı
#
# [372/2165] Tikky’s Coffee (tikkys-coffee)
# ✔ Tikky’s Coffee tamamlandı
#
# [373/2165] Serez Dondurmacısı Maltepe (serez-dondurmacisi-maltepe)
# ✔ Serez Dondurmacısı Maltepe tamamlandı
#
# [374/2165] Kahve Dünyası (kahve-dunyasi-fe5d)
# ✔ Kahve Dünyası tamamlandı
#
# [375/2165] McDonald’s McCafé (mcdonalds-mccafe-vviu)
# ✔ McDonald’s McCafé tamamlandı
#
# [376/2165] Mikel Coffee (mikel-coffee-rq2l)
# ✔ Mikel Coffee tamamlandı
#
# [377/2165] Caffe Nero (caffe-nero-akww)
# ✔ Caffe Nero tamamlandı
#
# [378/2165] Limp Patisserie (limp-patisserie)
# ✔ Limp Patisserie tamamlandı
#
# [379/2165] Doppio Coffeehouse (doppio-coffeehouse)
# ✔ Doppio Coffeehouse tamamlandı
#
# [380/2165] Moncai Premium Matcha (moncai-premium-matcha)
# ✔ Moncai Premium Matcha tamamlandı
#
# [381/2165] Brewlog Coffee (brewlog-coffee)
# ✔ Brewlog Coffee tamamlandı
#
# [382/2165] Çengelköy Börekçisi (cengelkoy-borekcisi-iuuf)
# ✔ Çengelköy Börekçisi tamamlandı
#
# [383/2165] Ethique Patisserie & Boulangerie (ethique-patisserie-and-boulangerie)
# ✔ Ethique Patisserie & Boulangerie tamamlandı
#
# [384/2165] Mahalle Fırın (mahalle-firin)
# ✔ Mahalle Fırın tamamlandı
#
# [385/2165] Greenwich Coffee (greenwich-coffee-tbnu)
# ✔ Greenwich Coffee tamamlandı
#
# [386/2165] Gloria Jean's Coffees (gloria-jeans-coffees-w3fg)
# ✔ Gloria Jean's Coffees tamamlandı
#
# [387/2165] Nubi Artisan Bakery (nubi-artisan-bakery)
# ✔ Nubi Artisan Bakery tamamlandı
#
# [388/2165] Lebon Gurme (lebon-gurme)
# ✔ Lebon Gurme tamamlandı
#
# [389/2165] Retro Burger & Salad & Dessert (retro-burger-and-salad-and-dessert)
# ✔ Retro Burger & Salad & Dessert tamamlandı
#
# [390/2165] Dozze Coffee (dozze-coffee)
# ✔ Dozze Coffee tamamlandı
#
# [391/2165] Coffee Pause (coffee-pause-sny0)
# ✔ Coffee Pause tamamlandı
#
# [392/2165] Dart Coffee (dart-coffee)
# ✔ Dart Coffee tamamlandı
#
# [393/2165] Tchibo (tchibo-jwcw)
# ✔ Tchibo tamamlandı
#
# [394/2165] Salamora Sandwiches (salamora-sandwiches)
# ✔ Salamora Sandwiches tamamlandı
#
# [395/2165] Colombia Coffee (colombia-coffee-vjt0)
# ✔ Colombia Coffee tamamlandı
#
# [396/2165] Tupinamba (tupinamba)
# ✔ Tupinamba tamamlandı
#
# [397/2165] Nevada Coffee (nevada-coffee-ikiu)
# ✔ Nevada Coffee tamamlandı
#
# [398/2165] Mr Coffee (mr-coffee)
# ✔ Mr Coffee tamamlandı
#
# [399/2165] Dozze Coffee Bostancı (dozze-coffee-bostanci)
# ✔ Dozze Coffee Bostancı tamamlandı
#
# [400/2165] Diverso Caffe (diverso-caffe)
# ✔ Diverso Caffe tamamlandı
#
# [401/2165] Costa Coffee (costa-coffee-kmhw)
# ✔ Costa Coffee tamamlandı
#
# [402/2165] Carmelo Coffee (carmelo-coffee-wdez)
# ✔ Carmelo Coffee tamamlandı
#
# [403/2165] Hacıbaşar Kebap & Baklava (hacibasar-kebap-and-baklava-e8wi)
# ✔ Hacıbaşar Kebap & Baklava tamamlandı
#
# [404/2165] Starhan Pide & Döner (starhan-pide-and-doner)
# ✔ Starhan Pide & Döner tamamlandı
#
# [405/2165] Çeltik Kebap & Lahmacun (celtik-kebap-and-lahmacun-ow5z)
# ✔ Çeltik Kebap & Lahmacun tamamlandı
#
# [406/2165] Çınaraltı Dürüm (cinaralti-durum)
# ✔ Çınaraltı Dürüm tamamlandı
#
# [407/2165] Çeltik Kebap Maltepe Merkez (celtik-kebap-maltepe-merkez)
# ✔ Çeltik Kebap Maltepe Merkez tamamlandı
#
# [408/2165] Tadı Bafra (tadi-bafra)
# ✔ Tadı Bafra tamamlandı
#
# [409/2165] Saray Muhallebicisi 1935 (saray-muhallebicisi-1935-v2bj)
# ✔ Saray Muhallebicisi 1935 tamamlandı
#
# [410/2165] Kardeşler Kebap (kardesler-kebap-csn8)
# ✔ Kardeşler Kebap tamamlandı
#
# [411/2165] Mıntıka Kebap & Lahmacun & Meze (mintika-kebap-and-lahmacun-and-meze-yl0z)
# ✔ Mıntıka Kebap & Lahmacun & Meze tamamlandı
#
# [412/2165] Abooov Kebap Ahmet Usta (abooov-kebap-ahmet-usta)
# ✔ Abooov Kebap Ahmet Usta tamamlandı
#
# [413/2165] Tike Maltepe (tike-maltepe)
# ✔ Tike Maltepe tamamlandı
#
# [414/2165] Önder Kebap & Lahmacun (onder-kebap-and-lahmacun-fnk3)
# ✔ Önder Kebap & Lahmacun tamamlandı
#
# [415/2165] HD İskender (hd-iskender-cp0c)
# ✔ HD İskender tamamlandı
#
# [416/2165] Moston Ev Yemekleri (moston-ev-yemekleri)
# ✔ Moston Ev Yemekleri tamamlandı
#
# [417/2165] Erzincan Kasap Et & Mangal (erzincan-kasap-et-and-mangal)
# ✔ Erzincan Kasap Et & Mangal tamamlandı
#
# [418/2165] Közde Kanat & Piliç Çevirme (kozde-kanat-and-pilic-cevirme-h5ns)
# ✔ Közde Kanat & Piliç Çevirme tamamlandı
#
# [419/2165] Komagene Etsiz Çiğ Köfte (komagene-etsiz-cig-kofte-sh4q)
# ✔ Komagene Etsiz Çiğ Köfte tamamlandı
#
# [420/2165] İrfan Usta Lahmacun (irfan-usta-lahmacun)
# ✔ İrfan Usta Lahmacun tamamlandı
#
# [421/2165] Zirve Kokoreç (zirve-kokorec)
# ✔ Zirve Kokoreç tamamlandı
#
# [422/2165] 7/24 Sultanahmet Çorbacısı (7-24-sultanahmet-corbacisi)
# ✔ 7/24 Sultanahmet Çorbacısı tamamlandı
#
# [423/2165] Tek Büfe (tek-bufe-j6gm)
# ✔ Tek Büfe tamamlandı
#
# [424/2165] Karacabey Künefe & Kebap & Lahmacun (karacabey-kunefe-and-kebap-and-lahmacun)
# ✔ Karacabey Künefe & Kebap & Lahmacun tamamlandı
#
# [425/2165] Olimpiyat Kokoreç (olimpiyat-kokorec-dvbj)
# ✔ Olimpiyat Kokoreç tamamlandı
#
# [426/2165] Kuğu Pastanesi (kugu-pastanesi-u34d)
# ✔ Kuğu Pastanesi tamamlandı
#
# [427/2165] Hacıbey (hacibey)
# ✔ Hacıbey tamamlandı
#
# [428/2165] Küçükyalı Pilavcısı (kucukyali-pilavcisi-aya6)
# ✔ Küçükyalı Pilavcısı tamamlandı
#
# [429/2165] Pidem (pidem-wsay)
# ✔ Pidem tamamlandı
#
# [430/2165] İntiba Döner (intiba-doner-zlvo)
# ✔ İntiba Döner tamamlandı
#
# [431/2165] Sultanım Döner (sultanim-doner)
# ✔ Sultanım Döner tamamlandı
#
# [432/2165] Tarihi Demirci Döner Lokantası (tarihi-demirci-doner-lokantasi-n0t0)
# ✔ Tarihi Demirci Döner Lokantası tamamlandı
#
# [433/2165] Pilav Noktası (pilav-noktasi)
# ✔ Pilav Noktası tamamlandı
#
# [434/2165] Dürümle (durumle-mi1o)
# ✔ Dürümle tamamlandı
#
# [435/2165] Dürüm Sarayı (durum-sarayi)
# ✔ Dürüm Sarayı tamamlandı
#
# [436/2165] Mardin Mutfağı (mardin-mutfagi)
# ✔ Mardin Mutfağı tamamlandı
#
# [437/2165] 01 Lezzet Adana Sofrası (01-lezzet-adana-sofrasi)
# ✔ 01 Lezzet Adana Sofrası tamamlandı
#
# [438/2165] Akarçay Kebap (akarcay-kebap)
# ✔ Akarçay Kebap tamamlandı
#
# [439/2165] Kaplan Kebap(Zümrütevler) (kaplan-kebap-zumrutevler)
# ✔ Kaplan Kebap(Zümrütevler) tamamlandı
#
# [440/2165] Gazi Çiğ Köfte (gazi-cig-kofte-bltx)
# ✔ Gazi Çiğ Köfte tamamlandı
#
# [441/2165] Yalı Pide & Lahmacun & Sac Tava (yali-pide-and-lahmacun-and-sac-tava)
# ✔ Yalı Pide & Lahmacun & Sac Tava tamamlandı
#
# [442/2165] Rodop Köfte (rodop-kofte)
# ✔ Rodop Köfte tamamlandı
#
# [443/2165] Bostancı Fırat Kebap (bostanci-firat-kebap-k0to)
# ✔ Bostancı Fırat Kebap tamamlandı
#
# [444/2165] Garden Feast (garden-feast)
# ✔ Garden Feast tamamlandı
#
# [445/2165] Tarihi Maltepe Çorbacısı (tarihi-maltepe-corbacisi-i1w0)
# ✔ Tarihi Maltepe Çorbacısı tamamlandı
#
# [446/2165] Kaplan Kebap (Küçükyalı) (kaplan-kebap-kucukyali)
# ✔ Kaplan Kebap (Küçükyalı) tamamlandı
#
# [447/2165] Hacıoğlu (hacioglu-vj7e)
# ✔ Hacıoğlu tamamlandı
#
# [448/2165] Kent Kebap & Pide & Lahmacun (kent-kebap-and-pide-and-lahmacun)
# ✔ Kent Kebap & Pide & Lahmacun tamamlandı
#
# [449/2165] Turkish Bowl (turkish-bowl-szr8)
# ✔ Turkish Bowl tamamlandı
#
# [450/2165] Dürümcü Esnaf (durumcu-esnaf-v8ej)
# ✔ Dürümcü Esnaf tamamlandı
#
# [451/2165] Konya Tadım Etli Ekmek (konya-tadim-etli-ekmek-swgu)
# ✔ Konya Tadım Etli Ekmek tamamlandı
#
# [452/2165] Antepli Dürümcü Hacı Usta (antepli-durumcu-haci-usta)
# ✔ Antepli Dürümcü Hacı Usta tamamlandı
#
# [453/2165] Köfteci Yusuf (kofteci-yusuf-hrh4)
# ✔ Köfteci Yusuf tamamlandı
#
# [454/2165] Hasan Usta Köftevi (hasan-usta-koftevi-pr08)
# ✔ Hasan Usta Köftevi tamamlandı
#
# [455/2165] İskender Köfteci (iskender-kofteci)
# ✔ İskender Köfteci tamamlandı
#
# [456/2165] Zekokoreç & Döner & Kokoreç (zekokorec-and-doner-and-kokorec)
# ✔ Zekokoreç & Döner & Kokoreç tamamlandı
#
# [457/2165] Olimpiyat Kokoreç (olimpiyat-kokorec-dvbj)
# ✔ Olimpiyat Kokoreç tamamlandı
#
# [458/2165] Smash Burger B (smash-burger-b-z1hq)
# ✔ Smash Burger B tamamlandı
#
# [459/2165] Köfteci Ramiz (kofteci-ramiz-z2hy)
# ✔ Köfteci Ramiz tamamlandı
#
# [460/2165] Rodop Köfte (rodop-kofte)
# ✔ Rodop Köfte tamamlandı
#
# [461/2165] Tarihi Tencere Köftecisi (tarihi-tencere-koftecisi-e53u)
# ✔ Tarihi Tencere Köftecisi tamamlandı
#
# [462/2165] Ankara Sereserpe Köftecisi (ankara-sereserpe-koftecisi)
# ✔ Ankara Sereserpe Köftecisi tamamlandı
#
# [463/2165] Üstat Köfte & Üstat Mantı (ustat-kofte-and-ustat-manti-omso)
# ✔ Üstat Köfte & Üstat Mantı tamamlandı
#
# [464/2165] Köfte Co (kofte-co-e4by)
# ✔ Köfte Co tamamlandı
#
# [465/2165] Üstat Köfte & Üstat Mantı (ustat-kofte-and-ustat-manti-wygb)
# ✔ Üstat Köfte & Üstat Mantı tamamlandı
#
# [466/2165] Tarihi Fatih Köftecisi (tarihi-fatih-koftecisi)
# ✔ Tarihi Fatih Köftecisi tamamlandı
#
# [467/2165] Co Burger (co-burger-gche)
# ✔ Co Burger tamamlandı
#
# [468/2165] Bolulu Rıfat Usta Neşeli Köfte (bolulu-rifat-usta-neseli-kofte)
# ✔ Bolulu Rıfat Usta Neşeli Köfte tamamlandı
#
# [469/2165] Dükkan Büfe (dukkan-bufe)
# ✔ Dükkan Büfe tamamlandı
#
# [470/2165] Köfteci Elifin Mutfağı (kofteci-elifin-mutfagi)
# ✔ Köfteci Elifin Mutfağı tamamlandı
#
# [471/2165] Köfte Ci (kofte-ci)
# ✔ Köfte Ci tamamlandı
#
# [472/2165] May Köfte (may-kofte)
# ✔ May Köfte tamamlandı
#
# [473/2165] Ünlü Köfte (unlu-kofte)
# ✔ Ünlü Köfte tamamlandı
#
# [474/2165] Salon Pilav & Tantuni (salon-pilav-and-tantuni)
# ✔ Salon Pilav & Tantuni tamamlandı
#
# [475/2165] Hacı Destan Köftecisi (haci-destan-koftecisi-oi1b)
# ✔ Hacı Destan Köftecisi tamamlandı
#
# [476/2165] Tabi Tabi Mercimek Köfte & Meze Evi (tabi-tabi-mercimek-kofte-and-meze-evi-d33g)
# ✔ Tabi Tabi Mercimek Köfte & Meze Evi tamamlandı
#
# [477/2165] Köftedeyiz (koftedeyiz)
# ✔ Köftedeyiz tamamlandı
#
# [478/2165] Köfte Sucuk Ben (kofte-sucuk-ben)
# ✔ Köfte Sucuk Ben tamamlandı
#
# [479/2165] Köfteciyiz (kofteciyiz-pph2)
# ✔ Köfteciyiz tamamlandı
#
# [480/2165] Elif Sucuk & Köfte (elif-sucuk-and-kofte)
# ✔ Elif Sucuk & Köfte tamamlandı
#
# [481/2165] Adam Pizza & Burger (adam-pizza-and-burger)
# ✔ Adam Pizza & Burger tamamlandı
#
# [482/2165] Boshima Balkan Köftecisi (boshima-balkan-koftecisi)
# ✔ Boshima Balkan Köftecisi tamamlandı
#
# [483/2165] Wrap Keyfi (wrap-keyfi)
# ✔ Wrap Keyfi tamamlandı
#
# [484/2165] Yess Köfte (yess-kofte)
# ✔ Yess Köfte tamamlandı
#
# [485/2165] Balkan Mutfağı (balkan-mutfagi)
# ✔ Balkan Mutfağı tamamlandı
#
# [486/2165] Ada Köfte (ada-kofte-rzyc)
# ✔ Ada Köfte tamamlandı
#
# [487/2165] Cızbız Fast & Food (cizbiz-fast-and-food)
# ✔ Cızbız Fast & Food tamamlandı
#
# [488/2165] Köfteci Recep (kofteci-recep)
# ✔ Köfteci Recep tamamlandı
#
# [489/2165] Köfteci Hakan Usta (kofteci-hakan-usta)
# ✔ Köfteci Hakan Usta tamamlandı
#
# [490/2165] Köfteci Ayhan (kofteci-ayhan-sasf)
# ✔ Köfteci Ayhan tamamlandı
#
# [491/2165] Vefa Köfte (vefa-kofte)
# ✔ Vefa Köfte tamamlandı
#
# [492/2165] Kekik Köfte (kekik-kofte)
# ✔ Kekik Köfte tamamlandı
#
# [493/2165] Güler Köfte (guler-kofte)
# ✔ Güler Köfte tamamlandı
#
# [494/2165] Kuzen’s Fast Food (kuzens-fast-food-qqal)
# ✔ Kuzen’s Fast Food tamamlandı
#
# [495/2165] Onur Et Izgara & Köfte (onur-et-izgara-and-kofte)
# ✔ Onur Et Izgara & Köfte tamamlandı
#
# [496/2165] Üç Çeyrek Kokoreç (uc-ceyrek-kokorec-nf2k)
# ✔ Üç Çeyrek Kokoreç tamamlandı
#
# [497/2165] My Köftecim (my-koftecim)
# ✔ My Köftecim tamamlandı
#
# [498/2165] Ziya-De Köfteci (ziya-de-kofteci)
# ✔ Ziya-De Köfteci tamamlandı
#
# [499/2165] Konumdayım Sokak Lezzetleri (konumdayim-sokak-lezzetleri)
# ✔ Konumdayım Sokak Lezzetleri tamamlandı
#
# [500/2165] Köfte Uzmanı (kofte-uzmani)
# ✔ Köfte Uzmanı tamamlandı
#
# [501/2165] Lezziz Pide & Lahmacun & Köfte (lezziz-pide-and-lahmacun-and-kofte)
# ✔ Lezziz Pide & Lahmacun & Köfte tamamlandı
#
# [502/2165] Rumeli Köftecisi (rumeli-koftecisi-t7tn)
# ✔ Rumeli Köftecisi tamamlandı
#
# [503/2165] Zirve Kokoreç (zirve-kokorec)
# ✔ Zirve Kokoreç tamamlandı
#
# [504/2165] Hacıbey (hacibey)
# ✔ Hacıbey tamamlandı
#
# [505/2165] Olimpiyat Kokoreç (olimpiyat-kokorec-dvbj)
# ✔ Olimpiyat Kokoreç tamamlandı
#
# [506/2165] Zekokoreç & Döner & Kokoreç (zekokorec-and-doner-and-kokorec)
# ✔ Zekokoreç & Döner & Kokoreç tamamlandı
#
# [507/2165] Meydan Kokoreç & İşkembe (meydan-kokorec-and-iskembe-meba)
# ✔ Meydan Kokoreç & İşkembe tamamlandı
#
# [508/2165] Olimpiyat Kokoreç 2 (olimpiyat-kokorec-2)
# ✔ Olimpiyat Kokoreç 2 tamamlandı
#
# [509/2165] Üçel Kokoreç (ucel-kokorec)
# ✔ Üçel Kokoreç tamamlandı
#
# [510/2165] Şampiyon Kokoreç (sampiyon-kokorec-tbo2)
# ✔ Şampiyon Kokoreç tamamlandı
#
# [511/2165] Uslubey İzmir Kuzu Kokoreç (uslubey-izmir-kuzu-kokorec)
# ✔ Uslubey İzmir Kuzu Kokoreç tamamlandı
#
# [512/2165] Bizim Kokoreç (bizim-kokorec-e8xw)
# ✔ Bizim Kokoreç tamamlandı
#
# [513/2165] Salon Kokoreç (salon-kokorec)
# ✔ Salon Kokoreç tamamlandı
#
# [514/2165] Ataşehir Sokak Lezzetleri (atasehir-sokak-lezzetleri)
# ✔ Ataşehir Sokak Lezzetleri tamamlandı
#
# [515/2165] Julienne Kokoreç (julienne-kokorec)
# ✔ Julienne Kokoreç tamamlandı
#
# [516/2165] Midyeci Yasin (midyeci-yasin-r0l2)
# ✔ Midyeci Yasin tamamlandı
#
# [517/2165] Üç Çeyrek Kokoreç (uc-ceyrek-kokorec-nf2k)
# ✔ Üç Çeyrek Kokoreç tamamlandı
#
# [518/2165] Keyf-i Kumpir & Waffle (keyf-i-kumpir-and-waffle-raoo)
# ✔ Keyf-i Kumpir & Waffle tamamlandı
#
# [519/2165] Ortaköy Kumpir & Tantuni (ortakoy-kumpir-and-tantuni)
# ✔ Ortaköy Kumpir & Tantuni tamamlandı
#
# [520/2165] Biz Büfe & Kumpir (biz-bufe-and-kumpir)
# ✔ Biz Büfe & Kumpir tamamlandı
#
# [521/2165] Waffpir Waffle & Kumpir (waffpir-waffle-and-kumpir-zs1i)
# ✔ Waffpir Waffle & Kumpir tamamlandı
#
# [522/2165] Granny's Waffles & Kumpir (grannys-waffles-and-kumpir-daa5)
# ✔ Granny's Waffles & Kumpir tamamlandı
#
# [523/2165] Granny's Waffles & Kumpir (grannys-waffles-and-kumpir-pxw2)
# ✔ Granny's Waffles & Kumpir tamamlandı
#
# [524/2165] 112 Kumpir & Waffle (112-kumpir-and-waffle)
# ✔ 112 Kumpir & Waffle tamamlandı
#
# [525/2165] Delice Kumpir & Waffle Dünyası (delice-kumpir-and-waffle-dunyasi)
# ✔ Delice Kumpir & Waffle Dünyası tamamlandı
#
# [526/2165] Date Waffle & Kumpir (date-waffle-and-kumpir)
# ✔ Date Waffle & Kumpir tamamlandı
#
# [527/2165] Galata Kumpir & Waffle (galata-kumpir-and-waffle)
# ✔ Galata Kumpir & Waffle tamamlandı
#
# [528/2165] Ortaköylü Kumpir Waffle (ortakoylu-kumpir-waffle)
# ✔ Ortaköylü Kumpir Waffle tamamlandı
#
# [529/2165] Waffpir Waffle & Kumpir (waffpir-waffle-and-kumpir-c4mz)
# ✔ Waffpir Waffle & Kumpir tamamlandı
#
# [530/2165] Bitez Kumpir & Meze (bitez-kumpir-and-meze)
# ✔ Bitez Kumpir & Meze tamamlandı
#
# [531/2165] Biz Büfe & Kumpir (biz-bufe-and-kumpir-dsta)
# ✔ Biz Büfe & Kumpir tamamlandı
#
# [532/2165] Angel's Kumpir & Waffle (angels-kumpir-and-waffle)
# ✔ Angel's Kumpir & Waffle tamamlandı
#
# [533/2165] Etod Kumpir & Waffle & Dondurma (etod-kumpir-and-waffle-and-dondurma-cypw)
# ✔ Etod Kumpir & Waffle & Dondurma tamamlandı
#
# [534/2165] Makarnam (makarnam)
# ✔ Makarnam tamamlandı
#
# [535/2165] Coff's Cafe & Restaurant (coffs-cafe-and-restaurant)
# ✔ Coff's Cafe & Restaurant tamamlandı
#
# [536/2165] Vokta Tavuk (vokta-tavuk)
# ✔ Vokta Tavuk tamamlandı
#
# [537/2165] Bafetto Pizza (bafetto-pizza-qtgn)
# ✔ Bafetto Pizza tamamlandı
#
# [538/2165] 1 Tabak Makarna (1-tabak-makarna)
# ✔ 1 Tabak Makarna tamamlandı
#
# [539/2165] Paio (paio)
# ✔ Paio tamamlandı
#
# [540/2165] Let's Salad (lets-salad-rc7k)
# ✔ Let's Salad tamamlandı
#
# [541/2165] Makarna Republic (makarna-republic)
# ✔ Makarna Republic tamamlandı
#
# [542/2165] Makarna Company (makarna-company-gob9)
# ✔ Makarna Company tamamlandı
#
# [543/2165] Gurme Mutfak Ev Yemekleri (gurme-mutfak-ev-yemekleri-lz14)
# ✔ Gurme Mutfak Ev Yemekleri tamamlandı
#
# [544/2165] Nammos (nammos-ki83)
# ✔ Nammos tamamlandı
#
# [545/2165] Köylüm Gözleme & Kahvaltı (koylum-gozleme-and-kahvalti)
# ✔ Köylüm Gözleme & Kahvaltı tamamlandı
#
# [546/2165] Leyla Anne Ev Yemekleri (leyla-anne-ev-yemekleri-eqls)
# ✔ Leyla Anne Ev Yemekleri tamamlandı
#
# [547/2165] La Makarna & Salata (la-makarna-and-salata)
# ✔ La Makarna & Salata tamamlandı
#
# [548/2165] Mambos (mambos)
# ✔ Mambos tamamlandı
#
# [549/2165] Envai Karaköy Lokantası (envai-karakoy-lokantasi-fofm)
# ✔ Envai Karaköy Lokantası tamamlandı
#
# [550/2165] Salatsa (salatsa)
# ✔ Salatsa tamamlandı
#
# [551/2165] The Rhythm Of Pasta Mambos (the-rhythm-of-pasta-mambos)
# ✔ The Rhythm Of Pasta Mambos tamamlandı
#
# [552/2165] Cadde 1 Makarna & Mantı (cadde-1-makarna-and-manti)
# ✔ Cadde 1 Makarna & Mantı tamamlandı
#
# [553/2165] Bab Texas Burger (bab-texas-burger)
# ✔ Bab Texas Burger tamamlandı
#
# [554/2165] By Puli (by-puli)
# ✔ By Puli tamamlandı
#
# [555/2165] Makarna Hub (makarna-hub-afkk)
# ✔ Makarna Hub tamamlandı
#
# [556/2165] Vrelo Balkan Pizza & Burger & Makarna (vrelo-balkan-pizza-and-burger-and-makarna)
# ✔ Vrelo Balkan Pizza & Burger & Makarna tamamlandı
#
# [557/2165] Mük Makarna (muk-makarna-bxe4)
# ✔ Mük Makarna tamamlandı
#
# [558/2165] My Moon Noodle (my-moon-noodle)
# ✔ My Moon Noodle tamamlandı
#
# [559/2165] NHR Cafe (nhr-cafe)
# ✔ NHR Cafe tamamlandı
#
# [560/2165] La Magica (la-magica-sns8)
# ✔ La Magica tamamlandı
#
# [561/2165] Muga Makarna (muga-makarna)
# ✔ Muga Makarna tamamlandı
#
# [562/2165] Senior CHEF (senior-chef)
# ✔ Senior CHEF tamamlandı
#
# [563/2165] Gravyer Sofra (gravyer-sofra-v74t)
# ✔ Gravyer Sofra tamamlandı
#
# [564/2165] Emir Lokantası (emir-lokantasi)
# ✔ Emir Lokantası tamamlandı
#
# [565/2165] Tina Mantı (tina-manti)
# ✔ Tina Mantı tamamlandı
#
# [566/2165] Köylüm Mantı (koylum-manti)
# ✔ Köylüm Mantı tamamlandı
#
# [567/2165] Dolu Dolu Mantı (dolu-dolu-manti-esoz)
# ✔ Dolu Dolu Mantı tamamlandı
#
# [568/2165] Hacer Ana Mantı (hacer-ana-manti)
# ✔ Hacer Ana Mantı tamamlandı
#
# [569/2165] Kızçe Pelmeni (kizce-pelmeni)
# ✔ Kızçe Pelmeni tamamlandı
#
# [570/2165] Köylüm Gözleme & Kahvaltı (koylum-gozleme-and-kahvalti)
# ✔ Köylüm Gözleme & Kahvaltı tamamlandı
#
# [571/2165] Zeynep Şef Mantı & Gözleme (zeynep-sef-manti-and-gozleme)
# ✔ Zeynep Şef Mantı & Gözleme tamamlandı
#
# [572/2165] Yağlama & Mantı Evi (yaglama-and-manti-evi)
# ✔ Yağlama & Mantı Evi tamamlandı
#
# [573/2165] Bodrum Mantı & Cafe (bodrum-manti-and-cafe-tt4n)
# ...
#
# [1974/2165] Köşebaşı Pilavcısı (kosebasi-pilavcisi-x4s4)
# ✔ Köşebaşı Pilavcısı tamamlandı
#
# [1975/2165] Nazar Pilav & Tavuk (nazar-pilav-and-tavuk)
# ✔ Nazar Pilav & Tavuk tamamlandı
#
# [1976/2165] Çağlayan Pilavcısı (caglayan-pilavcisi)
# ✔ Çağlayan Pilavcısı tamamlandı
#
# [1977/2165] Meşhur Çağlayan Pilavcısı (meshur-caglayan-pilavcisi)
# ✔ Meşhur Çağlayan Pilavcısı tamamlandı
#
# [1978/2165] Tarihi Şişhane Pilavcısı (tarihi-sishane-pilavcisi)
# ✔ Tarihi Şişhane Pilavcısı tamamlandı
#
# [1979/2165] Kardeşler Pilav (kardesler-pilav-ejvy)
# ✔ Kardeşler Pilav tamamlandı
#
# [1980/2165] Bomonti Ada Pilavcısı (bomonti-ada-pilavcisi)
# ✔ Bomonti Ada Pilavcısı tamamlandı
#
# [1981/2165] Meşhur Çağlayan Pilavcısı & Döner (meshur-caglayan-pilavcisi-and-doner)
# ✔ Meşhur Çağlayan Pilavcısı & Döner tamamlandı
#
# [1982/2165] Meşhur Kumkapanı Pilavcısı (meshur-kumkapani-pilavcisi)
# ✔ Meşhur Kumkapanı Pilavcısı tamamlandı
#
# [1983/2165] Tarihi Ada Pilavcısı (tarihi-ada-pilavcisi)
# ✔ Tarihi Ada Pilavcısı tamamlandı
#
# [1984/2165] Tarihi Unkapanı Pilavcısı (tarihi-unkapani-pilavcisi-zsgl)
# ✔ Tarihi Unkapanı Pilavcısı tamamlandı
#
# [1985/2165] Beyoğlu Pilavcısı (beyoglu-pilavcisi-okro)
# ✔ Beyoğlu Pilavcısı tamamlandı
#
# [1986/2165] Pilav & Makarna Üssü (pilav-and-makarna-ussu)
# ✔ Pilav & Makarna Üssü tamamlandı
#
# [1987/2165] Tuncay Meşhur Unkapanı Pilavcısı (tuncay-meshur-unkapani-pilavcisi)
# ✔ Tuncay Meşhur Unkapanı Pilavcısı tamamlandı
#
# [1988/2165] Tamtabak Pilav & Makarna (tamtabak-pilav-and-makarna)
# ✔ Tamtabak Pilav & Makarna tamamlandı
#
# [1989/2165] Tarihi Unkapanı Pilavcısı Beşiktaş (tarihi-unkapani-pilavcisi-besiktas)
# ✔ Tarihi Unkapanı Pilavcısı Beşiktaş tamamlandı
#
# [1990/2165] İl Forno (il-forno-qwgr)
# ✔ İl Forno tamamlandı
#
# [1991/2165] Fia Pizza (fia-pizza)
# ✔ Fia Pizza tamamlandı
#
# [1992/2165] Gagamima (gagamima)
# ✔ Gagamima tamamlandı
#
# [1993/2165] Pizza Wich (pizza-wich)
# ✔ Pizza Wich tamamlandı
#
# [1994/2165] Aşkım Büfe (askim-bufe)
# ✔ Aşkım Büfe tamamlandı
#
# [1995/2165] Pizza Nella İtaliano (pizza-nella-italiano-i9ap)
# ✔ Pizza Nella İtaliano tamamlandı
#
# [1996/2165] Pasaport Pizza (pasaport-pizza-ntj9)
# ✔ Pasaport Pizza tamamlandı
#
# [1997/2165] Öz Kekik Diyarı Pizza (oz-kekik-diyari-pizza)
# ✔ Öz Kekik Diyarı Pizza tamamlandı
#
# [1998/2165] Casa Forno Pizza & Makarna (casa-forno-pizza-and-makarna)
# ✔ Casa Forno Pizza & Makarna tamamlandı
#
# [1999/2165] Fames Cihangir (fames-cihangir)
# ✔ Fames Cihangir tamamlandı
#
# [2000/2165] Little Caesars Pizza (little-caesars-pizza-h6og)
# ✔ Little Caesars Pizza tamamlandı
#
# [2001/2165] Domino's Pizza (dominos-pizza-jvwz)
# ✔ Domino's Pizza tamamlandı
#
# [2002/2165] PizzaLazza (pizzalazza-xo5j)
# ✔ PizzaLazza tamamlandı
#
# [2003/2165] Pizza Nella Italiano (pizza-nella-italiano)
# ✔ Pizza Nella Italiano tamamlandı
#
# [2004/2165] Hero's Pizza (heros-pizza-b2q6)
# ✔ Hero's Pizza tamamlandı
#
# [2005/2165] Alfursan Resturant (alfursan-resturant)
# ✔ Alfursan Resturant tamamlandı
#
# [2006/2165] Papa John's Pizza (papa-johns-pizza-sy2h)
# ✔ Papa John's Pizza tamamlandı
#
# [2007/2165] Sbarro Pizza (sbarro-pizza-w9s0)
# ✔ Sbarro Pizza tamamlandı
#
# [2008/2165] Francesco Ristorante (francesco-ristorante)
# ✔ Francesco Ristorante tamamlandı
#
# [2009/2165] Must Bowl by Migros (must-bowl-by-migros-q1j2)
# ✔ Must Bowl by Migros tamamlandı
#
# [2010/2165] Gagamima (gagamima)
# ✔ Gagamima tamamlandı
#
# [2011/2165] My Salatte (my-salatte-kqhd)
# ✔ My Salatte tamamlandı
#
# [2012/2165] Salad Project (salad-project-hgss)
# ✔ Salad Project tamamlandı
#
# [2013/2165] Pizza Nella İtaliano (pizza-nella-italiano-i9ap)
# ✔ Pizza Nella İtaliano tamamlandı
#
# [2014/2165] Bowl & More (bowl-and-more-lm09)
# ✔ Bowl & More tamamlandı
#
# [2015/2165] Meat Burger & Gurme Mutfak (meat-burger-and-gurme-mutfak-ip0x)
# ✔ Meat Burger & Gurme Mutfak tamamlandı
#
# [2016/2165] Fresh Republic (fresh-republic)
# ✔ Fresh Republic tamamlandı
#
# [2017/2165] Eat Your Greens (eat-your-greens-a81d)
# ✔ Eat Your Greens tamamlandı
#
# [2018/2165] City Salads (city-salads-w69k)
# ✔ City Salads tamamlandı
#
# [2019/2165] Green Piece Salad & Bowl (green-piece-salad-and-bowl-dc40)
# ✔ Green Piece Salad & Bowl tamamlandı
#
# [2020/2165] Soul Bowl (soul-bowl-qfiv)
# ✔ Soul Bowl tamamlandı
#
# [2021/2165] Pilav & Makarna Üssü (pilav-and-makarna-ussu)
# ✔ Pilav & Makarna Üssü tamamlandı
#
# [2022/2165] Cafe Kazancı (cafe-kazanci)
# ✔ Cafe Kazancı tamamlandı
#
# [2023/2165] Tamtabak Pilav & Makarna (tamtabak-pilav-and-makarna)
# ✔ Tamtabak Pilav & Makarna tamamlandı
#
# [2024/2165] Tavuk Box (tavuk-box-nij5)
# ✔ Tavuk Box tamamlandı
#
# [2025/2165] Makarnacım (makarnacim-pdfk)
# ✔ Makarnacım tamamlandı
#
# [2026/2165] Kasabım Ethane (kasabim-ethane)
# ✔ Kasabım Ethane tamamlandı
#
# [2027/2165] Saltbae Burger (saltbae-burger-yrnx)
# ✔ Saltbae Burger tamamlandı
#
# [2028/2165] Besin Kasap & Steakhouse (besin-kasap-and-steakhouse)
# ✔ Besin Kasap & Steakhouse tamamlandı
#
# [2029/2165] Baltazar (baltazar-rvnh)
# ✔ Baltazar tamamlandı
#
# [2030/2165] Asaka Sushi & Chinese (asaka-sushi-and-chinese)
# ✔ Asaka Sushi & Chinese tamamlandı
#
# [2031/2165] Şerifin Izgarası (serifin-izgarasi-aw7j)
# ✔ Şerifin Izgarası tamamlandı
#
# [2032/2165] Şerifali Köftecisi (serifali-koftecisi-qwfv)
# ✔ Şerifali Köftecisi tamamlandı
#
# [2033/2165] Noodle Saka Chef (noodle-saka-chef)
# ✔ Noodle Saka Chef tamamlandı
#
# [2034/2165] Mindavallı Köfte & Piyaz (mindavalli-kofte-and-piyaz)
# ✔ Mindavallı Köfte & Piyaz tamamlandı
#
# [2035/2165] Fulya Eastnbull Steak & Burger (fulya-eastnbull-steak-and-burger)
# ✔ Fulya Eastnbull Steak & Burger tamamlandı
#
# [2036/2165] Burger Lab (burger-lab-xtqd)
# ✔ Burger Lab tamamlandı
#
# [2037/2165] Pilavcı Hamza Usta (pilavci-hamza-usta)
# ✔ Pilavcı Hamza Usta tamamlandı
#
# [2038/2165] Öz Gaziantep Sofrası (oz-gaziantep-sofrasi-xdhv)
# ✔ Öz Gaziantep Sofrası tamamlandı
#
# [2039/2165] Öz Hacıoğlu Lezzetleri (oz-hacioglu-lezzetleri)
# ✔ Öz Hacıoğlu Lezzetleri tamamlandı
#
# [2040/2165] Eatchil Steak (eatchil-steak)
# ✔ Eatchil Steak tamamlandı
#
# [2041/2165] Mersin Yaprak Tantuni (mersin-yaprak-tantuni-yzuq)
# ✔ Mersin Yaprak Tantuni tamamlandı
#
# [2042/2165] 33 Suat Usta Mersin Tantuni (33-suat-usta-mersin-tantuni-qdmp)
# ✔ 33 Suat Usta Mersin Tantuni tamamlandı
#
# [2043/2165] Beşaltı Kirvem Tantuni (besalti-kirvem-tantuni)
# ✔ Beşaltı Kirvem Tantuni tamamlandı
#
# [2044/2165] Galata Tantuni & Döner (galata-tantuni-and-doner)
# ✔ Galata Tantuni & Döner tamamlandı
#
# [2045/2165] Çağlayan Tantuni (caglayan-tantuni)
# ✔ Çağlayan Tantuni tamamlandı
#
# [2046/2165] Bey Tantuni (bey-tantuni-hjq0)
# ✔ Bey Tantuni tamamlandı
#
# [2047/2165] Tantuni Yiyelim (tantuni-yiyelim)
# ✔ Tantuni Yiyelim tamamlandı
#
# [2048/2165] 33 Suat Usta Mersin Tantuni (33-suat-usta-mersin-tantuni-lj7v)
# ✔ 33 Suat Usta Mersin Tantuni tamamlandı
#
# [2049/2165] Mis Tantuni (mis-tantuni-n1nt)
# ✔ Mis Tantuni tamamlandı
#
# [2050/2165] Bence Tantuni (bence-tantuni)
# ✔ Bence Tantuni tamamlandı
#
# [2051/2165] Galata Döner (galata-doner-f9yr)
# ✔ Galata Döner tamamlandı
#
# [2052/2165] Pozcu Tantuni (pozcu-tantuni-zbwv)
# ✔ Pozcu Tantuni tamamlandı
#
# [2053/2165] Ayla Tantuni (ayla-tantuni-dgpm)
# ✔ Ayla Tantuni tamamlandı
#
# [2054/2165] Tanto Tantuni (tanto-tantuni)
# ✔ Tanto Tantuni tamamlandı
#
# [2055/2165] Ta & Ma Cafe & Restaurant (ta-and-ma-cafe-and-restaurant)
# ✔ Ta & Ma Cafe & Restaurant tamamlandı
#
# [2056/2165] Tantuni Land (tantuni-land-galm)
# ✔ Tantuni Land tamamlandı
#
# [2057/2165] Tarihi Beyoğlu Pilavcısı (tarihi-beyoglu-pilavcisi-l3cl)
# ✔ Tarihi Beyoğlu Pilavcısı tamamlandı
#
# [2058/2165] Molino Cucina (molino-cucina-ru4z)
# ✔ Molino Cucina tamamlandı
#
# [2059/2165] Francesco Ristorante (francesco-ristorante)
# ✔ Francesco Ristorante tamamlandı
#
# [2060/2165] Saray Muhallebicisi 1935 (saray-muhallebicisi-1935-e0yo)
# ✔ Saray Muhallebicisi 1935 tamamlandı
#
# [2061/2165] Barbar Taş Fırın (barbar-tas-firin)
# ✔ Barbar Taş Fırın tamamlandı
#
# [2062/2165] Mardin Dünya Tatlısı (mardin-dunya-tatlisi)
# ✔ Mardin Dünya Tatlısı tamamlandı
#
# [2063/2165] Gaziantep Altın Dilim Baklava (gaziantep-altin-dilim-baklava)
# ✔ Gaziantep Altın Dilim Baklava tamamlandı
#
# [2064/2165] Helvacı Ali 1900 (helvaci-ali-1900-ms2b)
# ✔ Helvacı Ali 1900 tamamlandı
#
# [2065/2165] Mono Lounge (mono-lounge-s89s)
# ✔ Mono Lounge tamamlandı
#
# [2066/2165] Emirgan Sütiş (emirgan-sutis-lp8j)
# ✔ Emirgan Sütiş tamamlandı
#
# [2067/2165] Sufle Pera (sufle-pera-rmrr)
# ✔ Sufle Pera tamamlandı
#
# [2068/2165] Göreme Muhallebicisi (goreme-muhallebicisi-ivnp)
# ✔ Göreme Muhallebicisi tamamlandı
#
# [2069/2165] Hafız Mustafa 1864 (hafiz-mustafa-1864-jrob)
# ✔ Hafız Mustafa 1864 tamamlandı
#
# [2070/2165] Sirkeci Baba Cadde Pastanesi (sirkeci-baba-cadde-pastanesi)
# ✔ Sirkeci Baba Cadde Pastanesi tamamlandı
#
# [2071/2165] Helvacı Ali (helvaci-ali-zfqw)
# ✔ Helvacı Ali tamamlandı
#
# [2072/2165] Beylerbeyi Profiterol (beylerbeyi-profiterol-br7w)
# ✔ Beylerbeyi Profiterol tamamlandı
#
# [2073/2165] Kahve Dünyası (kahve-dunyasi-aqy8)
# ✔ Kahve Dünyası tamamlandı
#
# [2074/2165] Helvacı Ali (helvaci-ali-e9rv)
# ✔ Helvacı Ali tamamlandı
#
# [2075/2165] Eklercim (eklercim-q8zl)
# ✔ Eklercim tamamlandı
#
# [2076/2165] Popeyes (popeyes-mx0q)
# ✔ Popeyes tamamlandı
#
# [2077/2165] Texas Fried Chicken (texas-fried-chicken-yyvx)
# ✔ Texas Fried Chicken tamamlandı
#
# [2078/2165] The Wild Chicken (the-wild-chicken)
# ✔ The Wild Chicken tamamlandı
#
# [2079/2165] Must Bowl by Migros (must-bowl-by-migros-q1j2)
# ✔ Must Bowl by Migros tamamlandı
#
# [2080/2165] Mariva Resturant & Cafe (mariva-resturant-and-cafe)
# ✔ Mariva Resturant & Cafe tamamlandı
#
# [2081/2165] Makarnova (makarnova-bsux)
# ✔ Makarnova tamamlandı
#
# [2082/2165] Nazar Pilav & Tavuk (nazar-pilav-and-tavuk)
# ✔ Nazar Pilav & Tavuk tamamlandı
#
# [2083/2165] Akçay Büfe (akcay-bufe)
# ✔ Akçay Büfe tamamlandı
#
# [2084/2165] Acıktım (aciktim-ctij)
# ✔ Acıktım tamamlandı
#
# [2085/2165] Marinee Kanat (marinee-kanat)
# ✔ Marinee Kanat tamamlandı
#
# [2086/2165] Tavuk Dünyası (tavuk-dunyasi-fsib)
# ✔ Tavuk Dünyası tamamlandı
#
# [2087/2165] Sammy's Fried Chicken (sammys-fried-chicken)
# ✔ Sammy's Fried Chicken tamamlandı
#
# [2088/2165] Doyuyo (doyuyo-n30o)
# ✔ Doyuyo tamamlandı
#
# [2089/2165] Green Salads (green-salads-tk7d)
# ✔ Green Salads tamamlandı
#
# [2090/2165] Choys Fried Chicken (choys-fried-chicken)
# ✔ Choys Fried Chicken tamamlandı
#
# [2091/2165] ŞFC Şef Fried Chicken (sfc-sef-fried-chicken)
# ✔ ŞFC Şef Fried Chicken tamamlandı
#
# [2092/2165] Alfursan Resturant (alfursan-resturant)
# ✔ Alfursan Resturant tamamlandı
#
# [2093/2165] Cajun Corner (cajun-corner-ulfd)
# ✔ Cajun Corner tamamlandı
#
# [2094/2165] Kumpir Bago (kumpir-bago)
# ✔ Kumpir Bago tamamlandı
#
# [2095/2165] Vernazza (vernazza)
# ✔ Vernazza tamamlandı
#
# [2096/2165] Nisho Street Food (nisho-street-food-s10k)
# ✔ Nisho Street Food tamamlandı
#
# [2097/2165] Tamamen Organik Tost (tamamen-organik-tost-zayk)
# ✔ Tamamen Organik Tost tamamlandı
#
# [2098/2165] Akçay Büfe (akcay-bufe)
# ✔ Akçay Büfe tamamlandı
#
# [2099/2165] İqsir Bistro Restaurant (iqsir-bistro-restaurant)
# ✔ İqsir Bistro Restaurant tamamlandı
#
# [2100/2165] Cıncık Cafe Dünya Mutfağı (cincik-cafe-dunya-mutfagi)
# ✔ Cıncık Cafe Dünya Mutfağı tamamlandı
#
# [2101/2165] Sedwich (sedwich)
# ✔ Sedwich tamamlandı
#
# [2102/2165] Hanımeli Meze & Köfte (hanimeli-meze-and-kofte)
# ✔ Hanımeli Meze & Köfte tamamlandı
#
# [2103/2165] Tarçın Cafe Restuarant (tarcin-cafe-restuarant)
# ✔ Tarçın Cafe Restuarant tamamlandı
#
# [2104/2165] Köfteci Yusuf (kofteci-yusuf-dsj6)
# ✔ Köfteci Yusuf tamamlandı
#
# [2105/2165] Bambi Cafe Taksim Express (bambi-cafe-taksim-express-fmqa)
# ✔ Bambi Cafe Taksim Express tamamlandı
#
# [2106/2165] Etiler Marmaris (etiler-marmaris-vgqo)
# ✔ Etiler Marmaris tamamlandı
#
# [2107/2165] Subway (subway-vbrl)
# ✔ Subway tamamlandı
#
# [2108/2165] Es Sucuk'cum (es-sucukcum-oc87)
# ✔ Es Sucuk'cum tamamlandı
#
# [2109/2165] Büfe De Büfe (bufe-de-bufe)
# ✔ Büfe De Büfe tamamlandı
#
# [2110/2165] Kızılkayalar Hamburger (kizilkayalar-hamburger-vsmo)
# ✔ Kızılkayalar Hamburger tamamlandı
#
# [2111/2165] Munchies Sandviç (munchies-sandvic-aizx)
# ✔ Munchies Sandviç tamamlandı
#
# [2112/2165] SushiCo (sushico-h5pe)
# ✔ SushiCo tamamlandı
#
# [2113/2165] Sushi & Spice (sushi-and-spice)
# ✔ Sushi & Spice tamamlandı
#
# [2114/2165] Tas Ramen & Sushi Bar (tas-ramen-and-sushi-bar-dz45)
# ✔ Tas Ramen & Sushi Bar tamamlandı
#
# [2115/2165] Take Sushi (take-sushi)
# ✔ Take Sushi tamamlandı
#
# [2116/2165] Noodle Shop & Çin Kore Yemekleri (noodle-shop-and-cin-kore-yemekleri)
# ✔ Noodle Shop & Çin Kore Yemekleri tamamlandı
#
# [2117/2165] Luka Sushi (luka-sushi)
# ✔ Luka Sushi tamamlandı
#
# [2118/2165] Chinese Time (chinese-time-opp5)
# ✔ Chinese Time tamamlandı
#
# [2119/2165] Kumiko Sushi & More (kumiko-sushi-and-more)
# ✔ Kumiko Sushi & More tamamlandı
#
# [2120/2165] Shı Wok (shi-wok-oe4e)
# ✔ Shı Wok tamamlandı
#
# [2121/2165] Sushi-G (sushi-g-kgx7)
# ✔ Sushi-G tamamlandı
#
# [2122/2165] Noodle House (noodle-house-j7e9)
# ✔ Noodle House tamamlandı
#
# [2123/2165] Çin Büfe & Sushi (cin-bufe-and-sushi)
# ✔ Çin Büfe & Sushi tamamlandı
#
# [2124/2165] City Wok & Sushi (city-wok-and-sushi)
# ✔ City Wok & Sushi tamamlandı
#
# [2125/2165] China Magic Box Sushi (china-magic-box-sushi)
# ✔ China Magic Box Sushi tamamlandı
#
# [2126/2165] Kedai İndonesian Food (kedai-indonesian-food)
# ✔ Kedai İndonesian Food tamamlandı
#
# [2127/2165] Konoha Sushi & Chinese (konoha-sushi-and-chinese-bqn9)
# ✔ Konoha Sushi & Chinese tamamlandı
#
# [2128/2165] Chinese & Sushi Express (chinese-and-sushi-express-a22o)
# ✔ Chinese & Sushi Express tamamlandı
#
# [2129/2165] Eagle Chinese Gastro & Sushi (eagle-chinese-gastro-and-sushi-ie1j)
# ✔ Eagle Chinese Gastro & Sushi tamamlandı
#
# [2130/2165] Mr. Hamza Plus (mr-hamza-plus)
# ✔ Mr. Hamza Plus tamamlandı
#
# [2131/2165] Must Bowl by Migros (must-bowl-by-migros-q1j2)
# ✔ Must Bowl by Migros tamamlandı
#
# [2132/2165] Tost + (Kurtuluş) (tost-kurtulus)
# ✔ Tost + (Kurtuluş) tamamlandı
#
# [2133/2165] Bowl & More (bowl-and-more-lm09)
# ✔ Bowl & More tamamlandı
#
# [2134/2165] Tahin (tahin-esnv)
# ✔ Tahin tamamlandı
#
# [2135/2165] Eat Your Greens (eat-your-greens-a81d)
# ✔ Eat Your Greens tamamlandı
#
# [2136/2165] Bowl Department (bowl-department)
# ✔ Bowl Department tamamlandı
#
# [2137/2165] Soul Bowl (soul-bowl-qfiv)
# ✔ Soul Bowl tamamlandı
#
# [2138/2165] Happy Burger (happy-burger-eago)
# ✔ Happy Burger tamamlandı
#
# [2139/2165] Vegan Masa (vegan-masa)
# ✔ Vegan Masa tamamlandı
#
# [2140/2165] Pizza Vegas (pizza-vegas-f8ie)
# ✔ Pizza Vegas tamamlandı
#
# [2141/2165] Noodle House (noodle-house-tmsw)
# ✔ Noodle House tamamlandı
#
# [2142/2165] Falafel House (falafel-house)
# ✔ Falafel House tamamlandı
#
# [2143/2165] Güneş Kahvaltı Evi (gunes-kahvalti-evi-c2qk)
# ✔ Güneş Kahvaltı Evi tamamlandı
#
# [2144/2165] Leyna Falafel (leyna-falafel-v92d)
# ✔ Leyna Falafel tamamlandı
#
# [2145/2165] Daisy’s Bowls (daisys-bowls-voy5)
# ✔ Daisy’s Bowls tamamlandı
#
# [2146/2165] Rain Bowl (rain-bowl)
# ✔ Rain Bowl tamamlandı
#
# [2147/2165] Bowl Dente (bowl-dente-yfbm)
# ✔ Bowl Dente tamamlandı
#
# [2148/2165] Ziyafet Tavuklu Pilav (ziyafet-tavuklu-pilav)
# ✔ Ziyafet Tavuklu Pilav tamamlandı
#
# [2149/2165] Chocolate Waffle (chocolate-waffle-kvow)
# ✔ Chocolate Waffle tamamlandı
#
# [2150/2165] Always Waffle (always-waffle-h177)
# ✔ Always Waffle tamamlandı
#
# [2151/2165] Wowmix (wowmix)
# ✔ Wowmix tamamlandı
#
# [2152/2165] Pwb Peanut Waffle Belgium (pwb-peanut-waffle-belgium-mu9g)
# ✔ Pwb Peanut Waffle Belgium tamamlandı
#
# [2153/2165] Happy Waffle (happy-waffle-r4f0)
# ✔ Happy Waffle tamamlandı
#
# [2154/2165] Wafflecım 777 (wafflecim-777-xqsr)
# ✔ Wafflecım 777 tamamlandı
#
# [2155/2165] Lale Waffle & Kumpir (lale-waffle-and-kumpir-zzsd)
# ✔ Lale Waffle & Kumpir tamamlandı
#
# [2156/2165] Safiş Kumpir & Waffle (safis-kumpir-and-waffle)
# ✔ Safiş Kumpir & Waffle tamamlandı
#
# [2157/2165] Crispy Waffle (crispy-waffle-ev51)
# ✔ Crispy Waffle tamamlandı
#
# [2158/2165] Bunny Waffle (bunny-waffle)
# ✔ Bunny Waffle tamamlandı
#
# [2159/2165] Waffle House Special (waffle-house-special-kuvc)
# ✔ Waffle House Special tamamlandı
#
# [2160/2165] One Sweet (one-sweet)
# ✔ One Sweet tamamlandı
#
# [2161/2165] A Love Waffle (a-love-waffle-rb2f)
# ✔ A Love Waffle tamamlandı
#
# [2162/2165] Nuray Waffle (nuray-waffle-ofru)
# ✔ Nuray Waffle tamamlandı
#
# [2163/2165] Waffle Store (waffle-store-l0oq)
# ✔ Waffle Store tamamlandı
#
# [2164/2165] !Classo Dondurma & Waffle (classo-dondurma-and-waffle-byr7)
# ✔ !Classo Dondurma & Waffle tamamlandı
#
# [2165/2165] Granny's Waffles & Kumpir (grannys-waffles-and-kumpir-kz3x)
# ✔ Granny's Waffles & Kumpir tamamlandı
# ✅ TÜM RESTORANLAR TAMAMLANDI!

# %%
# New → Back
import pandas as pd
import requests
import csv
import time
import random
import os
import urllib.parse

INPUT_CSV = "../data/raw/links/restaurant_links.csv"
OUTPUT_CSV = "../data/raw/reviews/new_to_old_comments.csv"

df = pd.read_csv(INPUT_CSV)

# Restaurant-level columns
restaurant_columns = df.columns.tolist()

# The new column we will derive from the link
restaurant_columns_extended = restaurant_columns + ["restaurant_slug"]

# Review-level columns
review_columns = [
    "uuid", "reviewer_name", "reviewer_id",
    "overall_score", "restaurant_food_score", "rider_score",
    "text", "created_at", "like_count", "replies_count", "product_names"
]

# Output header
if not os.path.exists(OUTPUT_CSV):
    with open(OUTPUT_CSV, "w", newline="", encoding="utf-8-sig") as f:
        writer = csv.writer(f)
        writer.writerow(restaurant_columns_extended + review_columns)

records = df.to_dict(orient="records")

for i, restaurant in enumerate(records, 1):
    link = restaurant["link"]

    try:
        # vendor_id & slug
        parts = link.strip("/").split("/")
        if "restaurant" in parts:
            idx = parts.index("restaurant")
            vendor_id = parts[idx + 1]
            restaurant_slug = parts[idx + 2]
        else:
            vendor_id = parts[-2]
            restaurant_slug = parts[-1]

        # The Turkish name in the CSV file is PRESERVED.
        restaurant["vendor_id"] = vendor_id
        restaurant["restaurant_slug"] = restaurant_slug
        restaurant_name_tr = restaurant.get("restaurant_name", "")

        print(f"\n[{i}/{len(records)}] {restaurant_name_tr} ({restaurant_slug})")

        next_page = None
        total_yorum = 0

        while True:
            url = (
                f"https://reviews-api-tr.fd-api.com/reviews/vendor/{vendor_id}"
                f"?global_entity_id=YS_TR&limit=50&created_at=desc&has_dish=true"
            )

            if next_page:
                url += f"&nextPageKey={urllib.parse.quote(next_page)}"

            resp = requests.get(url, timeout=15)
            if resp.status_code != 200:
                print(f"  -> API hatası: {resp.status_code}")
                break

            data = resp.json()
            reviews = data.get("data", [])
            if not reviews:
                break

            with open(OUTPUT_CSV, "a", newline="", encoding="utf-8-sig") as f:
                writer = csv.writer(f)

                for r in reviews:
                    row_review = {
                        "uuid": r.get("uuid", ""),
                        "reviewer_name": r.get("reviewerName", ""),
                        "reviewer_id": r.get("reviewerId", ""),
                        "text": r.get("text", ""),
                        "created_at": r.get("createdAt", ""),
                        "like_count": r.get("likeCount", 0),
                        "replies_count": len(r.get("replies", [])),
                        "overall_score": "",
                        "restaurant_food_score": "",
                        "rider_score": "",
                        "product_names": ""
                    }

                    for rr in r.get("ratings", []):
                        topic = rr.get("topic", "").lower()
                        if topic == "overall":
                            row_review["overall_score"] = rr.get("score", "")
                        elif topic == "restaurant_food":
                            row_review["restaurant_food_score"] = rr.get("score", "")
                        elif topic == "rider":
                            row_review["rider_score"] = rr.get("score", "")

                    products = []
                    for p in r.get("productVariations", []) or []:
                        prod = p.get("product", {})
                        name = prod.get("defaultTitle", "")
                        if name:
                            products.append(name)

                    row_review["product_names"] = " | ".join(products)

                    # --- FINAL MERGED ROW ---
                    writer.writerow(
                        [restaurant[col] for col in restaurant_columns] +
                        [restaurant["restaurant_slug"]] +
                        [row_review[col] for col in review_columns]
                    )

            total_yorum += len(reviews)
            print(f"  → {len(reviews)} yorum eklendi (toplam {total_yorum})")

            next_page = data.get("nextPageKey")
            if not next_page:
                break

            time.sleep(random.uniform(3, 6))

        print(f"✔ {restaurant_name_tr}")

    except Exception as e:
        print("⚠ Hata:", e)
        time.sleep(5)
        continue

print("✅ TÜM RESTORANLAR TAMAMLANDI!")
# Out:
# [1/2165] Mis Balık Restaurant (mis-balik-restaurant)
#   → 50 yorum eklendi (toplam 50)
# ✔ Mis Balık Restaurant tamamlandı
#
# [2/2165] İstanbul Çiğ Köfte (istanbul-cig-kofte-p9zl)
#   → 11 yorum eklendi (toplam 11)
# ✔ İstanbul Çiğ Köfte tamamlandı
#
# [3/2165] Çınar Balık Izgara (cinar-balik-izgara)
#   → 16 yorum eklendi (toplam 16)
# ✔ Çınar Balık Izgara tamamlandı
#
# [4/2165] Karadeniz Balık Lokantası (karadeniz-balik-lokantasi-lhwv)
#   → 4 yorum eklendi (toplam 4)
# ✔ Karadeniz Balık Lokantası tamamlandı
#
# [5/2165] Küçükyalı Balıkçısı (kucukyali-balikcisi-tgvo)
#   → 50 yorum eklendi (toplam 50)
# ✔ Küçükyalı Balıkçısı tamamlandı
#
# [6/2165] Hepsi Meze & Sandviç Küçükyalı (hepsi-meze-and-sandvic-kucukyali)
#   → 50 yorum eklendi (toplam 50)
# ✔ Hepsi Meze & Sandviç Küçükyalı tamamlandı
#
# [7/2165] Balıkçı Selami (balikci-selami-znjl)
#   → 10 yorum eklendi (toplam 10)
# ✔ Balıkçı Selami tamamlandı
#
# [8/2165] Mavi Kıyı Balıkçısı (mavi-kiyi-balikcisi)
#   → 20 yorum eklendi (toplam 20)
# ✔ Mavi Kıyı Balıkçısı tamamlandı
#
# [9/2165] Urla Balıkçısı (urla-balikcisi-t360)
#   → 36 yorum eklendi (toplam 36)
# ✔ Urla Balıkçısı tamamlandı
#
# [10/2165] İstanbul Midye (istanbul-midye-nnt1)
#   → 14 yorum eklendi (toplam 14)
# ✔ İstanbul Midye tamamlandı
#
# [11/2165] Maltepe Şırdancısı (maltepe-sirdancisi)
#   → 32 yorum eklendi (toplam 32)
# ✔ Maltepe Şırdancısı tamamlandı
#
# [12/2165] Es Balık Evi (es-balik-evi)
#   → 50 yorum eklendi (toplam 50)
# ✔ Es Balık Evi tamamlandı
#
# [13/2165] İnci Balık (inci-balik-l1fg)
#   → 6 yorum eklendi (toplam 6)
# ✔ İnci Balık tamamlandı
#
# [14/2165] Adanalı Serra Dürüm (adanali-serra-durum)
# ✔ Adanalı Serra Dürüm tamamlandı
#
# [15/2165] Reşat Balık (resat-balik)
#   → 42 yorum eklendi (toplam 42)
# ✔ Reşat Balık tamamlandı
#
# [16/2165] Ken Sushi And More (ken-sushi-and-more)
#   → 50 yorum eklendi (toplam 50)
# ✔ Ken Sushi And More tamamlandı
#
# [17/2165] Balıkçı İrfan (balikci-irfan)
#   → 50 yorum eklendi (toplam 50)
# ✔ Balıkçı İrfan tamamlandı
#
# [18/2165] Dardenia Fish & Sushi (dardenia-fish-and-sushi-h3yt)
#   → 20 yorum eklendi (toplam 20)
# ✔ Dardenia Fish & Sushi tamamlandı
#
# [19/2165] Midyeci Yasin (midyeci-yasin-r0l2)
#   → 50 yorum eklendi (toplam 50)
# ✔ Midyeci Yasin tamamlandı
#
# [20/2165] Alkar Balık Izgara (alkar-balik-izgara-ximy)
#   → 50 yorum eklendi (toplam 50)
# ✔ Alkar Balık Izgara tamamlandı
#
# [21/2165] Tuzda Balık (tuzda-balik)
#   → 50 yorum eklendi (toplam 50)
# ✔ Tuzda Balık tamamlandı
#
# [22/2165] Fırtına Balık (firtina-balik)
#   → 2 yorum eklendi (toplam 2)
# ✔ Fırtına Balık tamamlandı
#
# [23/2165] Burger King (burger-king-nki0)
#   → 50 yorum eklendi (toplam 50)
# ✔ Burger King tamamlandı
#
# [24/2165] Frango Döner (frango-doner-yozu)
#   → 7 yorum eklendi (toplam 7)
# ✔ Frango Döner tamamlandı
#
# [25/2165] Arden Fried Chicken (arden-fried-chicken-mpwq)
#   → 50 yorum eklendi (toplam 50)
# ✔ Arden Fried Chicken tamamlandı
#
# [26/2165] Gurme Chefs Köz (gurme-chefs-koz)
#   → 19 yorum eklendi (toplam 19)
# ✔ Gurme Chefs Köz tamamlandı
#
# [27/2165] Carl's Jr. (carls-jr-f2h5)
#   → 50 yorum eklendi (toplam 50)
# ✔ Carl's Jr. tamamlandı
#
# [28/2165] Fried-Day Chicken (fried-day-chicken-nmdl)
#   → 8 yorum eklendi (toplam 8)
# ✔ Fried-Day Chicken tamamlandı
#
# [29/2165] Express Marmaris (express-marmaris)
#   → 50 yorum eklendi (toplam 50)
# ✔ Express Marmaris tamamlandı
#
# [30/2165] Burger Yiyelim (burger-yiyelim-ltaq)
#   → 50 yorum eklendi (toplam 50)
# ✔ Burger Yiyelim tamamlandı
#
# [31/2165] Mambos Burger (mambos-burger)
#   → 4 yorum eklendi (toplam 4)
# ✔ Mambos Burger tamamlandı
#
# [32/2165] Pattosan (pattosan)
#   → 50 yorum eklendi (toplam 50)
# ✔ Pattosan tamamlandı
#
# [33/2165] Burger Space (burger-space-qruc)
#   → 32 yorum eklendi (toplam 32)
# ✔ Burger Space tamamlandı
#
# [34/2165] James Burger (james-burger)
#   → 50 yorum eklendi (toplam 50)
# ✔ James Burger tamamlandı
#
# [35/2165] Saloon Burger (saloon-burger-qjfq)
#   → 50 yorum eklendi (toplam 50)
# ✔ Saloon Burger tamamlandı
#
# [36/2165] McDonald's (mcdonalds-q88l)
#   → 50 yorum eklendi (toplam 50)
# ✔ McDonald's tamamlandı
#
# [37/2165] Cantina Prime (cantina-prime)
#   → 50 yorum eklendi (toplam 50)
# ✔ Cantina Prime tamamlandı
#
# [38/2165] My Fried Chicken (my-fried-chicken-q4vq)
#   → 50 yorum eklendi (toplam 50)
# ✔ My Fried Chicken tamamlandı
#
# [39/2165] Hakan Büfe & Burger (hakan-bufe-and-burger)
#   → 50 yorum eklendi (toplam 50)
# ✔ Hakan Büfe & Burger tamamlandı
#
# [40/2165] Tavuk Dürüm Sofrası (tavuk-durum-sofrasi-z3gs)
#   → 50 yorum eklendi (toplam 50)
# ✔ Tavuk Dürüm Sofrası tamamlandı
#
# [41/2165] Cajun Corner (cajun-corner-euzr)
#   → 50 yorum eklendi (toplam 50)
# ✔ Cajun Corner tamamlandı
#
# [42/2165] Domino's Pizza (dominos-pizza-i8et)
#   → 50 yorum eklendi (toplam 50)
# ✔ Domino's Pizza tamamlandı
#
# [43/2165] Arby's (arbys-x24z)
#   → 50 yorum eklendi (toplam 50)
# ✔ Arby's tamamlandı
#
# [44/2165] Big Lou Burger (big-lou-burger)
#   → 50 yorum eklendi (toplam 50)
# ✔ Big Lou Burger tamamlandı
#
# [45/2165] Smash Burger B (smash-burger-b-z1hq)
#   → 50 yorum eklendi (toplam 50)
# ✔ Smash Burger B tamamlandı
#
# [46/2165] +1 Burger (1-burger-qa17)
#   → 50 yorum eklendi (toplam 50)
# ✔ +1 Burger tamamlandı
#
# [47/2165] Why Burger (why-burger)
#   → 47 yorum eklendi (toplam 47)
# ✔ Why Burger tamamlandı
#
# [48/2165] Three Monkeys (three-monkeys-hbq5)
#   → 50 yorum eklendi (toplam 50)
# ✔ Three Monkeys tamamlandı
#
# [49/2165] Daily Dana Burger & Steak (daily-dana-burger-and-steak-g671)
#   → 50 yorum eklendi (toplam 50)
# ✔ Daily Dana Burger & Steak tamamlandı
#
# [50/2165] Tek Büfe (tek-bufe-j6gm)
#   → 11 yorum eklendi (toplam 11)
# ✔ Tek Büfe tamamlandı
#
# [51/2165] Arjantin Burger (arjantin-burger-es06)
#   → 18 yorum eklendi (toplam 18)
# ✔ Arjantin Burger tamamlandı
#
# [52/2165] Burgerillas (burgerillas-l75d)
#   → 50 yorum eklendi (toplam 50)
# ✔ Burgerillas tamamlandı
#
# [53/2165] Coff's Cafe & Restaurant (coffs-cafe-and-restaurant)
#   → 34 yorum eklendi (toplam 34)
# ✔ Coff's Cafe & Restaurant tamamlandı
#
# [54/2165] Bro's Burger (bros-burger-jjcb)
#   → 50 yorum eklendi (toplam 50)
# ✔ Bro's Burger tamamlandı
#
# [55/2165] Hebe Burger (hebe-burger)
#   → 42 yorum eklendi (toplam 42)
# ✔ Hebe Burger tamamlandı
#
# [56/2165] Burger House (burger-house-f4zz)
#   → 4 yorum eklendi (toplam 4)
# ✔ Burger House tamamlandı
#
# [57/2165] Big Baker (big-baker-mcat)
#   → 8 yorum eklendi (toplam 8)
# ✔ Big Baker tamamlandı
#
# [58/2165] Meat Burger & Gurme Mutfak (meat-burger-and-gurme-mutfak-iusl)
#   → 50 yorum eklendi (toplam 50)
# ✔ Meat Burger & Gurme Mutfak tamamlandı
#
# [59/2165] Öztürkler Büfe (ozturkler-bufe)
#   → 18 yorum eklendi (toplam 18)
# ✔ Öztürkler Büfe tamamlandı
#
# [60/2165] Base Burger (base-burger)
#   → 37 yorum eklendi (toplam 37)
# ✔ Base Burger tamamlandı
#
# [61/2165] Tıka Basa (tika-basa-cm82)
#   → 10 yorum eklendi (toplam 10)
# ✔ Tıka Basa tamamlandı
#
# [62/2165] Maris Food (maris-food)
#   → 18 yorum eklendi (toplam 18)
# ✔ Maris Food tamamlandı
#
# [63/2165] Yess Burger (yess-burger)
# ✔ Yess Burger tamamlandı
#
# [64/2165] Santiago Burger (santiago-burger-f8i4)
#   → 50 yorum eklendi (toplam 50)
# ✔ Santiago Burger tamamlandı
#
# [65/2165] Santiago Burger (santiago-burger-bhje)
#   → 50 yorum eklendi (toplam 50)
# ✔ Santiago Burger tamamlandı
#
# [66/2165] Retro Burger & Salad & Dessert (retro-burger-and-salad-and-dessert)
#   → 50 yorum eklendi (toplam 50)
# ✔ Retro Burger & Salad & Dessert tamamlandı
#
# [67/2165] Tost Akademisi (tost-akademisi-upmd)
#   → 4 yorum eklendi (toplam 4)
# ✔ Tost Akademisi tamamlandı
#
# [68/2165] Texas Fried Chicken (texas-fried-chicken-yxha)
#   → 35 yorum eklendi (toplam 35)
# ✔ Texas Fried Chicken tamamlandı
#
# [69/2165] Vegas Burger (vegas-burger-zxiv)
#   → 28 yorum eklendi (toplam 28)
# ✔ Vegas Burger tamamlandı
#
# [70/2165] Packet Burger (packet-burger-ne7b)
#   → 16 yorum eklendi (toplam 16)
# ✔ Packet Burger tamamlandı
#
# [71/2165] Dükkan Büfe (dukkan-bufe)
#   → 12 yorum eklendi (toplam 12)
# ✔ Dükkan Büfe tamamlandı
#
# [72/2165] White Burger by Serhat Doğramacı (white-burger-by-serhat-dogramaci-es2c)
#   → 6 yorum eklendi (toplam 6)
# ✔ White Burger by Serhat Doğramacı tamamlandı
#
# [73/2165] Komagene Etsiz Çiğ Köfte (komagene-etsiz-cig-kofte-sh4q)
#   → 45 yorum eklendi (toplam 45)
# ✔ Komagene Etsiz Çiğ Köfte tamamlandı
#
# [74/2165] Klikya Çiğ Köfte (klikya-cig-kofte)
#   → 6 yorum eklendi (toplam 6)
# ✔ Klikya Çiğ Köfte tamamlandı
#
# [75/2165] Gazi Çiğ Köfte (gazi-cig-kofte-bltx)
#   → 50 yorum eklendi (toplam 50)
# ✔ Gazi Çiğ Köfte tamamlandı
#
# [76/2165] Meşhur Adıyaman Çiğ Köftecisi Ömer Aybak (meshur-adiyaman-cig-koftecisi-omer-aybak-tr3t)
#   → 18 yorum eklendi (toplam 18)
# ✔ Meşhur Adıyaman Çiğ Köftecisi Ömer Aybak tamamlandı
#
# [77/2165] Çiğ Köfteci Ömer Usta (cig-kofteci-omer-usta-mr8d)
#   → 29 yorum eklendi (toplam 29)
# ✔ Çiğ Köfteci Ömer Usta tamamlandı
#
# [78/2165] İstanbul Çiğ Köfte (istanbul-cig-kofte-p9zl)
#   → 11 yorum eklendi (toplam 11)
# ✔ İstanbul Çiğ Köfte tamamlandı
#
# [79/2165] Arsamiea Çiğ Köfte (arsamiea-cig-kofte-p19t)
#   → 10 yorum eklendi (toplam 10)
# ✔ Arsamiea Çiğ Köfte tamamlandı
#
# [80/2165] Oses Çiğ Köfte (oses-cig-kofte-krf9)
#   → 8 yorum eklendi (toplam 8)
# ✔ Oses Çiğ Köfte tamamlandı
#
# [81/2165] Çiğ Köfteci Ömer Usta (cig-kofteci-omer-usta-c10a)
#   → 9 yorum eklendi (toplam 9)
# ✔ Çiğ Köfteci Ömer Usta tamamlandı
#
# [82/2165] Piro El Yapımı Çiğ Köfte (piro-el-yapimi-cig-kofte-dnr6)
#   → 34 yorum eklendi (toplam 34)
# ✔ Piro El Yapımı Çiğ Köfte tamamlandı
#
# [83/2165] Adıyaman Çiğ Köftecisi (adiyaman-cig-koftecisi-ptug)
#   → 8 yorum eklendi (toplam 8)
# ✔ Adıyaman Çiğ Köftecisi tamamlandı
#
# [84/2165] Konyataş (konyatas-azlx)
#   → 50 yorum eklendi (toplam 50)
# ✔ Konyataş tamamlandı
#
# [85/2165] Kahta Çiğ Köfte (kahta-cig-kofte-yrw3)
#   → 2 yorum eklendi (toplam 2)
# ✔ Kahta Çiğ Köfte tamamlandı
#
# [86/2165] Arsamiea (arsamiea-jh0i)
#   → 50 yorum eklendi (toplam 50)
# ✔ Arsamiea tamamlandı
#
# [87/2165] Hepsi Meze & Sandviç Küçükyalı (hepsi-meze-and-sandvic-kucukyali)
#   → 50 yorum eklendi (toplam 50)
# ✔ Hepsi Meze & Sandviç Küçükyalı tamamlandı
#
# [88/2165] Meşhur Adıyaman Çiğ Köftecisi (meshur-adiyaman-cig-koftecisi-awrh)
#   → 15 yorum eklendi (toplam 15)
# ✔ Meşhur Adıyaman Çiğ Köftecisi tamamlandı
#
# [89/2165] Buhara Pide & Lahmacun (buhara-pide-and-lahmacun)
# ✔ Buhara Pide & Lahmacun tamamlandı
#
# [90/2165] Meşhur Çiğ Köfteci Ömür Usta (meshur-cig-kofteci-omur-usta)
#   → 50 yorum eklendi (toplam 50)
# ✔ Meşhur Çiğ Köfteci Ömür Usta tamamlandı
#
# [91/2165] Ziyafet Çiğ Köfte (ziyafet-cig-kofte-i2ki)
#   → 10 yorum eklendi (toplam 10)
# ✔ Ziyafet Çiğ Köfte tamamlandı
#
# [92/2165] Mr. Çiğ Köfte (mr-cig-kofte-u662)
#   → 7 yorum eklendi (toplam 7)
# ✔ Mr. Çiğ Köfte tamamlandı
#
# [93/2165] Köfteci Elifin Mutfağı (kofteci-elifin-mutfagi)
#   → 45 yorum eklendi (toplam 45)
# ✔ Köfteci Elifin Mutfağı tamamlandı
#
# [94/2165] Sepet Fast Food (sepet-fast-food)
#   → 20 yorum eklendi (toplam 20)
# ✔ Sepet Fast Food tamamlandı
#
# [95/2165] Çiğ Köfteci Aziz Usta (cig-kofteci-aziz-usta-pce9)
#   → 3 yorum eklendi (toplam 3)
# ✔ Çiğ Köfteci Aziz Usta tamamlandı
#
# [96/2165] Umur Çiğ Köfte (umur-cig-kofte)
# ✔ Umur Çiğ Köfte tamamlandı
#
# [97/2165] Çiğköftem (cigkoftem-lkmh)
#   → 8 yorum eklendi (toplam 8)
# ✔ Çiğköftem tamamlandı
#
# [98/2165] Mr. Çiğ Köfte (mr-cig-kofte-owpb)
# ✔ Mr. Çiğ Köfte tamamlandı
#
# [99/2165] İsot Lab Çiğ Köfte (isot-lab-cig-kofte)
#   → 17 yorum eklendi (toplam 17)
# ✔ İsot Lab Çiğ Köfte tamamlandı
#
# [100/2165] Sırrı Usta Çiğ Köfte (sirri-usta-cig-kofte-ou7w)
#   → 3 yorum eklendi (toplam 3)
# ✔ Sırrı Usta Çiğ Köfte tamamlandı
#
# [101/2165] Adıger Çiğköfte (adiger-cigkofte)
#   → 11 yorum eklendi (toplam 11)
# ✔ Adıger Çiğköfte tamamlandı
#
# [102/2165] Zarif Çiğ Köfte (zarif-cig-kofte-r5mo)
#   → 7 yorum eklendi (toplam 7)
# ✔ Zarif Çiğ Köfte tamamlandı
#
# [103/2165] Arsamiea Çiğ Köfte (arsamiea-cig-kofte-d9oi)
#   → 19 yorum eklendi (toplam 19)
# ✔ Arsamiea Çiğ Köfte tamamlandı
#
# [104/2165] Sırrı Usta Çiğ Köfte (sirri-usta-cig-kofte-fwpj)
#   → 38 yorum eklendi (toplam 38)
# ✔ Sırrı Usta Çiğ Köfte tamamlandı
#
# [105/2165] Tatlıses Çiğ Köfte (tatlises-cig-kofte-r2t1)
#   → 2 yorum eklendi (toplam 2)
# ✔ Tatlıses Çiğ Köfte tamamlandı
#
# [106/2165] Pide İstanbul (pide-istanbul)
#   → 11 yorum eklendi (toplam 11)
# ✔ Pide İstanbul tamamlandı
#
# [107/2165] Pilav Gurmesi (pilav-gurmesi)
#   → 1 yorum eklendi (toplam 1)
# ✔ Pilav Gurmesi tamamlandı
#
# [108/2165] Köz Biber Kebap & Lahmacun & Pide (koz-biber-kebap-and-lahmacun-and-pide-qqgl)
#   → 13 yorum eklendi (toplam 13)
# ✔ Köz Biber Kebap & Lahmacun & Pide tamamlandı
#
# [109/2165] Meşhur Adıyaman Çiğ Köftecisi (meshur-adiyaman-cig-koftecisi-k4cb)
#   → 3 yorum eklendi (toplam 3)
# ✔ Meşhur Adıyaman Çiğ Köftecisi tamamlandı
#
# [110/2165] Köfteca Doğal Çiğ Köfte (kofteca-dogal-cig-kofte)
#   → 50 yorum eklendi (toplam 50)
# ✔ Köfteca Doğal Çiğ Köfte tamamlandı
#
# [111/2165] Köfte Uzmanı (kofte-uzmani)
# ✔ Köfte Uzmanı tamamlandı
#
# [112/2165] Biberzade Çiğ Köfte (biberzade-cig-kofte-qx9p)
#   → 1 yorum eklendi (toplam 1)
# ✔ Biberzade Çiğ Köfte tamamlandı
#
# [113/2165] Meşhur Adıyamanlı Çiğ Köfteci Canan Şef (meshur-adiyamanli-cig-kofteci-canan-sef)
#   → 3 yorum eklendi (toplam 3)
# ✔ Meşhur Adıyamanlı Çiğ Köfteci Canan Şef tamamlandı
#
# [114/2165] Ustam Çiğ Köfte (ustam-cig-kofte-unb6)
#   → 5 yorum eklendi (toplam 5)
# ✔ Ustam Çiğ Köfte tamamlandı
#
# [115/2165] Ustam Çiğ Köfte (ustam-cig-kofte-j2t5)
#   → 26 yorum eklendi (toplam 26)
# ✔ Ustam Çiğ Köfte tamamlandı
#
# [116/2165] Çiğ Köfteci Sait (cig-kofteci-sait-c415)
#   → 1 yorum eklendi (toplam 1)
# ✔ Çiğ Köfteci Sait tamamlandı
#
# [117/2165] THE ANGRY CHEF (the-angry-chef)
#   → 2 yorum eklendi (toplam 2)
# ✔ THE ANGRY CHEF tamamlandı
#
# [118/2165] Berat Çiğ Köfte (berat-cig-kofte-ybkl)
# ✔ Berat Çiğ Köfte tamamlandı
#
# [119/2165] Çiğ Köfteci Ömer Usta Cevizli (cig-kofteci-omer-usta-cevizli)
# ✔ Çiğ Köfteci Ömer Usta Cevizli tamamlandı
#
# [120/2165] Çiğ Köfteci Ömer Usta (cig-kofteci-omer-usta-m297)
# ✔ Çiğ Köfteci Ömer Usta tamamlandı
#
# [121/2165] Çiğ Köfteci Sait (cig-kofteci-sait-sx4i)
#   → 4 yorum eklendi (toplam 4)
# ✔ Çiğ Köfteci Sait tamamlandı
#
# [122/2165] Bolulu Hasan Usta (bolulu-hasan-usta-agsz)
#   → 50 yorum eklendi (toplam 50)
# ✔ Bolulu Hasan Usta tamamlandı
#
# [123/2165] +1 Sandviç (1-sandvic-nz79)
#   → 50 yorum eklendi (toplam 50)
# ✔ +1 Sandviç tamamlandı
#
# [124/2165] Fıştık (fistik)
#   → 50 yorum eklendi (toplam 50)
# ✔ Fıştık tamamlandı
#
# [125/2165] Cremeria Milano (cremeria-milano-zirh)
#   → 5 yorum eklendi (toplam 5)
# ✔ Cremeria Milano tamamlandı
#
# [126/2165] Mado (mado-comb)
#   → 13 yorum eklendi (toplam 13)
# ✔ Mado tamamlandı
#
# [127/2165] Mua Gelatieri D'Italia (mua-gelatieri-ditalia-mfcz)
#   → 9 yorum eklendi (toplam 9)
# ✔ Mua Gelatieri D'Italia tamamlandı
#
# [128/2165] Serez Dondurmacısı Maltepe (serez-dondurmacisi-maltepe)
#   → 8 yorum eklendi (toplam 8)
# ✔ Serez Dondurmacısı Maltepe tamamlandı
#
# [129/2165] Baklavacı Güllüoğlu (baklavaci-gulluoglu-gzwu)
#   → 50 yorum eklendi (toplam 50)
# ✔ Baklavacı Güllüoğlu tamamlandı
#
# [130/2165] Vero Gelato Bostancı (vero-gelato-bostanci)
#   → 25 yorum eklendi (toplam 25)
# ✔ Vero Gelato Bostancı tamamlandı
#
# [131/2165] Serbele Meze (serbele-meze-r31o)
#   → 50 yorum eklendi (toplam 50)
# ✔ Serbele Meze tamamlandı
#
# [132/2165] Meşhur Gaziantep Baklavacısı Vakıf Usta (meshur-gaziantep-baklavacisi-vakif-usta)
#   → 6 yorum eklendi (toplam 6)
# ✔ Meşhur Gaziantep Baklavacısı Vakıf Usta tamamlandı
#
# [133/2165] Lu Gelato Bostancı (lu-gelato-bostanci)
#   → 27 yorum eklendi (toplam 27)
# ✔ Lu Gelato Bostancı tamamlandı
#
# [134/2165] Pan Dolce Gelato & Coffee (pan-dolce-gelato-and-coffee)
#   → 30 yorum eklendi (toplam 30)
# ✔ Pan Dolce Gelato & Coffee tamamlandı
#
# [135/2165] Meşhur Gaziantep Baklavacısı Mehmet Usta (meshur-gaziantep-baklavacisi-mehmet-usta)
#   → 2 yorum eklendi (toplam 2)
# ✔ Meşhur Gaziantep Baklavacısı Mehmet Usta tamamlandı
#
# [136/2165] Fıstıkzade Baklava & Tatlı (fistikzade-baklava-and-tatli)
#   → 11 yorum eklendi (toplam 11)
# ✔ Fıstıkzade Baklava & Tatlı tamamlandı
#
# [137/2165] Asiloğlu Baklava (asiloglu-baklava)
#   → 12 yorum eklendi (toplam 12)
# ✔ Asiloğlu Baklava tamamlandı
#
# [138/2165] Dondurmacı Güllüoğlu (dondurmaci-gulluoglu)
#   → 50 yorum eklendi (toplam 50)
# ✔ Dondurmacı Güllüoğlu tamamlandı
#
# [139/2165] Vardarlı Dondurma (vardarli-dondurma)
#   → 30 yorum eklendi (toplam 30)
# ✔ Vardarlı Dondurma tamamlandı
#
# [140/2165] Zarifzade Baklava (zarifzade-baklava)
#   → 50 yorum eklendi (toplam 50)
# ✔ Zarifzade Baklava tamamlandı
#
# [141/2165] Çınar Dondurma (cinar-dondurma-ofix)
#   → 41 yorum eklendi (toplam 41)
# ✔ Çınar Dondurma tamamlandı
#
# [142/2165] Hacıbey Tatlıcılık (hacibey-tatlicilik-mmh8)
#   → 21 yorum eklendi (toplam 21)
# ✔ Hacıbey Tatlıcılık tamamlandı
#
# [143/2165] Blue Ice Cream (blue-ice-cream-qlzs)
#   → 10 yorum eklendi (toplam 10)
# ✔ Blue Ice Cream tamamlandı
#
# [144/2165] Acil Dondurma (acil-dondurma)
# ✔ Acil Dondurma tamamlandı
#
# [145/2165] Lucio Gelato (lucio-gelato)
#   → 2 yorum eklendi (toplam 2)
# ✔ Lucio Gelato tamamlandı
#
# [146/2165] Yaşar Usta Sorbe Dondurma (yasar-usta-sorbe-dondurma)
# ✔ Yaşar Usta Sorbe Dondurma tamamlandı
#
# [147/2165] Etod Kumpir & Waffle & Dondurma (etod-kumpir-and-waffle-and-dondurma-cypw)
#   → 12 yorum eklendi (toplam 12)
# ✔ Etod Kumpir & Waffle & Dondurma tamamlandı
#
# [148/2165] Gülün Dondurma Dünyası Yaşar Usta (gulun-dondurma-dunyasi-yasar-usta)
# ✔ Gülün Dondurma Dünyası Yaşar Usta tamamlandı
#
# [149/2165] Nido Maraş Dondurma (nido-maras-dondurma)
# ✔ Nido Maraş Dondurma tamamlandı
#
# [150/2165] Nido Maraş Dondurma (nido-maras-dondurma-k1up)
# ✔ Nido Maraş Dondurma tamamlandı
#
# [151/2165] İkram Dondurma (ikram-dondurma-v6j8)
#   → 3 yorum eklendi (toplam 3)
# ✔ İkram Dondurma tamamlandı
#
# [152/2165] Hayri Usta Maraş Dondurma (hayri-usta-maras-dondurma)
#   → 1 yorum eklendi (toplam 1)
# ✔ Hayri Usta Maraş Dondurma tamamlandı
#
# [153/2165] Hacıbaşar Kebap & Baklava (hacibasar-kebap-and-baklava-e8wi)
#   → 50 yorum eklendi (toplam 50)
# ✔ Hacıbaşar Kebap & Baklava tamamlandı
#
# [154/2165] Starhan Pide & Döner (starhan-pide-and-doner)
#   → 50 yorum eklendi (toplam 50)
# ✔ Starhan Pide & Döner tamamlandı
#
# [155/2165] Dönerci Celal Usta (donerci-celal-usta-iqvo)
#   → 50 yorum eklendi (toplam 50)
# ✔ Dönerci Celal Usta tamamlandı
#
# [156/2165] Aboo Dürümcü Mahmut Usta (aboo-durumcu-mahmut-usta)
#   → 50 yorum eklendi (toplam 50)
# ✔ Aboo Dürümcü Mahmut Usta tamamlandı
#
# [157/2165] Çeltik Kebap & Lahmacun (celtik-kebap-and-lahmacun-ow5z)
#   → 50 yorum eklendi (toplam 50)
# ✔ Çeltik Kebap & Lahmacun tamamlandı
#
# [158/2165] As İskender Kebap (as-iskender-kebap)
#   → 50 yorum eklendi (toplam 50)
# ✔ As İskender Kebap tamamlandı
#
# [159/2165] Hatay Soslu Dürüm Evi (hatay-soslu-durum-evi-ynf3)
#   → 50 yorum eklendi (toplam 50)
# ✔ Hatay Soslu Dürüm Evi tamamlandı
#
# [160/2165] Maydonoz Döner (maydonoz-doner-u6xi)
#   → 50 yorum eklendi (toplam 50)
# ✔ Maydonoz Döner tamamlandı
#
# [161/2165] Tavukoloji (tavukoloji-udag)
#   → 50 yorum eklendi (toplam 50)
# ✔ Tavukoloji tamamlandı
#
# [162/2165] Kebo (kebo-twui)
#   → 50 yorum eklendi (toplam 50)
# ✔ Kebo tamamlandı
#
# [163/2165] Express Marmaris (express-marmaris)
#   → 50 yorum eklendi (toplam 50)
# ✔ Express Marmaris tamamlandı
#
# [164/2165] Hatto Döner (hatto-doner)
#   → 50 yorum eklendi (toplam 50)
# ✔ Hatto Döner tamamlandı
#
# [165/2165] Paşa Döner (pasa-doner-ski6)
#   → 34 yorum eklendi (toplam 34)
# ✔ Paşa Döner tamamlandı
#
# [166/2165] By Hatay Döner Dürüm (by-hatay-doner-durum)
#   → 5 yorum eklendi (toplam 5)
# ✔ By Hatay Döner Dürüm tamamlandı
#
# [167/2165] Kaplan Kebap(Zümrütevler) (kaplan-kebap-zumrutevler)
#   → 50 yorum eklendi (toplam 50)
# ✔ Kaplan Kebap(Zümrütevler) tamamlandı
#
# [168/2165] Döner Ustası Çetin Yalçın (doner-ustasi-cetin-yalcin-x2ot)
#   → 45 yorum eklendi (toplam 45)
# ✔ Döner Ustası Çetin Yalçın tamamlandı
#
# [169/2165] Öncü Döner (oncu-doner-gkfx)
#   → 50 yorum eklendi (toplam 50)
# ✔ Öncü Döner tamamlandı
#
# [170/2165] Tavuk Dürüm Sofrası (tavuk-durum-sofrasi-z3gs)
#   → 50 yorum eklendi (toplam 50)
# ✔ Tavuk Dürüm Sofrası tamamlandı
#
# [171/2165] HD İskender (hd-iskender-cp0c)
#   → 50 yorum eklendi (toplam 50)
# ✔ HD İskender tamamlandı
#
# [172/2165] Dürüm Max (durum-max-pe8k)
#   → 50 yorum eklendi (toplam 50)
# ✔ Dürüm Max tamamlandı
#
# [173/2165] Usta Dönerci (usta-donerci-xvp0)
#   → 50 yorum eklendi (toplam 50)
# ✔ Usta Dönerci tamamlandı
#
# [174/2165] Tek Büfe (tek-bufe-j6gm)
#   → 11 yorum eklendi (toplam 11)
# ✔ Tek Büfe tamamlandı
#
# [175/2165] Maltepe Zurna Dürüm (maltepe-zurna-durum)
#   → 46 yorum eklendi (toplam 46)
# ✔ Maltepe Zurna Dürüm tamamlandı
#
# [176/2165] Kardeşler Zurna Dürüm (kardesler-zurna-durum-e55n)
#   → 50 yorum eklendi (toplam 50)
# ✔ Kardeşler Zurna Dürüm tamamlandı
#
# [177/2165] İntiba Döner (intiba-doner-zlvo)
#   → 50 yorum eklendi (toplam 50)
# ✔ İntiba Döner tamamlandı
#
# [178/2165] Tarihi Demirci Döner Lokantası (tarihi-demirci-doner-lokantasi-n0t0)
#   → 22 yorum eklendi (toplam 22)
# ✔ Tarihi Demirci Döner Lokantası tamamlandı
#
# [179/2165] Hot Döner (hot-doner-xggd)
#   → 50 yorum eklendi (toplam 50)
# ✔ Hot Döner tamamlandı
#
# [180/2165] Frango Döner & Sauce (frango-doner-and-sauce-tay4)
#   → 35 yorum eklendi (toplam 35)
# ✔ Frango Döner & Sauce tamamlandı
#
# [181/2165] Yeniyo Döner (yeniyo-doner-fhtv)
#   → 50 yorum eklendi (toplam 50)
# ✔ Yeniyo Döner tamamlandı
#
# [182/2165] Deha Dürüm (deha-durum)
#   → 20 yorum eklendi (toplam 20)
# ✔ Deha Dürüm tamamlandı
#
# [183/2165] Kardeşim Zurna Dürüm (kardesim-zurna-durum-xzg9)
#   → 50 yorum eklendi (toplam 50)
# ✔ Kardeşim Zurna Dürüm tamamlandı
#
# [184/2165] Tek Büfe (tek-bufe-aspq)
#   → 50 yorum eklendi (toplam 50)
# ✔ Tek Büfe tamamlandı
#
# [185/2165] Bereket Döner (bereket-doner-i1x6)
#   → 50 yorum eklendi (toplam 50)
# ✔ Bereket Döner tamamlandı
#
# [186/2165] Şehzade Katık Dürüm (sehzade-katik-durum)
#   → 50 yorum eklendi (toplam 50)
# ✔ Şehzade Katık Dürüm tamamlandı
#
# [187/2165] Bursa İshakbey (bursa-ishakbey-xsy7)
#   → 50 yorum eklendi (toplam 50)
# ✔ Bursa İshakbey tamamlandı
#
# [188/2165] Deran Usta Hatay Döner (deran-usta-hatay-doner)
#   → 50 yorum eklendi (toplam 50)
# ✔ Deran Usta Hatay Döner tamamlandı
#
# [189/2165] Hatay Soslu Döner Evi (hatay-soslu-doner-evi)
#   → 50 yorum eklendi (toplam 50)
# ✔ Hatay Soslu Döner Evi tamamlandı
#
# [190/2165] Dönerci Ali Usta (donerci-ali-usta-gjrh)
#   → 29 yorum eklendi (toplam 29)
# ✔ Dönerci Ali Usta tamamlandı
#
# [191/2165] Kaplan Kebap (Küçükyalı) (kaplan-kebap-kucukyali)
#   → 50 yorum eklendi (toplam 50)
# ✔ Kaplan Kebap (Küçükyalı) tamamlandı
#
# [192/2165] Hacıoğlu (hacioglu-vj7e)
#   → 50 yorum eklendi (toplam 50)
# ✔ Hacıoğlu tamamlandı
#
# [193/2165] Tat Kebap (tat-kebap-t66e)
#   → 50 yorum eklendi (toplam 50)
# ✔ Tat Kebap tamamlandı
#
# [194/2165] Gülüm Döner & Lahmacun (gulum-doner-and-lahmacun)
#   → 6 yorum eklendi (toplam 6)
# ✔ Gülüm Döner & Lahmacun tamamlandı
#
# [195/2165] Özel Soslu Hatay Döneri (ozel-soslu-hatay-doneri)
#   → 50 yorum eklendi (toplam 50)
# ✔ Özel Soslu Hatay Döneri tamamlandı
#
# [196/2165] Baydöner İskender (baydoner-iskender-kwbl)
#   → 45 yorum eklendi (toplam 45)
# ✔ Baydöner İskender tamamlandı
#
# [197/2165] Karınca Kebap (karinca-kebap)
#   → 50 yorum eklendi (toplam 50)
# ✔ Karınca Kebap tamamlandı
#
# [198/2165] By Hatay Döner (by-hatay-doner-rzm7)
#   → 26 yorum eklendi (toplam 26)
# ✔ By Hatay Döner tamamlandı
#
# [199/2165] Dürüm Max (durum-max-rnwp)
#   → 50 yorum eklendi (toplam 50)
# ✔ Dürüm Max tamamlandı
#
# [200/2165] Akan Zurna & Döner (akan-zurna-and-doner)
#   → 11 yorum eklendi (toplam 11)
# ✔ Akan Zurna & Döner tamamlandı
#
# [201/2165] Acaip Soslu Döner (acaip-soslu-doner)
#   → 50 yorum eklendi (toplam 50)
# ✔ Acaip Soslu Döner tamamlandı
#
# [202/2165] Hatay Usulü Zurna Dürüm (hatay-usulu-zurna-durum-h8e3)
#   → 22 yorum eklendi (toplam 22)
# ✔ Hatay Usulü Zurna Dürüm tamamlandı
#
# [203/2165] Cajun Corner (cajun-corner-euzr)
#   → 50 yorum eklendi (toplam 50)
# ✔ Cajun Corner tamamlandı
#
# [204/2165] Tavuk Fakültesi (tavuk-fakultesi-o65k)
#   → 50 yorum eklendi (toplam 50)
# ✔ Tavuk Fakültesi tamamlandı
#
# [205/2165] Tavuk Dünyası (tavuk-dunyasi-hl5v)
#   → 50 yorum eklendi (toplam 50)
# ✔ Tavuk Dünyası tamamlandı
#
# [206/2165] Garden Gurme (garden-gurme)
#   → 50 yorum eklendi (toplam 50)
# ✔ Garden Gurme tamamlandı
#
# [207/2165] Green Salads (green-salads-l5yb)
#   → 50 yorum eklendi (toplam 50)
# ✔ Green Salads tamamlandı
#
# [208/2165] Bowl Lab (bowl-lab)
#   → 50 yorum eklendi (toplam 50)
# ✔ Bowl Lab tamamlandı
#
# [209/2165] Cantina Prime (cantina-prime)
#   → 50 yorum eklendi (toplam 50)
# ✔ Cantina Prime tamamlandı
#
# [210/2165] Must Bowl by Migros (must-bowl-by-migros-t1ah)
#   → 50 yorum eklendi (toplam 50)
# ✔ Must Bowl by Migros tamamlandı
#
# [211/2165] Coff's Cafe & Restaurant (coffs-cafe-and-restaurant)
#   → 34 yorum eklendi (toplam 34)
# ✔ Coff's Cafe & Restaurant tamamlandı
#
# [212/2165] Smash Burger B (smash-burger-b-z1hq)
#   → 50 yorum eklendi (toplam 50)
# ✔ Smash Burger B tamamlandı
#
# [213/2165] Pastacı Hamdi (pastaci-hamdi)
#   → 50 yorum eklendi (toplam 50)
# ✔ Pastacı Hamdi tamamlandı
#
# [214/2165] Cookshop (cookshop-r2fs)
#   → 24 yorum eklendi (toplam 24)
# ✔ Cookshop tamamlandı
#
# [215/2165] KitchenDo (kitchendo)
#   → 50 yorum eklendi (toplam 50)
# ✔ KitchenDo tamamlandı
#
# [216/2165] Bowl & Bowl (bowl-and-bowl-aw0q)
#   → 21 yorum eklendi (toplam 21)
# ✔ Bowl & Bowl tamamlandı
#
# [217/2165] The Granma Food & Coffee (the-granma-food-and-coffee)
#   → 33 yorum eklendi (toplam 33)
# ✔ The Granma Food & Coffee tamamlandı
#
# [218/2165] Bowl Kase (bowl-kase-hd88)
#   → 25 yorum eklendi (toplam 25)
# ✔ Bowl Kase tamamlandı
#
# [219/2165] Timboo Cafe (timboo-cafe)
#   → 16 yorum eklendi (toplam 16)
# ✔ Timboo Cafe tamamlandı
#
# [220/2165] Bowl & More (bowl-and-more-lrip)
#   → 50 yorum eklendi (toplam 50)
# ✔ Bowl & More tamamlandı
#
# [221/2165] Schnitzel Art (schnitzel-art-efh6)
#   → 50 yorum eklendi (toplam 50)
# ✔ Schnitzel Art tamamlandı
#
# [222/2165] Akça Pasta & Cafe & Restaurant (akca-pasta-and-cafe-and-restaurant)
#   → 19 yorum eklendi (toplam 19)
# ✔ Akça Pasta & Cafe & Restaurant tamamlandı
#
# [223/2165] Tazedirekt Mutfak (tazedirekt-mutfak)
#   → 33 yorum eklendi (toplam 33)
# ✔ Tazedirekt Mutfak tamamlandı
#
# [224/2165] Let's Salad (lets-salad-rc7k)
#   → 42 yorum eklendi (toplam 42)
# ✔ Let's Salad tamamlandı
#
# [225/2165] Gina Bowl (gina-bowl-mz9t)
#   → 50 yorum eklendi (toplam 50)
# ✔ Gina Bowl tamamlandı
#
# [226/2165] Mev Mutfak (mev-mutfak-bls1)
#   → 50 yorum eklendi (toplam 50)
# ✔ Mev Mutfak tamamlandı
#
# [227/2165] Food Nook Roll & Sandwiches (food-nook-roll-and-sandwiches)
#   → 50 yorum eklendi (toplam 50)
# ✔ Food Nook Roll & Sandwiches tamamlandı
#
# [228/2165] Sultan Döner Kebap & Lahmacun (sultan-doner-kebap-and-lahmacun)
#   → 42 yorum eklendi (toplam 42)
# ✔ Sultan Döner Kebap & Lahmacun tamamlandı
#
# [229/2165] Mado (mado-comb)
#   → 13 yorum eklendi (toplam 13)
# ✔ Mado tamamlandı
#
# [230/2165] Bodrum Mantı & Cafe (bodrum-manti-and-cafe-tt4n)
#   → 42 yorum eklendi (toplam 42)
# ✔ Bodrum Mantı & Cafe tamamlandı
#
# [231/2165] Filifu Cafe (filifu-cafe)
#   → 19 yorum eklendi (toplam 19)
# ✔ Filifu Cafe tamamlandı
#
# [232/2165] Big Chefs (big-chefs-i0fd)
#   → 33 yorum eklendi (toplam 33)
# ✔ Big Chefs tamamlandı
#
# [233/2165] Natura Prime (natura-prime)
#   → 6 yorum eklendi (toplam 6)
# ✔ Natura Prime tamamlandı
#
# [234/2165] Makarna Company (makarna-company-gob9)
#   → 29 yorum eklendi (toplam 29)
# ✔ Makarna Company tamamlandı
#
# [235/2165] Bowllife (bowllife)
#   → 50 yorum eklendi (toplam 50)
# ✔ Bowllife tamamlandı
#
# [236/2165] Gurme Mutfak Ev Yemekleri (gurme-mutfak-ev-yemekleri-lz14)
#   → 4 yorum eklendi (toplam 4)
# ✔ Gurme Mutfak Ev Yemekleri tamamlandı
#
# [237/2165] Leyla Anne Ev Yemekleri (leyla-anne-ev-yemekleri-eqls)
#   → 14 yorum eklendi (toplam 14)
# ✔ Leyla Anne Ev Yemekleri tamamlandı
#
# [238/2165] Schnitzel Art (schnitzel-art-u8qu)
#   → 29 yorum eklendi (toplam 29)
# ✔ Schnitzel Art tamamlandı
#
# [239/2165] Güneş Kahvaltı Evi (gunes-kahvalti-evi-vc6p)
#   → 43 yorum eklendi (toplam 43)
# ✔ Güneş Kahvaltı Evi tamamlandı
#
# [240/2165] Salad Town (salad-town-r2to)
#   → 10 yorum eklendi (toplam 10)
# ✔ Salad Town tamamlandı
#
# [241/2165] Nammos (nammos-ki83)
#   → 10 yorum eklendi (toplam 10)
# ✔ Nammos tamamlandı
#
# [242/2165] Cafe dlento (cafe-dlento)
#   → 3 yorum eklendi (toplam 3)
# ✔ Cafe dlento tamamlandı
#
# [243/2165] Paul's Lazanya (pauls-lazanya)
#   → 50 yorum eklendi (toplam 50)
# ✔ Paul's Lazanya tamamlandı
#
# [244/2165] The Rhythm Of Pasta Mambos (the-rhythm-of-pasta-mambos)
#   → 14 yorum eklendi (toplam 14)
# ✔ The Rhythm Of Pasta Mambos tamamlandı
#
# [245/2165] Boshi-Co Balkan Mutfağı (boshi-co-balkan-mutfagi)
#   → 8 yorum eklendi (toplam 8)
# ✔ Boshi-Co Balkan Mutfağı tamamlandı
#
# [246/2165] Tacofit (tacofit-y1m0)
#   → 7 yorum eklendi (toplam 7)
# ✔ Tacofit tamamlandı
#
# [247/2165] Japon Uzakdoğu Mutfağı (japon-uzakdogu-mutfagi)
#   → 50 yorum eklendi (toplam 50)
# ✔ Japon Uzakdoğu Mutfağı tamamlandı
#
# [248/2165] Ethique Patisserie & Boulangerie (ethique-patisserie-and-boulangerie)
#   → 50 yorum eklendi (toplam 50)
# ✔ Ethique Patisserie & Boulangerie tamamlandı
#
# [249/2165] Wrap Republic (wrap-republic)
#   → 12 yorum eklendi (toplam 12)
# ✔ Wrap Republic tamamlandı
#
# [250/2165] Lebon Gurme (lebon-gurme)
#   → 6 yorum eklendi (toplam 6)
# ✔ Lebon Gurme tamamlandı
#
# [251/2165] Chef Ayşe (chef-ayse)
#   → 8 yorum eklendi (toplam 8)
# ✔ Chef Ayşe tamamlandı
#
# [252/2165] Taze Kase (taze-kase-e2v7)
#   → 4 yorum eklendi (toplam 4)
# ✔ Taze Kase tamamlandı
#
# [253/2165] Moston Ev Yemekleri (moston-ev-yemekleri)
#   → 50 yorum eklendi (toplam 50)
# ✔ Moston Ev Yemekleri tamamlandı
#
# [254/2165] Kavurmacı Hasan Usta (kavurmaci-hasan-usta-ixoq)
#   → 50 yorum eklendi (toplam 50)
# ✔ Kavurmacı Hasan Usta tamamlandı
#
# [255/2165] İskender Köfteci (iskender-kofteci)
#   → 15 yorum eklendi (toplam 15)
# ✔ İskender Köfteci tamamlandı
#
# [256/2165] Köylüm Gözleme & Kahvaltı (koylum-gozleme-and-kahvalti)
#   → 50 yorum eklendi (toplam 50)
# ✔ Köylüm Gözleme & Kahvaltı tamamlandı
#
# [257/2165] Pilav Noktası (pilav-noktasi)
#   → 50 yorum eklendi (toplam 50)
# ✔ Pilav Noktası tamamlandı
#
# [258/2165] Tavuk Kampüsü (tavuk-kampusu-s6my)
#   → 50 yorum eklendi (toplam 50)
# ✔ Tavuk Kampüsü tamamlandı
#
# [259/2165] Adile Sultan Ev Yemekleri (adile-sultan-ev-yemekleri-r2kp)
#   → 50 yorum eklendi (toplam 50)
# ✔ Adile Sultan Ev Yemekleri tamamlandı
#
# [260/2165] Meydan Kokoreç & İşkembe (meydan-kokorec-and-iskembe-meba)
#   → 50 yorum eklendi (toplam 50)
# ✔ Meydan Kokoreç & İşkembe tamamlandı
#
# [261/2165] Tavuk Dürüm Sofrası (tavuk-durum-sofrasi-z3gs)
#   → 50 yorum eklendi (toplam 50)
# ✔ Tavuk Dürüm Sofrası tamamlandı
#
# [262/2165] Çorba Molası (corba-molasi-yqp3)
#   → 17 yorum eklendi (toplam 17)
# ✔ Çorba Molası tamamlandı
#
# [263/2165] Şölen Çorba 7/24 (solen-corba-7-24)
#   → 27 yorum eklendi (toplam 27)
# ✔ Şölen Çorba 7/24 tamamlandı
#
# [264/2165] Tarihi Maltepe Çorbacısı (tarihi-maltepe-corbacisi-i1w0)
#   → 50 yorum eklendi (toplam 50)
# ✔ Tarihi Maltepe Çorbacısı tamamlandı
#
# [265/2165] Çorbistan (corbistan)
#   → 16 yorum eklendi (toplam 16)
# ✔ Çorbistan tamamlandı
#
# [266/2165] Kafalti Meze & Şarküteri (kafalti-meze-and-sarkuteri-zxzi)
#   → 30 yorum eklendi (toplam 30)
# ✔ Kafalti Meze & Şarküteri tamamlandı
#
# [267/2165] Çinilihan Mutfağı (cinilihan-mutfagi)
#   → 50 yorum eklendi (toplam 50)
# ✔ Çinilihan Mutfağı tamamlandı
#
# [268/2165] Gurme Mutfak Ev Yemekleri (gurme-mutfak-ev-yemekleri-lz14)
#   → 4 yorum eklendi (toplam 4)
# ✔ Gurme Mutfak Ev Yemekleri tamamlandı
#
# [269/2165] Aras Ev Lezzetleri (aras-ev-lezzetleri)
#   → 28 yorum eklendi (toplam 28)
# ✔ Aras Ev Lezzetleri tamamlandı
#
# [270/2165] Lezzet Lokantası (lezzet-lokantasi-c0gq)
#   → 34 yorum eklendi (toplam 34)
# ✔ Lezzet Lokantası tamamlandı
#
# [271/2165] Sevgi Lokantası Ev Yemekleri (sevgi-lokantasi-ev-yemekleri-jf8i)
#   → 15 yorum eklendi (toplam 15)
# ✔ Sevgi Lokantası Ev Yemekleri tamamlandı
#
# [272/2165] Yağlama & Mantı Evi (yaglama-and-manti-evi)
#   → 27 yorum eklendi (toplam 27)
# ✔ Yağlama & Mantı Evi tamamlandı
#
# [273/2165] Leyla Anne Ev Yemekleri (leyla-anne-ev-yemekleri-eqls)
#   → 14 yorum eklendi (toplam 14)
# ✔ Leyla Anne Ev Yemekleri tamamlandı
#
# [274/2165] Erenler Et Lokantası (erenler-et-lokantasi)
#   → 19 yorum eklendi (toplam 19)
# ✔ Erenler Et Lokantası tamamlandı
#
# [275/2165] Agapia Mezze (agapia-mezze-go95)
#   → 50 yorum eklendi (toplam 50)
# ✔ Agapia Mezze tamamlandı
#
# [276/2165] Adile Hanımın Mutfağı (adile-hanimin-mutfagi)
#   → 8 yorum eklendi (toplam 8)
# ✔ Adile Hanımın Mutfağı tamamlandı
#
# [277/2165] Altın Tencere Ev Yemekleri (altin-tencere-ev-yemekleri-fbir)
#   → 17 yorum eklendi (toplam 17)
# ✔ Altın Tencere Ev Yemekleri tamamlandı
#
# [278/2165] Mezelerce (mezelerce-gau6)
#   → 7 yorum eklendi (toplam 7)
# ✔ Mezelerce tamamlandı
#
# [279/2165] Envai Karaköy Lokantası (envai-karakoy-lokantasi-fofm)
#   → 9 yorum eklendi (toplam 9)
# ✔ Envai Karaköy Lokantası tamamlandı
#
# [280/2165] Salatsa (salatsa)
#   → 2 yorum eklendi (toplam 2)
# ✔ Salatsa tamamlandı
#
# [281/2165] Nostalji Ev Yemekleri (nostalji-ev-yemekleri)
#   → 14 yorum eklendi (toplam 14)
# ✔ Nostalji Ev Yemekleri tamamlandı
#
# [282/2165] Kısıklı Çorbacısı (kisikli-corbacisi)
#   → 5 yorum eklendi (toplam 5)
# ✔ Kısıklı Çorbacısı tamamlandı
#
# [283/2165] Katibe Hanım Ev Yemekleri (katibe-hanim-ev-yemekleri-zdlg)
#   → 50 yorum eklendi (toplam 50)
# ✔ Katibe Hanım Ev Yemekleri tamamlandı
#
# [284/2165] Maltepe Mantı Evi (maltepe-manti-evi)
#   → 31 yorum eklendi (toplam 31)
# ✔ Maltepe Mantı Evi tamamlandı
#
# [285/2165] Bol Kepçe Ev Yemekleri (bol-kepce-ev-yemekleri-w6kd)
#   → 16 yorum eklendi (toplam 16)
# ✔ Bol Kepçe Ev Yemekleri tamamlandı
#
# [286/2165] Meze İstanbul (meze-istanbul)
#   → 32 yorum eklendi (toplam 32)
# ✔ Meze İstanbul tamamlandı
#
# [287/2165] Şu Pilav (su-pilav)
#   → 9 yorum eklendi (toplam 9)
# ✔ Şu Pilav tamamlandı
#
# [288/2165] Köylü Kızı Ev Yemekleri (koylu-kizi-ev-yemekleri)
#   → 1 yorum eklendi (toplam 1)
# ✔ Köylü Kızı Ev Yemekleri tamamlandı
#
# [289/2165] Annenin Ev Yemekleri (annenin-ev-yemekleri-iw95)
#   → 3 yorum eklendi (toplam 3)
# ✔ Annenin Ev Yemekleri tamamlandı
#
# [290/2165] Tokana Mantı (tokana-manti-w09l)
# ✔ Tokana Mantı tamamlandı
#
# [291/2165] Rukiye Teyze Ev Yemekleri (rukiye-teyze-ev-yemekleri-yn6r)
#   → 30 yorum eklendi (toplam 30)
# ✔ Rukiye Teyze Ev Yemekleri tamamlandı
#
# [292/2165] Turkuaz Ev Yemekleri & Tatlı (turkuaz-ev-yemekleri-and-tatli)
# ✔ Turkuaz Ev Yemekleri & Tatlı tamamlandı
#
# [293/2165] Reyhani Ev Yemekleri (reyhani-ev-yemekleri-b7m7)
# ✔ Reyhani Ev Yemekleri tamamlandı
#
# [294/2165] Mahmut Usta Ev Yemekleri (mahmut-usta-ev-yemekleri)
# ✔ Mahmut Usta Ev Yemekleri tamamlandı
#
# [295/2165] Mantı Dünyası (manti-dunyasi-elat)
# ✔ Mantı Dünyası tamamlandı
#
# [296/2165] Bientat Gastronomi (bientat-gastronomi-vegv)
# ✔ Bientat Gastronomi tamamlandı
#
# [297/2165] Meze Sofrası (meze-sofrasi-pn7p)
# ✔ Meze Sofrası tamamlandı
#
# [298/2165] Mantı Hane (manti-hane-rl3j)
# ✔ Mantı Hane tamamlandı
#
# [299/2165] Diyardan Çorba (diyardan-corba-pmhx)
# ✔ Diyardan Çorba tamamlandı
#
# [300/2165] Tarihi Karadeniz Sütlaç (tarihi-karadeniz-sutlac)
# ✔ Tarihi Karadeniz Sütlaç tamamlandı
#
# [301/2165] Arwen Cafe (arwen-cafe)
# ✔ Arwen Cafe tamamlandı
#
# [302/2165] Öz Cemil Usta (oz-cemil-usta)
#   → 9 yorum eklendi (toplam 9)
# ✔ Öz Cemil Usta tamamlandı
#
# [303/2165] Express Marmaris (express-marmaris)
#   → 50 yorum eklendi (toplam 50)
# ✔ Express Marmaris tamamlandı
#
# [304/2165] The Granma Food & Coffee (the-granma-food-and-coffee)
#   → 33 yorum eklendi (toplam 33)
# ✔ The Granma Food & Coffee tamamlandı
#
# [305/2165] Köfteci Yusuf (kofteci-yusuf-hrh4)
#   → 50 yorum eklendi (toplam 50)
# ✔ Köfteci Yusuf tamamlandı
#
# [306/2165] Köylüm Gözleme & Kahvaltı (koylum-gozleme-and-kahvalti)
#   → 50 yorum eklendi (toplam 50)
# ✔ Köylüm Gözleme & Kahvaltı tamamlandı
#
# [307/2165] İskender Köfteci (iskender-kofteci)
#   → 15 yorum eklendi (toplam 15)
# ✔ İskender Köfteci tamamlandı
#
# [308/2165] Fıstıkâlâ  Baklava & Börek (fistikala-baklava-and-borek)
#   → 30 yorum eklendi (toplam 30)
# ✔ Fıstıkâlâ  Baklava & Börek tamamlandı
#
# [309/2165] Kuğu Pastanesi (kugu-pastanesi-u34d)
#   → 50 yorum eklendi (toplam 50)
# ✔ Kuğu Pastanesi tamamlandı
#
# [310/2165] Lotus Croissant & Breakfast (lotus-croissant-and-breakfast)
#   → 50 yorum eklendi (toplam 50)
# ✔ Lotus Croissant & Breakfast tamamlandı
#
# [311/2165] Fıstıkname Baklava & Börek (fistikname-baklava-and-borek)
#   → 50 yorum eklendi (toplam 50)
# ✔ Fıstıkname Baklava & Börek tamamlandı
#
# [312/2165] Kızçe Çi Börek (kizce-ci-borek)
#   → 50 yorum eklendi (toplam 50)
# ✔ Kızçe Çi Börek tamamlandı
#
# [313/2165] Meşhur Sarıyer Börekçisi (meshur-sariyer-borekcisi-xtt7)
#   → 28 yorum eklendi (toplam 28)
# ✔ Meşhur Sarıyer Börekçisi tamamlandı
#
# [314/2165] Yalı Kavurmacısı (yali-kavurmacisi)
#   → 50 yorum eklendi (toplam 50)
# ✔ Yalı Kavurmacısı tamamlandı
#
# [315/2165] Simit Sarayı (simit-sarayi-ztoz)
#   → 50 yorum eklendi (toplam 50)
# ✔ Simit Sarayı tamamlandı
#
# [316/2165] Caleo Coffee & Bakery (caleo-coffee-and-bakery)
#   → 50 yorum eklendi (toplam 50)
# ✔ Caleo Coffee & Bakery tamamlandı
#
# [317/2165] Gurme Chefs Köz (gurme-chefs-koz)
#   → 19 yorum eklendi (toplam 19)
# ✔ Gurme Chefs Köz tamamlandı
#
# [318/2165] Mir Börek & Cafe (mir-borek-and-cafe-vyy6)
#   → 15 yorum eklendi (toplam 15)
# ✔ Mir Börek & Cafe tamamlandı
#
# [319/2165] Zeynep Şef Mantı & Gözleme (zeynep-sef-manti-and-gozleme)
#   → 50 yorum eklendi (toplam 50)
# ✔ Zeynep Şef Mantı & Gözleme tamamlandı
#
# [320/2165] Maltepe Tostçusu Waffle & Magnolia (maltepe-tostcusu-waffle-and-magnolia)
#   → 35 yorum eklendi (toplam 35)
# ✔ Maltepe Tostçusu Waffle & Magnolia tamamlandı
#
# [321/2165] Özsüt (ozsut-rtsy)
#   → 24 yorum eklendi (toplam 24)
# ✔ Özsüt tamamlandı
#
# [322/2165] Güneş Kahvaltı Evi (gunes-kahvalti-evi-vc6p)
#   → 43 yorum eklendi (toplam 43)
# ✔ Güneş Kahvaltı Evi tamamlandı
#
# [323/2165] Pate Mantı & Çi Börek (pate-manti-and-ci-borek)
#   → 37 yorum eklendi (toplam 37)
# ✔ Pate Mantı & Çi Börek tamamlandı
#
# [324/2165] Manolya Pastanesi (manolya-pastanesi-i2j7)
#   → 50 yorum eklendi (toplam 50)
# ✔ Manolya Pastanesi tamamlandı
#
# [325/2165] Çengelköy Börekçisi (cengelkoy-borekcisi-iuuf)
#   → 1 yorum eklendi (toplam 1)
# ✔ Çengelköy Börekçisi tamamlandı
#
# [326/2165] Panista Tost (panista-tost-jw5k)
# ✔ Panista Tost tamamlandı
#
# [327/2165] Simit Mi? Gevrek Mi? (simit-mi-gevrek-mi)
#   → 19 yorum eklendi (toplam 19)
# ✔ Simit Mi? Gevrek Mi? tamamlandı
#
# [328/2165] Simit Omlet (simit-omlet)
#   → 8 yorum eklendi (toplam 8)
# ✔ Simit Omlet tamamlandı
#
# [329/2165] Bolulu Rıfat Usta Neşeli Köfte (bolulu-rifat-usta-neseli-kofte)
# ✔ Bolulu Rıfat Usta Neşeli Köfte tamamlandı
#
# [330/2165] Galata Kahvaltıcısı (galata-kahvalticisi)
#   → 39 yorum eklendi (toplam 39)
# ✔ Galata Kahvaltıcısı tamamlandı
#
# [331/2165] Pişi Omlet (pisi-omlet)
#   → 2 yorum eklendi (toplam 2)
# ✔ Pişi Omlet tamamlandı
#
# [332/2165] Panetto Pasta & Cafe (panetto-pasta-and-cafe)
#   → 50 yorum eklendi (toplam 50)
# ✔ Panetto Pasta & Cafe tamamlandı
#
# [333/2165] Aşk-ı Kahvaltı (ask-i-kahvalti-gmmi)
#   → 2 yorum eklendi (toplam 2)
# ✔ Aşk-ı Kahvaltı tamamlandı
#
# [334/2165] Fıstıkzade Baklava & Tatlı (fistikzade-baklava-and-tatli)
#   → 11 yorum eklendi (toplam 11)
# ✔ Fıstıkzade Baklava & Tatlı tamamlandı
#
# [335/2165] Manolya Pastanesi Kayışdağı (manolya-pastanesi-kayisdagi)
#   → 25 yorum eklendi (toplam 25)
# ✔ Manolya Pastanesi Kayışdağı tamamlandı
#
# [336/2165] Tarabya Kumrucusu 1994 (tarabya-kumrucusu-1994)
#   → 1 yorum eklendi (toplam 1)
# ✔ Tarabya Kumrucusu 1994 tamamlandı
#
# [337/2165] Ulviye Börek (ulviye-borek)
#   → 48 yorum eklendi (toplam 48)
# ✔ Ulviye Börek tamamlandı
#
# [338/2165] Tarihi Pembegül Pastanesi (tarihi-pembegul-pastanesi)
#   → 6 yorum eklendi (toplam 6)
# ✔ Tarihi Pembegül Pastanesi tamamlandı
#
# [339/2165] Köylü Kızı Gözleme (koylu-kizi-gozleme)
#   → 16 yorum eklendi (toplam 16)
# ✔ Köylü Kızı Gözleme tamamlandı
#
# [340/2165] C1 Coffee & Lounge (c1-coffee-and-lounge)
#   → 6 yorum eklendi (toplam 6)
# ✔ C1 Coffee & Lounge tamamlandı
#
# [341/2165] By Puli (by-puli)
# ✔ By Puli tamamlandı
#
# [342/2165] Bi Gözleme Kahvaltı & Mantı Evi (bi-gozleme-kahvalti-and-manti-evi)
#   → 50 yorum eklendi (toplam 50)
# ✔ Bi Gözleme Kahvaltı & Mantı Evi tamamlandı
#
# [343/2165] Bayraktar Gaziantep Baklava (bayraktar-gaziantep-baklava)
#   → 2 yorum eklendi (toplam 2)
# ✔ Bayraktar Gaziantep Baklava tamamlandı
#
# [344/2165] Lokmano (lokmano)
#   → 1 yorum eklendi (toplam 1)
# ✔ Lokmano tamamlandı
#
# [345/2165] Elit Patso (elit-patso)
# ✔ Elit Patso tamamlandı
#
# [346/2165] Acil Pilav (acil-pilav-x11u)
# ✔ Acil Pilav tamamlandı
#
# [347/2165] Mis Börek (mis-borek-ufq8)
# ✔ Mis Börek tamamlandı
#
# [348/2165] Acil Börek (acil-borek)
# ✔ Acil Börek tamamlandı
#
# [349/2165] Acil Ciğer (acil-ciger-szkd)
# ✔ Acil Ciğer tamamlandı
#
# [350/2165] California Wrap (california-wrap)
# ✔ California Wrap tamamlandı
#
# [351/2165] Börekhane (borekhane-kybg)
# ✔ Börekhane tamamlandı
#
# [352/2165] Dönerix (donerix-t59w)
# ✔ Dönerix tamamlandı
#
# [353/2165] Starbucks Coffee (starbucks-coffee-sudm)
#   → 50 yorum eklendi (toplam 50)
# ✔ Starbucks Coffee tamamlandı
#
# [354/2165] The Granma Food & Coffee (the-granma-food-and-coffee)
#   → 33 yorum eklendi (toplam 33)
# ✔ The Granma Food & Coffee tamamlandı
#
# [355/2165] Coffy (coffy-uq7h)
#   → 50 yorum eklendi (toplam 50)
# ✔ Coffy tamamlandı
#
# [356/2165] Yummy Sushi (yummy-sushi)
#   → 50 yorum eklendi (toplam 50)
# ✔ Yummy Sushi tamamlandı
#
# [357/2165] Nazar Profiterol (nazar-profiterol-pu6u)
#   → 50 yorum eklendi (toplam 50)
# ✔ Nazar Profiterol tamamlandı
#
# [358/2165] Moncai Bubble Tea (moncai-bubble-tea-ifvp)
#   → 41 yorum eklendi (toplam 41)
# ✔ Moncai Bubble Tea tamamlandı
#
# [359/2165] Magnolia Shop (magnolia-shop-kxse)
#   → 50 yorum eklendi (toplam 50)
# ✔ Magnolia Shop tamamlandı
#
# [360/2165] Nuna Bakery (nuna-bakery)
#   → 50 yorum eklendi (toplam 50)
# ✔ Nuna Bakery tamamlandı
#
# [361/2165] The Rhythm Of Pasta Mambos (the-rhythm-of-pasta-mambos)
#   → 14 yorum eklendi (toplam 14)
# ✔ The Rhythm Of Pasta Mambos tamamlandı
#
# [362/2165] Burger King Cafe (burger-king-cafe-tkad)
#   → 6 yorum eklendi (toplam 6)
# ✔ Burger King Cafe tamamlandı
#
# [363/2165] Micoffees (micoffees)
#   → 50 yorum eklendi (toplam 50)
# ✔ Micoffees tamamlandı
#
# [364/2165] Mambos (mambos)
#   → 11 yorum eklendi (toplam 11)
# ✔ Mambos tamamlandı
#
# [365/2165] The Co. Coffee (the-co-coffee-nnt8)
#   → 3 yorum eklendi (toplam 3)
# ✔ The Co. Coffee tamamlandı
#
# [366/2165] Kaffee Schütz (kaffee-schutz-rndb)
#   → 10 yorum eklendi (toplam 10)
# ✔ Kaffee Schütz tamamlandı
#
# [367/2165] Paio Coffee (paio-coffee)
#   → 4 yorum eklendi (toplam 4)
# ✔ Paio Coffee tamamlandı
#
# [368/2165] Espressolab (espressolab-lpgx)
#   → 9 yorum eklendi (toplam 9)
# ✔ Espressolab tamamlandı
#
# [369/2165] Caleo Coffee & Bakery (caleo-coffee-and-bakery)
#   → 50 yorum eklendi (toplam 50)
# ✔ Caleo Coffee & Bakery tamamlandı
#
# [370/2165] NockNock Coffee (nocknock-coffee)
#   → 50 yorum eklendi (toplam 50)
# ✔ NockNock Coffee tamamlandı
#
# [371/2165] Riposo Coffee Kitchen (riposo-coffee-kitchen)
#   → 14 yorum eklendi (toplam 14)
# ✔ Riposo Coffee Kitchen tamamlandı
#
# [372/2165] Tikky’s Coffee (tikkys-coffee)
# ✔ Tikky’s Coffee tamamlandı
#
# [373/2165] Serez Dondurmacısı Maltepe (serez-dondurmacisi-maltepe)
#   → 8 yorum eklendi (toplam 8)
# ✔ Serez Dondurmacısı Maltepe tamamlandı
#
# [374/2165] Kahve Dünyası (kahve-dunyasi-fe5d)
#   → 47 yorum eklendi (toplam 47)
# ✔ Kahve Dünyası tamamlandı
#
# [375/2165] McDonald’s McCafé (mcdonalds-mccafe-vviu)
#   → 10 yorum eklendi (toplam 10)
# ✔ McDonald’s McCafé tamamlandı
#
# [376/2165] Mikel Coffee (mikel-coffee-rq2l)
#   → 26 yorum eklendi (toplam 26)
# ✔ Mikel Coffee tamamlandı
#
# [377/2165] Caffe Nero (caffe-nero-akww)
#   → 22 yorum eklendi (toplam 22)
# ✔ Caffe Nero tamamlandı
#
# [378/2165] Limp Patisserie (limp-patisserie)
#   → 33 yorum eklendi (toplam 33)
# ✔ Limp Patisserie tamamlandı
#
# [379/2165] Doppio Coffeehouse (doppio-coffeehouse)
#   → 6 yorum eklendi (toplam 6)
# ✔ Doppio Coffeehouse tamamlandı
#
# [380/2165] Moncai Premium Matcha (moncai-premium-matcha)
#   → 8 yorum eklendi (toplam 8)
# ✔ Moncai Premium Matcha tamamlandı
#
# [381/2165] Brewlog Coffee (brewlog-coffee)
#   → 4 yorum eklendi (toplam 4)
# ✔ Brewlog Coffee tamamlandı
#
# [382/2165] Çengelköy Börekçisi (cengelkoy-borekcisi-iuuf)
#   → 1 yorum eklendi (toplam 1)
# ✔ Çengelköy Börekçisi tamamlandı
#
# [383/2165] Ethique Patisserie & Boulangerie (ethique-patisserie-and-boulangerie)
#   → 50 yorum eklendi (toplam 50)
# ✔ Ethique Patisserie & Boulangerie tamamlandı
#
# [384/2165] Mahalle Fırın (mahalle-firin)
#   → 12 yorum eklendi (toplam 12)
# ✔ Mahalle Fırın tamamlandı
#
# [385/2165] Greenwich Coffee (greenwich-coffee-tbnu)
#   → 5 yorum eklendi (toplam 5)
# ✔ Greenwich Coffee tamamlandı
#
# [386/2165] Gloria Jean's Coffees (gloria-jeans-coffees-w3fg)
#   → 18 yorum eklendi (toplam 18)
# ✔ Gloria Jean's Coffees tamamlandı
#
# [387/2165] Nubi Artisan Bakery (nubi-artisan-bakery)
#   → 13 yorum eklendi (toplam 13)
# ✔ Nubi Artisan Bakery tamamlandı
#
# [388/2165] Lebon Gurme (lebon-gurme)
#   → 6 yorum eklendi (toplam 6)
# ✔ Lebon Gurme tamamlandı
#
# [389/2165] Retro Burger & Salad & Dessert (retro-burger-and-salad-and-dessert)
#   → 50 yorum eklendi (toplam 50)
# ✔ Retro Burger & Salad & Dessert tamamlandı
#
# [390/2165] Dozze Coffee (dozze-coffee)
# ✔ Dozze Coffee tamamlandı
#
# [391/2165] Coffee Pause (coffee-pause-sny0)
#   → 21 yorum eklendi (toplam 21)
# ✔ Coffee Pause tamamlandı
#
# [392/2165] Dart Coffee (dart-coffee)
#   → 4 yorum eklendi (toplam 4)
# ✔ Dart Coffee tamamlandı
#
# [393/2165] Tchibo (tchibo-jwcw)
#   → 10 yorum eklendi (toplam 10)
# ✔ Tchibo tamamlandı
#
# [394/2165] Salamora Sandwiches (salamora-sandwiches)
#   → 32 yorum eklendi (toplam 32)
# ✔ Salamora Sandwiches tamamlandı
#
# [395/2165] Colombia Coffee (colombia-coffee-vjt0)
#   → 2 yorum eklendi (toplam 2)
# ✔ Colombia Coffee tamamlandı
#
# [396/2165] Tupinamba (tupinamba)
#   → 4 yorum eklendi (toplam 4)
# ✔ Tupinamba tamamlandı
#
# [397/2165] Nevada Coffee (nevada-coffee-ikiu)
# ✔ Nevada Coffee tamamlandı
#
# [398/2165] Mr Coffee (mr-coffee)
#   → 50 yorum eklendi (toplam 50)
# ✔ Mr Coffee tamamlandı
#
# [399/2165] Dozze Coffee Bostancı (dozze-coffee-bostanci)
#   → 13 yorum eklendi (toplam 13)
# ✔ Dozze Coffee Bostancı tamamlandı
#
# [400/2165] Diverso Caffe (diverso-caffe)
#   → 4 yorum eklendi (toplam 4)
# ✔ Diverso Caffe tamamlandı
#
# [401/2165] Costa Coffee (costa-coffee-kmhw)
#   → 1 yorum eklendi (toplam 1)
# ✔ Costa Coffee tamamlandı
#
# [402/2165] Carmelo Coffee (carmelo-coffee-wdez)
#   → 7 yorum eklendi (toplam 7)
# ✔ Carmelo Coffee tamamlandı
#
# [403/2165] Hacıbaşar Kebap & Baklava (hacibasar-kebap-and-baklava-e8wi)
#   → 50 yorum eklendi (toplam 50)
# ✔ Hacıbaşar Kebap & Baklava tamamlandı
#
# [404/2165] Starhan Pide & Döner (starhan-pide-and-doner)
#   → 50 yorum eklendi (toplam 50)
# ✔ Starhan Pide & Döner tamamlandı
#
# [405/2165] Çeltik Kebap & Lahmacun (celtik-kebap-and-lahmacun-ow5z)
#   → 50 yorum eklendi (toplam 50)
# ✔ Çeltik Kebap & Lahmacun tamamlandı
#
# [406/2165] Çınaraltı Dürüm (cinaralti-durum)
#   → 50 yorum eklendi (toplam 50)
# ✔ Çınaraltı Dürüm tamamlandı
#
# [407/2165] Çeltik Kebap Maltepe Merkez (celtik-kebap-maltepe-merkez)
#   → 50 yorum eklendi (toplam 50)
# ✔ Çeltik Kebap Maltepe Merkez tamamlandı
#
# [408/2165] Tadı Bafra (tadi-bafra)
#   → 50 yorum eklendi (toplam 50)
# ✔ Tadı Bafra tamamlandı
#
# [409/2165] Saray Muhallebicisi 1935 (saray-muhallebicisi-1935-v2bj)
#   → 50 yorum eklendi (toplam 50)
# ✔ Saray Muhallebicisi 1935 tamamlandı
#
# [410/2165] Kardeşler Kebap (kardesler-kebap-csn8)
#   → 50 yorum eklendi (toplam 50)
# ✔ Kardeşler Kebap tamamlandı
#
# [411/2165] Mıntıka Kebap & Lahmacun & Meze (mintika-kebap-and-lahmacun-and-meze-yl0z)
#   → 50 yorum eklendi (toplam 50)
# ✔ Mıntıka Kebap & Lahmacun & Meze tamamlandı
#
# [412/2165] Abooov Kebap Ahmet Usta (abooov-kebap-ahmet-usta)
#   → 50 yorum eklendi (toplam 50)
# ✔ Abooov Kebap Ahmet Usta tamamlandı
#
# [413/2165] Tike Maltepe (tike-maltepe)
#   → 50 yorum eklendi (toplam 50)
# ✔ Tike Maltepe tamamlandı
#
# [414/2165] Önder Kebap & Lahmacun (onder-kebap-and-lahmacun-fnk3)
#   → 43 yorum eklendi (toplam 43)
# ✔ Önder Kebap & Lahmacun tamamlandı
#
# [415/2165] HD İskender (hd-iskender-cp0c)
#   → 50 yorum eklendi (toplam 50)
# ✔ HD İskender tamamlandı
#
# [416/2165] Moston Ev Yemekleri (moston-ev-yemekleri)
#   → 50 yorum eklendi (toplam 50)
# ✔ Moston Ev Yemekleri tamamlandı
#
# [417/2165] Erzincan Kasap Et & Mangal (erzincan-kasap-et-and-mangal)
#   → 50 yorum eklendi (toplam 50)
# ✔ Erzincan Kasap Et & Mangal tamamlandı
#
# [418/2165] Közde Kanat & Piliç Çevirme (kozde-kanat-and-pilic-cevirme-h5ns)
#   → 50 yorum eklendi (toplam 50)
# ✔ Közde Kanat & Piliç Çevirme tamamlandı
#
# [419/2165] Komagene Etsiz Çiğ Köfte (komagene-etsiz-cig-kofte-sh4q)
#   → 45 yorum eklendi (toplam 45)
# ✔ Komagene Etsiz Çiğ Köfte tamamlandı
#
# [420/2165] İrfan Usta Lahmacun (irfan-usta-lahmacun)
#   → 50 yorum eklendi (toplam 50)
# ✔ İrfan Usta Lahmacun tamamlandı
#
# [421/2165] Zirve Kokoreç (zirve-kokorec)
#   → 50 yorum eklendi (toplam 50)
# ✔ Zirve Kokoreç tamamlandı
#
# [422/2165] 7/24 Sultanahmet Çorbacısı (7-24-sultanahmet-corbacisi)
#   → 50 yorum eklendi (toplam 50)
# ✔ 7/24 Sultanahmet Çorbacısı tamamlandı
#
# [423/2165] Tek Büfe (tek-bufe-j6gm)
#   → 11 yorum eklendi (toplam 11)
# ✔ Tek Büfe tamamlandı
#
# [424/2165] Karacabey Künefe & Kebap & Lahmacun (karacabey-kunefe-and-kebap-and-lahmacun)
# ...
#
# [2026/2165] Kasabım Ethane (kasabim-ethane)
#   → 50 yorum eklendi (toplam 50)
# ✔ Kasabım Ethane tamamlandı
#
# [2027/2165] Saltbae Burger (saltbae-burger-yrnx)
#   → 15 yorum eklendi (toplam 15)
# ✔ Saltbae Burger tamamlandı
#
# [2028/2165] Besin Kasap & Steakhouse (besin-kasap-and-steakhouse)
#   → 47 yorum eklendi (toplam 47)
# ✔ Besin Kasap & Steakhouse tamamlandı
#
# [2029/2165] Baltazar (baltazar-rvnh)
#   → 50 yorum eklendi (toplam 50)
# ✔ Baltazar tamamlandı
#
# [2030/2165] Asaka Sushi & Chinese (asaka-sushi-and-chinese)
#   → 50 yorum eklendi (toplam 50)
# ✔ Asaka Sushi & Chinese tamamlandı
#
# [2031/2165] Şerifin Izgarası (serifin-izgarasi-aw7j)
#   → 50 yorum eklendi (toplam 50)
# ✔ Şerifin Izgarası tamamlandı
#
# [2032/2165] Şerifali Köftecisi (serifali-koftecisi-qwfv)
#   → 50 yorum eklendi (toplam 50)
# ✔ Şerifali Köftecisi tamamlandı
#
# [2033/2165] Noodle Saka Chef (noodle-saka-chef)
#   → 50 yorum eklendi (toplam 50)
# ✔ Noodle Saka Chef tamamlandı
#
# [2034/2165] Mindavallı Köfte & Piyaz (mindavalli-kofte-and-piyaz)
#   → 8 yorum eklendi (toplam 8)
# ✔ Mindavallı Köfte & Piyaz tamamlandı
#
# [2035/2165] Fulya Eastnbull Steak & Burger (fulya-eastnbull-steak-and-burger)
#   → 50 yorum eklendi (toplam 50)
# ✔ Fulya Eastnbull Steak & Burger tamamlandı
#
# [2036/2165] Burger Lab (burger-lab-xtqd)
#   → 5 yorum eklendi (toplam 5)
# ✔ Burger Lab tamamlandı
#
# [2037/2165] Pilavcı Hamza Usta (pilavci-hamza-usta)
#   → 3 yorum eklendi (toplam 3)
# ✔ Pilavcı Hamza Usta tamamlandı
#
# [2038/2165] Öz Gaziantep Sofrası (oz-gaziantep-sofrasi-xdhv)
#   → 7 yorum eklendi (toplam 7)
# ✔ Öz Gaziantep Sofrası tamamlandı
#
# [2039/2165] Öz Hacıoğlu Lezzetleri (oz-hacioglu-lezzetleri)
#   → 38 yorum eklendi (toplam 38)
# ✔ Öz Hacıoğlu Lezzetleri tamamlandı
#
# [2040/2165] Eatchil Steak (eatchil-steak)
#   → 4 yorum eklendi (toplam 4)
# ✔ Eatchil Steak tamamlandı
#
# [2041/2165] Mersin Yaprak Tantuni (mersin-yaprak-tantuni-yzuq)
#   → 50 yorum eklendi (toplam 50)
# ✔ Mersin Yaprak Tantuni tamamlandı
#
# [2042/2165] 33 Suat Usta Mersin Tantuni (33-suat-usta-mersin-tantuni-qdmp)
#   → 50 yorum eklendi (toplam 50)
# ✔ 33 Suat Usta Mersin Tantuni tamamlandı
#
# [2043/2165] Beşaltı Kirvem Tantuni (besalti-kirvem-tantuni)
#   → 3 yorum eklendi (toplam 3)
# ✔ Beşaltı Kirvem Tantuni tamamlandı
#
# [2044/2165] Galata Tantuni & Döner (galata-tantuni-and-doner)
#   → 1 yorum eklendi (toplam 1)
# ✔ Galata Tantuni & Döner tamamlandı
#
# [2045/2165] Çağlayan Tantuni (caglayan-tantuni)
#   → 1 yorum eklendi (toplam 1)
# ✔ Çağlayan Tantuni tamamlandı
#
# [2046/2165] Bey Tantuni (bey-tantuni-hjq0)
#   → 50 yorum eklendi (toplam 50)
# ✔ Bey Tantuni tamamlandı
#
# [2047/2165] Tantuni Yiyelim (tantuni-yiyelim)
#   → 50 yorum eklendi (toplam 50)
# ✔ Tantuni Yiyelim tamamlandı
#
# [2048/2165] 33 Suat Usta Mersin Tantuni (33-suat-usta-mersin-tantuni-lj7v)
#   → 50 yorum eklendi (toplam 50)
# ✔ 33 Suat Usta Mersin Tantuni tamamlandı
#
# [2049/2165] Mis Tantuni (mis-tantuni-n1nt)
#   → 18 yorum eklendi (toplam 18)
# ✔ Mis Tantuni tamamlandı
#
# [2050/2165] Bence Tantuni (bence-tantuni)
#   → 19 yorum eklendi (toplam 19)
# ✔ Bence Tantuni tamamlandı
#
# [2051/2165] Galata Döner (galata-doner-f9yr)
#   → 1 yorum eklendi (toplam 1)
# ✔ Galata Döner tamamlandı
#
# [2052/2165] Pozcu Tantuni (pozcu-tantuni-zbwv)
#   → 50 yorum eklendi (toplam 50)
# ✔ Pozcu Tantuni tamamlandı
#
# [2053/2165] Ayla Tantuni (ayla-tantuni-dgpm)
#   → 8 yorum eklendi (toplam 8)
# ✔ Ayla Tantuni tamamlandı
#
# [2054/2165] Tanto Tantuni (tanto-tantuni)
#   → 20 yorum eklendi (toplam 20)
# ✔ Tanto Tantuni tamamlandı
#
# [2055/2165] Ta & Ma Cafe & Restaurant (ta-and-ma-cafe-and-restaurant)
#   → 7 yorum eklendi (toplam 7)
# ✔ Ta & Ma Cafe & Restaurant tamamlandı
#
# [2056/2165] Tantuni Land (tantuni-land-galm)
#   → 4 yorum eklendi (toplam 4)
# ✔ Tantuni Land tamamlandı
#
# [2057/2165] Tarihi Beyoğlu Pilavcısı (tarihi-beyoglu-pilavcisi-l3cl)
# ✔ Tarihi Beyoğlu Pilavcısı tamamlandı
#
# [2058/2165] Molino Cucina (molino-cucina-ru4z)
#   → 50 yorum eklendi (toplam 50)
# ✔ Molino Cucina tamamlandı
#
# [2059/2165] Francesco Ristorante (francesco-ristorante)
#   → 50 yorum eklendi (toplam 50)
# ✔ Francesco Ristorante tamamlandı
#
# [2060/2165] Saray Muhallebicisi 1935 (saray-muhallebicisi-1935-e0yo)
#   → 50 yorum eklendi (toplam 50)
# ✔ Saray Muhallebicisi 1935 tamamlandı
#
# [2061/2165] Barbar Taş Fırın (barbar-tas-firin)
#   → 25 yorum eklendi (toplam 25)
# ✔ Barbar Taş Fırın tamamlandı
#
# [2062/2165] Mardin Dünya Tatlısı (mardin-dunya-tatlisi)
#   → 1 yorum eklendi (toplam 1)
# ✔ Mardin Dünya Tatlısı tamamlandı
#
# [2063/2165] Gaziantep Altın Dilim Baklava (gaziantep-altin-dilim-baklava)
#   → 2 yorum eklendi (toplam 2)
# ✔ Gaziantep Altın Dilim Baklava tamamlandı
#
# [2064/2165] Helvacı Ali 1900 (helvaci-ali-1900-ms2b)
#   → 5 yorum eklendi (toplam 5)
# ✔ Helvacı Ali 1900 tamamlandı
#
# [2065/2165] Mono Lounge (mono-lounge-s89s)
#   → 1 yorum eklendi (toplam 1)
# ✔ Mono Lounge tamamlandı
#
# [2066/2165] Emirgan Sütiş (emirgan-sutis-lp8j)
#   → 1 yorum eklendi (toplam 1)
# ✔ Emirgan Sütiş tamamlandı
#
# [2067/2165] Sufle Pera (sufle-pera-rmrr)
#   → 20 yorum eklendi (toplam 20)
# ✔ Sufle Pera tamamlandı
#
# [2068/2165] Göreme Muhallebicisi (goreme-muhallebicisi-ivnp)
#   → 50 yorum eklendi (toplam 50)
# ✔ Göreme Muhallebicisi tamamlandı
#
# [2069/2165] Hafız Mustafa 1864 (hafiz-mustafa-1864-jrob)
#   → 50 yorum eklendi (toplam 50)
# ✔ Hafız Mustafa 1864 tamamlandı
#
# [2070/2165] Sirkeci Baba Cadde Pastanesi (sirkeci-baba-cadde-pastanesi)
#   → 50 yorum eklendi (toplam 50)
# ✔ Sirkeci Baba Cadde Pastanesi tamamlandı
#
# [2071/2165] Helvacı Ali (helvaci-ali-zfqw)
#   → 50 yorum eklendi (toplam 50)
# ✔ Helvacı Ali tamamlandı
#
# [2072/2165] Beylerbeyi Profiterol (beylerbeyi-profiterol-br7w)
#   → 50 yorum eklendi (toplam 50)
# ✔ Beylerbeyi Profiterol tamamlandı
#
# [2073/2165] Kahve Dünyası (kahve-dunyasi-aqy8)
#   → 44 yorum eklendi (toplam 44)
# ✔ Kahve Dünyası tamamlandı
#
# [2074/2165] Helvacı Ali (helvaci-ali-e9rv)
#   → 50 yorum eklendi (toplam 50)
# ✔ Helvacı Ali tamamlandı
#
# [2075/2165] Eklercim (eklercim-q8zl)
#   → 50 yorum eklendi (toplam 50)
# ✔ Eklercim tamamlandı
#
# [2076/2165] Popeyes (popeyes-mx0q)
#   → 50 yorum eklendi (toplam 50)
# ✔ Popeyes tamamlandı
#
# [2077/2165] Texas Fried Chicken (texas-fried-chicken-yyvx)
#   → 50 yorum eklendi (toplam 50)
# ✔ Texas Fried Chicken tamamlandı
#
# [2078/2165] The Wild Chicken (the-wild-chicken)
#   → 50 yorum eklendi (toplam 50)
# ✔ The Wild Chicken tamamlandı
#
# [2079/2165] Must Bowl by Migros (must-bowl-by-migros-q1j2)
#   → 50 yorum eklendi (toplam 50)
# ✔ Must Bowl by Migros tamamlandı
#
# [2080/2165] Mariva Resturant & Cafe (mariva-resturant-and-cafe)
#   → 1 yorum eklendi (toplam 1)
# ✔ Mariva Resturant & Cafe tamamlandı
#
# [2081/2165] Makarnova (makarnova-bsux)
#   → 3 yorum eklendi (toplam 3)
# ✔ Makarnova tamamlandı
#
# [2082/2165] Nazar Pilav & Tavuk (nazar-pilav-and-tavuk)
# ✔ Nazar Pilav & Tavuk tamamlandı
#
# [2083/2165] Akçay Büfe (akcay-bufe)
#   → 5 yorum eklendi (toplam 5)
# ✔ Akçay Büfe tamamlandı
#
# [2084/2165] Acıktım (aciktim-ctij)
#   → 2 yorum eklendi (toplam 2)
# ✔ Acıktım tamamlandı
#
# [2085/2165] Marinee Kanat (marinee-kanat)
#   → 3 yorum eklendi (toplam 3)
# ✔ Marinee Kanat tamamlandı
#
# [2086/2165] Tavuk Dünyası (tavuk-dunyasi-fsib)
#   → 50 yorum eklendi (toplam 50)
# ✔ Tavuk Dünyası tamamlandı
#
# [2087/2165] Sammy's Fried Chicken (sammys-fried-chicken)
#   → 50 yorum eklendi (toplam 50)
# ✔ Sammy's Fried Chicken tamamlandı
#
# [2088/2165] Doyuyo (doyuyo-n30o)
#   → 50 yorum eklendi (toplam 50)
# ✔ Doyuyo tamamlandı
#
# [2089/2165] Green Salads (green-salads-tk7d)
#   → 50 yorum eklendi (toplam 50)
# ✔ Green Salads tamamlandı
#
# [2090/2165] Choys Fried Chicken (choys-fried-chicken)
#   → 50 yorum eklendi (toplam 50)
# ✔ Choys Fried Chicken tamamlandı
#
# [2091/2165] ŞFC Şef Fried Chicken (sfc-sef-fried-chicken)
#   → 50 yorum eklendi (toplam 50)
# ✔ ŞFC Şef Fried Chicken tamamlandı
#
# [2092/2165] Alfursan Resturant (alfursan-resturant)
#   → 50 yorum eklendi (toplam 50)
# ✔ Alfursan Resturant tamamlandı
#
# [2093/2165] Cajun Corner (cajun-corner-ulfd)
#   → 50 yorum eklendi (toplam 50)
# ✔ Cajun Corner tamamlandı
#
# [2094/2165] Kumpir Bago (kumpir-bago)
#   → 50 yorum eklendi (toplam 50)
# ✔ Kumpir Bago tamamlandı
#
# [2095/2165] Vernazza (vernazza)
#   → 50 yorum eklendi (toplam 50)
# ✔ Vernazza tamamlandı
#
# [2096/2165] Nisho Street Food (nisho-street-food-s10k)
#   → 3 yorum eklendi (toplam 3)
# ✔ Nisho Street Food tamamlandı
#
# [2097/2165] Tamamen Organik Tost (tamamen-organik-tost-zayk)
#   → 1 yorum eklendi (toplam 1)
# ✔ Tamamen Organik Tost tamamlandı
#
# [2098/2165] Akçay Büfe (akcay-bufe)
#   → 5 yorum eklendi (toplam 5)
# ✔ Akçay Büfe tamamlandı
#
# [2099/2165] İqsir Bistro Restaurant (iqsir-bistro-restaurant)
#   → 6 yorum eklendi (toplam 6)
# ✔ İqsir Bistro Restaurant tamamlandı
#
# [2100/2165] Cıncık Cafe Dünya Mutfağı (cincik-cafe-dunya-mutfagi)
#   → 4 yorum eklendi (toplam 4)
# ✔ Cıncık Cafe Dünya Mutfağı tamamlandı
#
# [2101/2165] Sedwich (sedwich)
#   → 16 yorum eklendi (toplam 16)
# ✔ Sedwich tamamlandı
#
# [2102/2165] Hanımeli Meze & Köfte (hanimeli-meze-and-kofte)
#   → 13 yorum eklendi (toplam 13)
# ✔ Hanımeli Meze & Köfte tamamlandı
#
# [2103/2165] Tarçın Cafe Restuarant (tarcin-cafe-restuarant)
#   → 2 yorum eklendi (toplam 2)
# ✔ Tarçın Cafe Restuarant tamamlandı
#
# [2104/2165] Köfteci Yusuf (kofteci-yusuf-dsj6)
#   → 50 yorum eklendi (toplam 50)
# ✔ Köfteci Yusuf tamamlandı
#
# [2105/2165] Bambi Cafe Taksim Express (bambi-cafe-taksim-express-fmqa)
#   → 50 yorum eklendi (toplam 50)
# ✔ Bambi Cafe Taksim Express tamamlandı
#
# [2106/2165] Etiler Marmaris (etiler-marmaris-vgqo)
#   → 44 yorum eklendi (toplam 44)
# ✔ Etiler Marmaris tamamlandı
#
# [2107/2165] Subway (subway-vbrl)
#   → 50 yorum eklendi (toplam 50)
# ✔ Subway tamamlandı
#
# [2108/2165] Es Sucuk'cum (es-sucukcum-oc87)
#   → 41 yorum eklendi (toplam 41)
# ✔ Es Sucuk'cum tamamlandı
#
# [2109/2165] Büfe De Büfe (bufe-de-bufe)
#   → 50 yorum eklendi (toplam 50)
# ✔ Büfe De Büfe tamamlandı
#
# [2110/2165] Kızılkayalar Hamburger (kizilkayalar-hamburger-vsmo)
#   → 50 yorum eklendi (toplam 50)
# ✔ Kızılkayalar Hamburger tamamlandı
#
# [2111/2165] Munchies Sandviç (munchies-sandvic-aizx)
#   → 50 yorum eklendi (toplam 50)
# ✔ Munchies Sandviç tamamlandı
#
# [2112/2165] SushiCo (sushico-h5pe)
#   → 50 yorum eklendi (toplam 50)
# ✔ SushiCo tamamlandı
#
# [2113/2165] Sushi & Spice (sushi-and-spice)
#   → 37 yorum eklendi (toplam 37)
# ✔ Sushi & Spice tamamlandı
#
# [2114/2165] Tas Ramen & Sushi Bar (tas-ramen-and-sushi-bar-dz45)
#   → 13 yorum eklendi (toplam 13)
# ✔ Tas Ramen & Sushi Bar tamamlandı
#
# [2115/2165] Take Sushi (take-sushi)
#   → 16 yorum eklendi (toplam 16)
# ✔ Take Sushi tamamlandı
#
# [2116/2165] Noodle Shop & Çin Kore Yemekleri (noodle-shop-and-cin-kore-yemekleri)
#   → 11 yorum eklendi (toplam 11)
# ✔ Noodle Shop & Çin Kore Yemekleri tamamlandı
#
# [2117/2165] Luka Sushi (luka-sushi)
#   → 15 yorum eklendi (toplam 15)
# ✔ Luka Sushi tamamlandı
#
# [2118/2165] Chinese Time (chinese-time-opp5)
#   → 33 yorum eklendi (toplam 33)
# ✔ Chinese Time tamamlandı
#
# [2119/2165] Kumiko Sushi & More (kumiko-sushi-and-more)
#   → 50 yorum eklendi (toplam 50)
# ✔ Kumiko Sushi & More tamamlandı
#
# [2120/2165] Shı Wok (shi-wok-oe4e)
#   → 20 yorum eklendi (toplam 20)
# ✔ Shı Wok tamamlandı
#
# [2121/2165] Sushi-G (sushi-g-kgx7)
#   → 50 yorum eklendi (toplam 50)
# ✔ Sushi-G tamamlandı
#
# [2122/2165] Noodle House (noodle-house-j7e9)
#   → 50 yorum eklendi (toplam 50)
# ✔ Noodle House tamamlandı
#
# [2123/2165] Çin Büfe & Sushi (cin-bufe-and-sushi)
#   → 50 yorum eklendi (toplam 50)
# ✔ Çin Büfe & Sushi tamamlandı
#
# [2124/2165] City Wok & Sushi (city-wok-and-sushi)
#   → 50 yorum eklendi (toplam 50)
# ✔ City Wok & Sushi tamamlandı
#
# [2125/2165] China Magic Box Sushi (china-magic-box-sushi)
#   → 50 yorum eklendi (toplam 50)
# ✔ China Magic Box Sushi tamamlandı
#
# [2126/2165] Kedai İndonesian Food (kedai-indonesian-food)
#   → 50 yorum eklendi (toplam 50)
# ✔ Kedai İndonesian Food tamamlandı
#
# [2127/2165] Konoha Sushi & Chinese (konoha-sushi-and-chinese-bqn9)
#   → 50 yorum eklendi (toplam 50)
# ✔ Konoha Sushi & Chinese tamamlandı
#
# [2128/2165] Chinese & Sushi Express (chinese-and-sushi-express-a22o)
#   → 50 yorum eklendi (toplam 50)
# ✔ Chinese & Sushi Express tamamlandı
#
# [2129/2165] Eagle Chinese Gastro & Sushi (eagle-chinese-gastro-and-sushi-ie1j)
#   → 50 yorum eklendi (toplam 50)
# ✔ Eagle Chinese Gastro & Sushi tamamlandı
#
# [2130/2165] Mr. Hamza Plus (mr-hamza-plus)
#   → 50 yorum eklendi (toplam 50)
# ✔ Mr. Hamza Plus tamamlandı
#
# [2131/2165] Must Bowl by Migros (must-bowl-by-migros-q1j2)
#   → 50 yorum eklendi (toplam 50)
# ✔ Must Bowl by Migros tamamlandı
#
# [2132/2165] Tost + (Kurtuluş) (tost-kurtulus)
#   → 50 yorum eklendi (toplam 50)
# ✔ Tost + (Kurtuluş) tamamlandı
#
# [2133/2165] Bowl & More (bowl-and-more-lm09)
#   → 50 yorum eklendi (toplam 50)
# ✔ Bowl & More tamamlandı
#
# [2134/2165] Tahin (tahin-esnv)
#   → 47 yorum eklendi (toplam 47)
# ✔ Tahin tamamlandı
#
# [2135/2165] Eat Your Greens (eat-your-greens-a81d)
#   → 32 yorum eklendi (toplam 32)
# ✔ Eat Your Greens tamamlandı
#
# [2136/2165] Bowl Department (bowl-department)
#   → 50 yorum eklendi (toplam 50)
# ✔ Bowl Department tamamlandı
#
# [2137/2165] Soul Bowl (soul-bowl-qfiv)
#   → 50 yorum eklendi (toplam 50)
# ✔ Soul Bowl tamamlandı
#
# [2138/2165] Happy Burger (happy-burger-eago)
#   → 50 yorum eklendi (toplam 50)
# ✔ Happy Burger tamamlandı
#
# [2139/2165] Vegan Masa (vegan-masa)
#   → 50 yorum eklendi (toplam 50)
# ✔ Vegan Masa tamamlandı
#
# [2140/2165] Pizza Vegas (pizza-vegas-f8ie)
#   → 23 yorum eklendi (toplam 23)
# ✔ Pizza Vegas tamamlandı
#
# [2141/2165] Noodle House (noodle-house-tmsw)
#   → 50 yorum eklendi (toplam 50)
# ✔ Noodle House tamamlandı
#
# [2142/2165] Falafel House (falafel-house)
#   → 29 yorum eklendi (toplam 29)
# ✔ Falafel House tamamlandı
#
# [2143/2165] Güneş Kahvaltı Evi (gunes-kahvalti-evi-c2qk)
#   → 50 yorum eklendi (toplam 50)
# ✔ Güneş Kahvaltı Evi tamamlandı
#
# [2144/2165] Leyna Falafel (leyna-falafel-v92d)
#   → 17 yorum eklendi (toplam 17)
# ✔ Leyna Falafel tamamlandı
#
# [2145/2165] Daisy’s Bowls (daisys-bowls-voy5)
#   → 34 yorum eklendi (toplam 34)
# ✔ Daisy’s Bowls tamamlandı
#
# [2146/2165] Rain Bowl (rain-bowl)
#   → 48 yorum eklendi (toplam 48)
# ✔ Rain Bowl tamamlandı
#
# [2147/2165] Bowl Dente (bowl-dente-yfbm)
#   → 48 yorum eklendi (toplam 48)
# ✔ Bowl Dente tamamlandı
#
# [2148/2165] Ziyafet Tavuklu Pilav (ziyafet-tavuklu-pilav)
#   → 6 yorum eklendi (toplam 6)
# ✔ Ziyafet Tavuklu Pilav tamamlandı
#
# [2149/2165] Chocolate Waffle (chocolate-waffle-kvow)
#   → 45 yorum eklendi (toplam 45)
# ✔ Chocolate Waffle tamamlandı
#
# [2150/2165] Always Waffle (always-waffle-h177)
#   → 50 yorum eklendi (toplam 50)
# ✔ Always Waffle tamamlandı
#
# [2151/2165] Wowmix (wowmix)
#   → 50 yorum eklendi (toplam 50)
# ✔ Wowmix tamamlandı
#
# [2152/2165] Pwb Peanut Waffle Belgium (pwb-peanut-waffle-belgium-mu9g)
#   → 50 yorum eklendi (toplam 50)
# ✔ Pwb Peanut Waffle Belgium tamamlandı
#
# [2153/2165] Happy Waffle (happy-waffle-r4f0)
#   → 50 yorum eklendi (toplam 50)
# ✔ Happy Waffle tamamlandı
#
# [2154/2165] Wafflecım 777 (wafflecim-777-xqsr)
#   → 20 yorum eklendi (toplam 20)
# ✔ Wafflecım 777 tamamlandı
#
# [2155/2165] Lale Waffle & Kumpir (lale-waffle-and-kumpir-zzsd)
#   → 45 yorum eklendi (toplam 45)
# ✔ Lale Waffle & Kumpir tamamlandı
#
# [2156/2165] Safiş Kumpir & Waffle (safis-kumpir-and-waffle)
#   → 40 yorum eklendi (toplam 40)
# ✔ Safiş Kumpir & Waffle tamamlandı
#
# [2157/2165] Crispy Waffle (crispy-waffle-ev51)
#   → 50 yorum eklendi (toplam 50)
# ✔ Crispy Waffle tamamlandı
#
# [2158/2165] Bunny Waffle (bunny-waffle)
#   → 50 yorum eklendi (toplam 50)
# ✔ Bunny Waffle tamamlandı
#
# [2159/2165] Waffle House Special (waffle-house-special-kuvc)
#   → 50 yorum eklendi (toplam 50)
# ✔ Waffle House Special tamamlandı
#
# [2160/2165] One Sweet (one-sweet)
#   → 50 yorum eklendi (toplam 50)
# ✔ One Sweet tamamlandı
#
# [2161/2165] A Love Waffle (a-love-waffle-rb2f)
#   → 20 yorum eklendi (toplam 20)
# ✔ A Love Waffle tamamlandı
#
# [2162/2165] Nuray Waffle (nuray-waffle-ofru)
#   → 8 yorum eklendi (toplam 8)
# ✔ Nuray Waffle tamamlandı
#
# [2163/2165] Waffle Store (waffle-store-l0oq)
#   → 4 yorum eklendi (toplam 4)
# ✔ Waffle Store tamamlandı
#
# [2164/2165] !Classo Dondurma & Waffle (classo-dondurma-and-waffle-byr7)
#   → 10 yorum eklendi (toplam 10)
# ✔ !Classo Dondurma & Waffle tamamlandı
#
# [2165/2165] Granny's Waffles & Kumpir (grannys-waffles-and-kumpir-kz3x)
#   → 5 yorum eklendi (toplam 5)
# ✔ Granny's Waffles & Kumpir tamamlandı
# ✅ TÜM RESTORANLAR TAMAMLANDI!

# %% [markdown]
# dataset limitation

# %%
import pandas as pd

csv_files = [
    "../data/raw/reviews/comments_from_low_to_high_ratings.csv",
    "../data/raw/reviews/new_to_old_comments.csv",
]

dfs = []
for file in csv_files:
    df = pd.read_csv(file)
    dfs.append(df)

merged = pd.concat(dfs, ignore_index=True)

merged.to_csv("../data/raw/reviews/restaurants_reviews_raw.csv", index=False, encoding="utf-8")

print("✅ restaurants_reviews_raw.csv")
# Out:
# ✅ restaurants_reviews_raw.csv
